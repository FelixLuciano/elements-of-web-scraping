# %% [markdown]
# # Análise de texto de fontes desestruturadas e Web
#
# ## Aula 04
#
# Neste aula iremos aprender como obter e analisar dados da Web (*World Wide Web*) utilizando bibliotecas Python.
#
# <img src="https://atd-insper.s3.us-east-2.amazonaws.com/aula04/img/requests-sidebar.png">
#
# A biblioteca utilizada será a **requests**, cujo lema é *HTTP for humans!* Nosso objetivo será entender como podemos requisitar estes recursos disponíveis na Web.
#
# Para conhecer mais sobre ela, acesse https://requests.readthedocs.io/

# %% [markdown]
# ## Instalando a biblioteca *requests*
#
# Primeiro, vamos instalar a principal biblioteca da aula!

# %%
# !pip install requests

# %% [markdown]
# Caso a bibliteca instalada seja de uma versão anterior, podemos atualizar com:

# %%
# !pip install -U pip
# !pip install -U requests

# %% [markdown]
# ## Importando as bibliotecas necessárias
#
# Agora, vamos importar as bibliotecas necessárias:

# %%
# para trabalhar com diretórios / sistema operacional
import os

# para nos comunicarmos com a Web
import requests

# para pegar o executável do Python
import sys

# %% [markdown]
# Caso obtenha algum erro, utilize o **!pip install** para instalar a biblioteca ausente!
#
# Vamos conferir com qual versão da biblioteca **requests** estamos trabalhando?

# %%
print(requests.__version__)
# Out:
# 2.28.2

# %% [markdown]
# Você também pode conferir de onde está executando o Python e qual a versão

# %%
print('Executável:')
print(sys.executable)

print('\nVersão do Python:')
print(sys.version)
# Out:
# Executável:
# /opt/conda/bin/python
#
# Versão do Python:
# 3.10.9 | packaged by conda-forge | (main, Feb  2 2023, 20:20:04) [GCC 11.3.0]

# %% [markdown]
# Vamos conferir em qual diretório iremos trabalhar (é o diretório do notebook)?

# %%
print('O seu notebook está na pasta:')
print(os.getcwd())
# Out:
# O seu notebook está na pasta:
# /home/jovyan

# %% [markdown]
# ## Validação de CEP!
#
# É comum que exista a necessidade de comunicação entre aplicações. Isto é feito pela disponibilização de uma API (*Application Programming Interface - Interface de Programação de Aplicativos*).
#
# Uma API atua como uma camada que provê **comunicação**, ou seja, espeficifa uma interface que outras aplicações devem utilizar caso queiram se comunicar, permitindo que diferentes sistemas conversem entre si sem precisar entender exatamente o que cada um faz.
#
# Apesar do termos ser comumente utilizado em um contexto Web, nos computador as aplicações precisam conhecer a API do sistema operacional para solicitar recursos, e nós programadores precisamos conhecer a API do pandas, sklearn, matplotlib, etc. caso queiramos utilizar recursos destes pacotes no Python!
#
# Como um primeiro exemplo, iremos utilizar a API do viacep para validar **CEP**s!  Abra o site https://viacep.com.br e veja como este webservice (https://pt.wikipedia.org/wiki/Web_service) é disponibilizado.

# %%
cep = '04546-042'

# Complete a URL
url_cep = f"https://viacep.com.br/ws/{cep}/piped/"

req = requests.get(url_cep)
req
# Out:
# <Response [200]>

# %% [markdown]
# Perceba, pela **rota** descrita na **URL**, que escolhemos o formato `piped`. Então, esperamos que as informações do CEP consultado volte como uma string separada por pipes `|`.
#
#
# Com a requisição feita, vamos conferir o código de resposta:

# %%
req.status_code
# Out:
# 200

# %% [markdown]
# O tipo de conteúdo retornado:

# %%
req.headers['content-type']
# Out:
# 'text/plain; charset=utf-8'

# %% [markdown]
# Perceba que obtivemos `text/plain`, o que significa que a resposta veio como uma string, em codificação `utf-8` (exploraremos depois a codificação).

# %%
print('Texto de resposta:\n')
print(req.text)
# Out:
# Texto de resposta:
#
# cep:04546-042|logradouro:Rua Quatá|complemento:de 251/252 a 449/450|bairro:Vila Olímpia|localidade:São Paulo|uf:SP|ibge:3550308|gia:1004|ddd:11|siafi:7107

# %% [markdown]
# E se fizermos a requisição de um CEP inválido?!

# %%
cep = '12345'
url_cep = f"https://viacep.com.br/ws/{cep}/piped/"
req = requests.get(url_cep)

req
# Out:
# <Response [400]>

# %% [markdown]
# Conferindo o código de resposta:

# %%
print('Código de status da resposta: {}'.format(req.status_code))
# Out:
# Código de status da resposta: 400

# %% [markdown]
# Iremos estudar nos próximos tópicos o significado do status de resposta. Por enquanto, você tem algum palpite sobre em quais situações ele pode ser útil?!

# %% [raw]
# Erro no lado do cliente

# %% [markdown]
# ## Códigos de status de respostas HTTP
#
#
# Quando solicitamos um recurso, quais são as respostas possíveis? É importante perceber que nem sempre o recurso solicitado estará disponível.
#
# Vamos fazer uma requisição GET ao Google.

# %%
resposta = requests.get('http://www.google.com/')
resposta
# Out:
# <Response [200]>

# %% [markdown]
# Vamos conferir o código de resposta:

# %%
print('Código de status da resposta: {}'.format(resposta.status_code))
# Out:
# Código de status da resposta: 200

# %%
resposta.ok
# Out:
# True

# %% [markdown]
# Agora, vamos realizar uma consulta utilizando uma URL inexistente:

# %%
resposta = requests.get('http://www.google.com/abacadabra')
resposta
# Out:
# <Response [404]>

# %%
print('Código de status da resposta: {}'.format(resposta.status_code))
# Out:
# Código de status da resposta: 404

# %% [markdown]
# Perceba que temos um novo código `404` e que a requisição não está ok!

# %%
resposta.ok
# Out:
# False

# %% [markdown]
# E por último esta consulta retorna:

# %%
url = 'https://atd-insper.s3.us-east-2.amazonaws.com/aula04/fatura.pdf'

resposta = requests.get(url)
resposta
# Out:
# <Response [403]>

# %% [markdown]
# Acesse https://developer.mozilla.org/pt-BR/docs/Web/HTTP/Status ou https://pt.wikipedia.org/wiki/Lista_de_códigos_de_estado_HTTP para ver mais informações sobre os códigos de status da resposta. Eles podem indicar desde um sucesso, recurso inexistente até uma ausência de permissão para acesso.

# %% [markdown]
# **Exercício 1** Crie um bloco de código (preferencialmente uma função) que consulte um CEP. Caso o CEP seja válido, imprima o endereço. Caso o CEP seja inválido, imprima a mensagem "*CEP inválido!*"

# %%
def consulta_cep(cep):
    url_cep = f"https://viacep.com.br/ws/{cep}/piped/"
    response = requests.get(url_cep)

    if not response.ok or response.status_code != 200:
        raise ValueError(f"Status code {response.status_code}")

    return dict(item.split(":") for item in response.text.split("|"))

# %%
consulta_cep('123')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 consulta_cep('123')
#
# Cell In[40], line 6, in consulta_cep(cep)
#       3 response = requests.get(url_cep)
#       5 if not response.ok or response.status_code != 200:
# ----> 6     raise ValueError(f"Status code {response.status_code}")
#       8 return dict(item.split(":") for item in response.text.split("|"))
#
# ValueError: Status code 400

# %%
consulta_cep('01310100')
# Out:
# {'cep': '01310-100',
#  'logradouro': 'Avenida Paulista',
#  'complemento': 'de 612 a 1510 - lado par',
#  'bairro': 'Bela Vista',
#  'localidade': 'São Paulo',
#  'uf': 'SP',
#  'ibge': '3550308',
#  'gia': '1004',
#  'ddd': '11',
#  'siafi': '7107'}

# %% [markdown]
# **Exercício 2** O que acontece caso pesquise algum CEP no formato válido, mas que seja um CEP inexistente? Altere sua função para considerar este caso

# %%
def consulta_cep(cep):
    url_cep = f"https://viacep.com.br/ws/{cep}/piped/"
    response = requests.get(url_cep)

    if not response.ok or response.status_code != 200:
        raise ValueError(f"Status code {response.status_code}")

    data = dict(item.split(":") for item in response.text.split("|"))

    if "erro" in data:
        raise ValueError("Invalid CEP")

    return data

# %%
consulta_cep('77777777')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 consulta_cep('77777777')
#
# Cell In[59], line 11, in consulta_cep(cep)
#       8 data = dict(item.split(":") for item in response.text.split("|"))
#      10 if "erro" in data:
# ---> 11     raise ValueError("Invalid CEP")
#      13 return data
#
# ValueError: Invalid CEP

# %%
consulta_cep('1234')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 consulta_cep('1234')
#
# Cell In[59], line 6, in consulta_cep(cep)
#       3 response = requests.get(url_cep)
#       5 if not response.ok or response.status_code != 200:
# ----> 6     raise ValueError(f"Status code {response.status_code}")
#       8 data = dict(item.split(":") for item in response.text.split("|"))
#      10 if "erro" in data:
#
# ValueError: Status code 400

# %%
consulta_cep('05436100')
# Out:
# {'cep': '05436-100',
#  'logradouro': 'Rua Gonçalo Afonso',
#  'complemento': '',
#  'bairro': 'Jardim das Bandeiras',
#  'localidade': 'São Paulo',
#  'uf': 'SP',
#  'ibge': '3550308',
#  'gia': '1004',
#  'ddd': '11',
#  'siafi': '7107'}

# %% [markdown]
# **Exercício 3**
#
# - **a)**) Separe a string do endereço do exercício anterior em substrings, divindindo pelo *pipe* (barra vertical $\rightarrow$ |). Armazene o resultado em uma lista.
#
# - **b)** Tente também separar o que é título (ex: `logradouro`) do que é conteúdo (ex:`Rua Gonçalo Afonso`). Armazene o resultado em um dicionário.

# %%
# Seu código aqui

# %% [markdown]
# No exercício 3 o texto de retorno foi dividido utilizando o *pipe* (barra vertical $\rightarrow$ |) como referência. Entretanto, uma forma melhor seria utilizar a interface **JSON** do viacep!
#
# Note que será alterada o final da URL:

# %%
cep = '05436100'
url = 'https://viacep.com.br/ws/{}/json/'.format(cep)

req = requests.get(url=url)

endereco = req.text

endereco
# Out:
# '{\n  "cep": "05436-100",\n  "logradouro": "Rua Gonçalo Afonso",\n  "complemento": "",\n  "bairro": "Jardim das Bandeiras",\n  "localidade": "São Paulo",\n  "uf": "SP",\n  "ibge": "3550308",\n  "gia": "1004",\n  "ddd": "11",\n  "siafi": "7107"\n}'

# %%
print(endereco)
# Out:
# {
#   "cep": "05436-100",
#   "logradouro": "Rua Gonçalo Afonso",
#   "complemento": "",
#   "bairro": "Jardim das Bandeiras",
#   "localidade": "São Paulo",
#   "uf": "SP",
#   "ibge": "3550308",
#   "gia": "1004",
#   "ddd": "11",
#   "siafi": "7107"
# }

# %% [markdown]
# Vamos utilizar a biblioteca `json` para representar o endereço de forma estruturada:

# %%
import json

dicionario_endereco = json.loads(endereco)
dicionario_endereco
# Out:
# {'cep': '05436-100',
#  'logradouro': 'Rua Gonçalo Afonso',
#  'complemento': '',
#  'bairro': 'Jardim das Bandeiras',
#  'localidade': 'São Paulo',
#  'uf': 'SP',
#  'ibge': '3550308',
#  'gia': '1004',
#  'ddd': '11',
#  'siafi': '7107'}

# %% [markdown]
# Podemos então utilizar o `dicionario_endereco` para acessar informações dos dados, utilizando **chave** para obter o **valor** armazenado. Veja com a chave **cep**:

# %%
dicionario_endereco['cep']
# Out:
# '05436-100'

# %% [markdown]
# **Exercício 4** Qual o código de resposta que identifica que houve **sucesso** na requisição GET?

# %% [markdown]
# R: 200

# %% [markdown]
# **Exercício 5** Qual a diferença entre os códigos de erro 401 e 403?

# %% [markdown]
# R: Significa que o servidor se recusa a disponibilizar o recurso para o cliente. No caso do erro 401, a identidade do cliente é desconhecida, já no 403, é desconhecida.

# %% [markdown]
# **Exercício 6** Crie um bloco de código que acessa uma URL, informa se houve sucesso ou trata os erros 404, 403 e 401, fornecendo mensagens adequadas.

# %%
def consulta_cep(cep):
    url_cep = f"https://viacep.com.br/ws/{cep}/piped/"
    response = requests.get(url_cep)

    STATUS_CODE_RESPONSE = {
        401: "Unauthrized",
        403: "Forbiden",
        404: "Invalid CEP",
    }

    if not response.ok:
        if response.status_code in STATUS_CODE_RESPONSE:
            raise ValueError(STATUS_CODE_RESPONSE)

    data = dict(item.split(":") for item in response.text.split("|"))

    if "erro" in data:
        raise ValueError(STATUS_CODE_RESPONSE[403])

    return data

# %% [markdown]
# ## Internet Protocol address (IP)
#
# Os seres humanos acessam informações on-line utilizando endereços como http://www.google.com. Para que os recursos sejam localizados, os navegadores da Web utilizam endereços de protocolo de internet (**IP**). A conversão de nomes de domínio em endereços de **IP** pode ser realizada utilizando um serviço **DNS** (*Domain Name System*).
#
# Iremos conferir o endereço **IP** dos servidores que estamos consultando

# %%
gg = requests.get('https://google.com', stream=True)
gg.raw._connection.sock.getpeername()
# Out:
# ('142.250.218.164', 443)

# %%
gg = requests.get('http://www.insper.edu.br/', stream=True)
gg.raw._connection.sock.getpeername()
# Out:
# ('23.41.255.78', 443)

# %% [markdown]
# No próximo comando, iremos realizar um `ping`. O comando `ping` é uma ferramenta simples usada para testar a conectividade entre dois dispositivos em uma rede. Quando o comando `ping` é executado, ele envia um pacote ICMP (pense como se fosse uma mensagem) para o dispositivo de destino e aguarda uma resposta. Se uma resposta for recebida, o comando ping exibe informações como tempo de resposta, perda de pacotes e número de pacotes transmitidos.
#
# Obs: se estiver no Windows, remova o -c 4

# %%
# !sudo apt update
# !sudo apt install iputils-ping -y
# !ping -c 4 www.insper.edu.br
# Out:
# PING e242044.dscb.akamaiedge.net (23.41.255.78) 56(84) bytes of data.
# 64 bytes from 23.41.255.78 (23.41.255.78): icmp_seq=1 ttl=36 time=4.98 ms
# 64 bytes from 23.41.255.78 (23.41.255.78): icmp_seq=2 ttl=36 time=7.36 ms
# 64 bytes from 23.41.255.78 (23.41.255.78): icmp_seq=3 ttl=36 time=14.5 ms
# 64 bytes from 23.41.255.78 (23.41.255.78): icmp_seq=4 ttl=36 time=15.4 ms
#
# --- e242044.dscb.akamaiedge.net ping statistics ---
# 4 packets transmitted, 4 received, 0% packet loss, time 3005ms
# rtt min/avg/max/mdev = 4.978/10.572/15.419/4.496 ms

# %% [markdown]
# ## Baixando imagens
#
# Nos tópicos anteriores fizemos requisições que retornaram conteúdo do tipo `text/plain` (strings). Entretanto, as mesmas chamadas GET podem ser utilizadas para recuperar imagens, PDFs, páginas Web, etc.
#
# Vamos solicitar uma imagem PNG:

# %%
url_imagem = 'https://s2.studylib.net/store/data/013539884_1-c723ea60365e3706a333362a126d4c5a.png'

req = requests.get(url = url_imagem)

print(req.status_code)
# Out:
# 200

# %% [markdown]
# Perceba que o código `200` nos indica que obtivemos sucesso!
#
# No `content-type`, perceba que o conteúdo retornado é do tipo `img/png`

# %%
req.headers['content-type']
# Out:
# 'image/png'

# %% [markdown]
# Agora, vamos salvar a imagem. Abriremos um arquivo em modo de escrita e escrevemos o conteúdo (`req.content`) retornado pela requisição.

# %%
with open('notebooks/lessons/04/the-lady-tasting-tea.png', "wb") as content:
    content.write(req.content)

# %% [markdown]
# **Exercício 7** Exiba a imagem na tela.
#
# **Dica:** não se esqueça de importar o **cv2** e o **matplotlib**. Confira como fizemos na aula passada.

# %%
import cv2 as cv
from matplotlib import pyplot as plt


img = cv.imread('notebooks/lessons/04/the-lady-tasting-tea.png')

plt.rcParams['figure.figsize'] = (15,15)
plt.imshow(img);

# %% [markdown]
# **Exercício 8** Conforme aula anterior, utilize um **Reader** do **EasyOCR** para realizar a transcrição dos dados contidos na imagem.

# %%
import easyocr


reader = easyocr.Reader(['pt', 'en'], gpu = False)

texto = reader.readtext('notebooks/lessons/04/the-lady-tasting-tea.png')
texto
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# [([[613, 95], [677, 95], [677, 111], [613, 111]],
#   'Erin Shea',
#   0.849013471150254),
#  ([[651, 113], [675, 113], [675, 129], [651, 129]], '081', 0.9864007617224706),
#  ([[497, 131], [679, 131], [679, 147], [497, 147]],
#   'The Lady Tasting Te Paper',
#   0.49577262469602207),
#  ([[575, 147], [677, 147], [677, 165], [575, 165]],
#   'March 15, 2005',
#   0.898486726645517),
#  ([[306, 181], [484, 181], [484, 206], [306, 206]],
#   'Ihe Lady Tasting Tea',
#   0.8040635469902021),
#  ([[163, 241], [357, 241], [357, 257], [163, 257]],
#   'Thc Lady Tasting Tea not only',
#   0.603404967595729),
#  ([[395, 240], [629, 240], [629, 260], [395, 260]],
#   'the reader through the progression of',
#   0.8705638571514693),
#  ([[114, 275], [251, 275], [251, 293], [114, 293]],
#   'statistics, but also the',
#   0.7921520463025263),
#  ([[299, 277], [339, 277], [339, 291], [299, 291]],
#   'of the',
#   0.8281238396517626),
#  ([[423, 275], [643, 275], [643, 293], [423, 293]],
#   'the time period; the brilliant minds',
#   0.6658541167775595),
#  ([[115, 311], [633, 311], [633, 329], [115, 329]],
#   'associated with the breakthroughs in this mathematical realm; the people of the era',
#   0.7105886889878633),
#  ([[115, 347], [659, 347], [659, 365], [115, 365]],
#   'affected by the different applications of this progressing science; and, last but not least,',
#   0.5788792879084947),
#  ([[115, 381], [337, 381], [337, 401], [115, 401]],
#   'the various philosophical questions',
#   0.9705297064796827),
#  ([[341, 383], [645, 383], [645, 399], [341, 399]],
#   'answered and unanswered, inextricable from the',
#   0.5360662207423965),
#  ([[115, 419], [227, 419], [227, 437], [115, 437]],
#   'study of statistics',
#   0.8934819008499495),
#  ([[163, 453], [653, 453], [653, 473], [163, 473]],
#   'The story begins in Cambridge; England in the 1920s in the simple setting of a',
#   0.6470085908045928),
#  ([[114, 489], [223, 489], [223, 509], [114, 509]],
#   'garden tea party .',
#   0.8598495252408099),
#  ([[243, 493], [291, 493], [291, 507], [243, 507]],
#   'womnan',
#   0.9617446245643168),
#  ([[289, 486], [666, 486], [666, 510], [289, 510]],
#   'claiming she can tell the difference between tea poured into',
#   0.6535860323472719),
#  ([[115, 526], [397, 526], [397, 543], [115, 543]],
#   'milk and milk poured into tea introduces this',
#   0.9831909472517427),
#  ([[437, 527], [635, 527], [635, 543], [437, 543]],
#   'and then we jump back into the',
#   0.611381692814342),
#  ([[117, 561], [425, 561], [425, 581], [117, 581]],
#   '1890s, when the statistics revolution grows roots.',
#   0.5777798826143609),
#  ([[431, 561], [649, 561], [649, 581], [431, 581]],
#   'The story progresses from Pearson `',
#   0.4878863976872719),
#  ([[115, 595], [665, 595], [665, 615], [115, 615]],
#   'early work through World War L, The Depression and New Deal, World War IL, and the',
#   0.8327917314985395),
#  ([[115, 633], [569, 633], [569, 649], [115, 649]],
#   'Russian Revolution, and we learn of the different characters (Gosset aka',
#   0.6761100833827375),
#  ([[575, 633], [633, 633], [633, 649], [575, 649]],
#   'Student" ',
#   0.5102023118932534),
#  ([[115, 666], [341, 666], [341, 685], [115, 685]],
#   'Fisher, Neyman), scientific journals',
#   0.49324813939907075),
#  ([[369, 667], [637, 667], [637, 685], [369, 685]],
#   'books ( Biometrika, Statistical Methods for',
#   0.6406841728443751),
#  ([[115, 703], [633, 703], [633, 723], [115, 723]],
#   'Research Workers). and experiments of importance to the field that come into play_',
#   0.650853636435409),
#  ([[641, 705], [669, 705], [669, 719], [641, 719]], 'The', 0.5537710189819336),
#  ([[115, 739], [669, 739], [669, 759], [115, 759]],
#   'reader is given example after example of statistical applications during the different time',
#   0.6726571362424801),
#  ([[114, 775], [165, 775], [165, 793], [114, 793]],
#   'periods',
#   0.9870582289999166),
#  ([[169, 775], [671, 775], [671, 795], [169, 795]],
#   'from brewing Guinness in Ireland, to cracking German codes during wartime, to',
#   0.5838937364177315),
#  ([[115, 811], [409, 811], [409, 829], [115, 829]],
#   'attempting to locate buried landmines in Japan',
#   0.7720546232272321),
#  ([[423, 809], [667, 809], [667, 829], [423, 829]],
#   'failed attempt, which; according to the',
#   0.7493262676369276),
#  ([[115, 845], [373, 845], [373, 865], [115, 865]],
#   'author; in part led to the atomic bombing-',
#   0.5300972386007556),
#  ([[357.4929798734366, 239.13806578484224],
#    [394.96536339302827, 242.73909097485722],
#    [393.5070201265634, 257.86193421515776],
#    [356.03463660697173, 253.26090902514278]],
#   'takes',
#   0.45846696072218523),
#  ([[251.1401328392153, 272.19427896235214],
#    [299.9579608394752, 278.592091491776],
#    [297.8598671607847, 296.80572103764786],
#    [248.04203916052478, 289.407908508224]],
#   'history',
#   0.9998523450965754),
#  ([[338.29289321881345, 279.29289321881345],
#    [377.9086768439633, 275.5824998284493],
#    [379.70710678118655, 290.70710678118655],
#    [339.0913231560367, 293.4175001715507]],
#   'world',
#   0.958028320370076),
#  ([[379.1055728090001, 272.21114561800016],
#    [424.96116135138186, 279.6077677297236],
#    [421.8944271909999, 295.78885438199984],
#    [376.03883864861814, 289.3922322702764]],
#   'during',
#   0.9999098678240761),
#  ([[397.4929798734366, 525.1380657848422],
#    [432.96849293259686, 529.7509589601893],
#    [431.5070201265634, 543.8619342151578],
#    [396.03150706740314, 539.2490410398107]],
#   'stOFY .',
#   0.3228493828681919),
#  ([[339.2567058537528, 671.3310352683776],
#    [365.8376105968386, 668.4537322194531],
#    [367.7432941462472, 681.6689647316224],
#    [341.1623894031614, 684.5462677805469]],
#   'and',
#   0.9944158015216005)]

# %%
" ".join(a[-2] for a in texto)
# Out:
# 'Erin Shea 081 The Lady Tasting Te Paper March 15, 2005 Ihe Lady Tasting Tea Thc Lady Tasting Tea not only the reader through the progression of statistics, but also the of the the time period; the brilliant minds associated with the breakthroughs in this mathematical realm; the people of the era affected by the different applications of this progressing science; and, last but not least, the various philosophical questions answered and unanswered, inextricable from the study of statistics The story begins in Cambridge; England in the 1920s in the simple setting of a garden tea party . womnan claiming she can tell the difference between tea poured into milk and milk poured into tea introduces this and then we jump back into the 1890s, when the statistics revolution grows roots. The story progresses from Pearson ` early work through World War L, The Depression and New Deal, World War IL, and the Russian Revolution, and we learn of the different characters (Gosset aka Student"  Fisher, Neyman), scientific journals books ( Biometrika, Statistical Methods for Research Workers). and experiments of importance to the field that come into play_ The reader is given example after example of statistical applications during the different time periods from brewing Guinness in Ireland, to cracking German codes during wartime, to attempting to locate buried landmines in Japan failed attempt, which; according to the author; in part led to the atomic bombing- takes history world during stOFY . and'

# %% [markdown]
# ## Baixando arquivos de texto
#
# Vamos baixar um arquivo TXT do livro *Alice's Adventures in Wonderland*. Aproveitando, iremos configurar um **timeout**, que irá definir o tempo máximo de espera por uma resposta.
#
# Para conseguir o link do livro, acesse https://atd-insper.s3.us-east-2.amazonaws.com/aula04/alice_wonderland.txt

# %%
alice_url_txt = 'https://atd-insper.s3.us-east-2.amazonaws.com/aula04/alice_wonderland.txt'

resposta = requests.get(url=alice_url_txt, timeout=1)

resposta
# Out:
# <Response [200]>

# %% [markdown]
# Perceba que o argumento de `timeout` está quase zero! Provavelmente a requisição irá falhar. Aumente este valor até obter sucesso. Isto será útil quando você tiver uma tolerância máxima de espera por algum recurso.
#
# Vamos conferir o `content-type`:

# %%
resposta.headers['content-type']
# Out:
# 'text/plain'

# %% [markdown]
# Vejamos o texto retornado:

# %%
print(resposta.text)
# Out:
# Alice's Adventures in Wonderland
#
#                 ALICE'S ADVENTURES IN WONDERLAND
#
#                           Lewis Carroll
#
#                THE MILLENNIUM FULCRUM EDITION 3.0
#
#
#
#
#                             CHAPTER I
#
#                       Down the Rabbit-Hole
#
#
#   Alice was beginning to get very tired of sitting by her sister
# on the bank, and of having nothing to do:  once or twice she had
# peeped into the book her sister was reading, but it had no
# pictures or conversations in it, `and what is the use of a book,'
# thought Alice `without pictures or conversation?'
#
#   So she was considering in her own mind (as well as she could,
# for the hot day made her feel very sleepy and stupid), whether
# the pleasure of making a daisy-chain would be worth the trouble
# of getting up and picking the daisies, when suddenly a White
# Rabbit with pink eyes ran close by her.
#
#   There was nothing so VERY remarkable in that; nor did Alice
# think it so VERY much out of the way to hear the Rabbit say to
# itself, `Oh dear!  Oh dear!  I shall be late!'  (when she thought
# it over afterwards, it occurred to her that she ought to have
# wondered at this, but at the time it all seemed quite natural);
# but when the Rabbit actually TOOK A WATCH OUT OF ITS WAISTCOAT-
# POCKET, and looked at it, and then hurried on, Alice started to
# her feet, for it flashed across her mind that she had never
# before seen a rabbit with either a waistcoat-pocket, or a watch to
# take out of it, and burning with curiosity, she ran across the
# field after it, and fortunately was just in time to see it pop
# down a large rabbit-hole under the hedge.

# %% [markdown]
# Então podemos fazer o que quisermos com este texto:
# - Remover stopwords
# - Quebrar em palavras
# - Analisar sentimento das frases
# - etc.

# %%
resposta.text.split()
# Out:
# ["Alice's",
#  'Adventures',
#  'in',
#  'Wonderland',
#  "ALICE'S",
#  'ADVENTURES',
#  'IN',
#  'WONDERLAND',
#  'Lewis',
#  'Carroll',
#  'THE',
#  'MILLENNIUM',
#  'FULCRUM',
#  'EDITION',
#  '3.0',
#  'CHAPTER',
#  'I',
#  'Down',
#  'the',
#  'Rabbit-Hole',
#  'Alice',
#  'was',
#  'beginning',
#  'to',
#  'get',
#  'very',
#  'tired',
#  'of',
#  'sitting',
#  'by',
#  'her',
#  'sister',
#  'on',
#  'the',
#  'bank,',
#  'and',
#  'of',
#  'having',
#  'nothing',
#  'to',
#  'do:',
#  'once',
#  'or',
#  'twice',
#  'she',
#  'had',
#  'peeped',
#  'into',
#  'the',
#  'book',
#  'her',
#  'sister',
#  'was',
#  'reading,',
#  'but',
#  'it',
#  'had',
#  'no',
#  'pictures',
#  'or',
#  'conversations',
#  'in',
#  'it,',
#  '`and',
#  'what',
#  'is',
#  'the',
#  'use',
#  'of',
#  'a',
#  "book,'",
#  'thought',
#  'Alice',
#  '`without',
#  'pictures',
#  'or',
#  "conversation?'",
#  'So',
#  'she',
#  'was',
#  'considering',
#  'in',
#  'her',
#  'own',
#  'mind',
#  '(as',
#  'well',
#  'as',
#  'she',
#  'could,',
#  'for',
#  'the',
#  'hot',
#  'day',
#  'made',
#  'her',
#  'feel',
#  'very',
#  'sleepy',
#  'and',
#  'stupid),',
#  'whether',
#  'the',
#  'pleasure',
#  'of',
#  'making',
#  'a',
#  'daisy-chain',
#  'would',
#  'be',
#  'worth',
#  'the',
#  'trouble',
#  'of',
#  'getting',
#  'up',
#  'and',
#  'picking',
#  'the',
#  'daisies,',
#  'when',
#  'suddenly',
#  'a',
#  'White',
#  'Rabbit',
#  'with',
#  'pink',
#  'eyes',
#  'ran',
#  'close',
#  'by',
#  'her.',
#  'There',
#  'was',
#  'nothing',
#  'so',
#  'VERY',
#  'remarkable',
#  'in',
#  'that;',
#  'nor',
#  'did',
#  'Alice',
#  'think',
#  'it',
#  'so',
#  'VERY',
#  'much',
#  'out',
#  'of',
#  'the',
#  'way',
#  'to',
#  'hear',
#  'the',
#  'Rabbit',
#  'say',
#  'to',
#  'itself,',
#  '`Oh',
#  'dear!',
#  'Oh',
#  'dear!',
#  'I',
#  'shall',
#  'be',
#  "late!'",
#  '(when',
#  'she',
#  'thought',
#  'it',
#  'over',
#  'afterwards,',
#  'it',
#  'occurred',
#  'to',
#  'her',
#  'that',
#  'she',
#  'ought',
#  'to',
#  'have',
#  'wondered',
#  'at',
#  'this,',
#  'but',
#  'at',
#  'the',
#  'time',
#  'it',
#  'all',
#  'seemed',
#  'quite',
#  'natural);',
#  'but',
#  'when',
#  'the',
#  'Rabbit',
#  'actually',
#  'TOOK',
#  'A',
#  'WATCH',
#  'OUT',
#  'OF',
#  'ITS',
#  'WAISTCOAT-',
#  'POCKET,',
#  'and',
#  'looked',
#  'at',
#  'it,',
#  'and',
#  'then',
#  'hurried',
#  'on,',
#  'Alice',
#  'started',
#  'to',
#  'her',
#  'feet,',
#  'for',
#  'it',
#  'flashed',
#  'across',
#  'her',
#  'mind',
#  'that',
#  'she',
#  'had',
#  'never',
#  'before',
#  'seen',
#  'a',
#  'rabbit',
#  'with',
#  'either',
#  'a',
#  'waistcoat-pocket,',
#  'or',
#  'a',
#  'watch',
#  'to',
#  'take',
#  'out',
#  'of',
#  'it,',
#  'and',
#  'burning',
#  'with',
#  'curiosity,',
#  'she',
#  'ran',
#  'across',
#  'the',
#  'field',
#  'after',
#  'it,',
#  'and',
#  'fortunately',
#  'was',
#  'just',
#  'in',
#  'time',
#  'to',
#  'see',
#  'it',
#  'pop',
#  'down',
#  'a',
#  'large',
#  'rabbit-hole',
#  'under',
#  'the',
#  'hedge.']

# %% [markdown]
# ## Baixando páginas da Web
#
# A parte realmente legal de trabalharmos com dados da Internet é extrair informações das páginas da Web. Será que podemos utilizar a biblioteca **requests** para baixar conteúdos de páginas Web?
#
# Vamos ver um primeiro exemplo:
#
# **Dica**: copie a URL e cole em seu navegador para ver o conteúdo da página renderizado!

# %%
url = 'https://atd-insper.s3.us-east-2.amazonaws.com/aula04/amostra.html'

resposta = requests.get(url = url, )
resposta.encoding = "utf-8"

resposta
# Out:
# <Response [200]>

# %% [markdown]
# Conferindo o código de resposta:

# %%
print('Código de status da resposta: {}'.format(req.status_code))
# Out:
# Código de status da resposta: 200

# %% [markdown]
# E o texto de resposta:

# %%
print('Texto de resposta:')
print(resposta.text)
# Out:
# Texto de resposta:
# <!DOCTYPE html>
# <html>
#     <head>
#         <meta charset="UTF-8">
#         <title>Este é o título da página!</title>
#     </head>
#
#     <body>
#
#         <h1>Este é um exemplo de página Web!</h1>
#
#         <p>Estamos utilizando HTML, que é uma linguagem de <b>Marcação</b> de <i>texto</i></p>
#
#         <h2>Este é um cabeçalho</h2>
#
#         <p>E este é um parágrafo.</p>
#
#         <p>Link para o <a href="https://www.google.com">Google</a></p>
#     </body>
# </html>

# %% [markdown]
# Perceberam que alguns caracteres ficaram "estranhos"?!
#
# Vamos conferir o **encoding** utilizado

# %%
resposta.encoding
# Out:
# 'utf-8'

# %% [markdown]
# Vamos alterar o **encoding**

# %%
# Preencha aqui!

# %% [markdown]
# e rever o texto de resposta

# %%
print('Texto de resposta:')
# Preencha aqui!

# %% [markdown]
# Este conteúdo é um **HTML** (do inglês *HyperText Markup Language*). Na próxima aula, iremos aprender como extrair informações úteis de páginas HTML.
#
# Vamos conferir outra página mais completa?! Faremos a requisição da página de notícias de Ciência da Exame https://exame.com/ciencia/

# %%
resposta = requests.get(url = 'https://exame.com/ciencia/')

print(resposta.text)
# Out:
# <!DOCTYPE html><html lang="pt-br"><head><meta charSet="utf-8"/><title>Ciência | Exame | Descobertas da Ciência que estão ampliando o Conhecimento da Humanidade e transformando vidas. ✅ ✚ O canal que você conhece e Confia! ➤ Acesse!</title><meta name="description" content="Descobertas da Ciência que estão ampliando o Conhecimento da Humanidade e transformando vidas. ✅ ✚ O canal que você conhece e Confia! ➤ Acesse!"/><meta property="og:title" content="Ciência | Exame | Descobertas da Ciência que estão ampliando o Conhecimento da Humanidade e transformando vidas. ✅ ✚ O canal que você conhece e Confia! ➤ Acesse!"/><meta property="og:description" content="Ciência | Exame | Descobertas da Ciência que estão ampliando o Conhecimento da Humanidade e transformando vidas. ✅ ✚ O canal que você conhece e Confia! ➤ Acesse!"/><meta property="og:image" content="https://exame.com/images/exame.svg"/><meta property="twitter:image" content="https://exame.com/images/exame.svg"/><meta name="twitter:text:title" content="Ciência"/><link rel="preload" href="https://classic.exame.com/wp-content/uploads/2023/03/urn_newsml_afp.com_20230302_a376e5c0-17de-4ec0-83f4-752a17ca3db5_ipad.jpg?quality=70&amp;strip=info&amp;w=1024" as="image"/><link rel="canonical" href="https://exame.com/ciencia/"/><script>dataLayer = [{"page_type":"Category_Page","product_id":"exame","category_id":3213,"category":"Ciência"}];</script><script type="application/ld+json">{"@context":"https://schema.org/","@type":"WebPage","name":"Ciência","description":"Descobertas da Ciência que estão ampliando o Conhecimento da Humanidade e transformando vidas. ✅ ✚ O canal que você conhece e Confia! ➤ Acesse!","url":"https://exame.com/ciencia/","publisher":{"@type":"Organization","logo":"https://exame.com/images/exame.svg","name":"Exame.com"}}</script><meta name="viewport" content="width=device-width, initial-scale=1.0"/><meta property="og:url" content="https://exame.com/"/><meta property="og:site_name" content="Exame"/><meta property="og:locale" content="pt-br"/><meta name="twitter:site" content="@exame"/><meta name="twitter:creator" content="@exame"/><link rel="icon" type="image/x-icon" href="/favicon.ico"/><link rel="dns-prefetch" href="https://exame.com/"/><link rel="dns-prefetch" href="https://classic.exame.com/"/><link rel="dns-prefetch" href="https://cdn.segment.com/"/><link rel="dns-prefetch" href="https://tag.goadopt.io/"/><link rel="dns-prefetch" href="https://static.criteo.net/"/><link rel="dns-prefetch" href="https://gum.criteo.com/"/><link rel="dns-prefetch" href="https://www.google.com"/><link rel="dns-prefetch" href="https://pagead2.googlesyndication.com"/><link rel="dns-prefetch" href="https://securepubads.g.doubleclick.net" crossorigin="true"/><link rel="dns-prefetch" href="https://securepubads.g.doubleclick.net"/><link rel="dns-prefetch" href="https://cm.g.doubleclick.net"/><link rel="dns-prefetch" href="https://tpc.googlesyndication.com"/><link rel="dns-prefetch" href="https://www.googletagservices.com"/><link rel="dns-prefetch" href="https://www.googletagmanager.com" crossorigin="true"/><link rel="dns-prefetch" href="https://www.googletagmanager.com"/><link rel="dns-prefetch" href="https://www.googleadservices.com"/><link rel="dns-prefetch" href="https://www.google-analytics.com"/><link rel="dns-prefetch" href="https://www.googleads.g.doubleclick.net/"/><link rel="dns-prefetch" href="https://fonts.googleapis.com"/><link rel="dns-prefetch" href="https://connect.facebook.net"/><link rel="dns-prefetch" href="https://tag.navdmp.com"/><link rel="dns-prefetch" href="https://maps.googleapis.com"/><link rel="dns-prefetch" href="https://stats.g.doubleclick.net"/><link rel="dns-prefetch" href="https://adservice.google.com.br"/><link rel="dns-prefetch" href="https://a.teads.tv"/><link rel="dns-prefetch" href="https://sb.scorecardresearch.com"/><link rel="dns-prefetch" href="sdk.mrf.io"/><link rel="preload" href="/images/exame.svg" as="image"/><link rel="preload" href="/images/logo-exame- ...
#   fill: currentColor;
#   width: 1em;
#   height: 1em;
#   display: inline-block;
#   font-size: 1.5rem;
#   transition: fill 200ms cubic-bezier(0.4, 0, 0.2, 1) 0ms;
#   flex-shrink: 0;
#   user-select: none;
# }
# .MuiSvgIcon-colorPrimary {
#   color: #3f51b5;
# }
# .MuiSvgIcon-colorSecondary {
#   color: #f50057;
# }
# .MuiSvgIcon-colorAction {
#   color: rgba(0, 0, 0, 0.54);
# }
# .MuiSvgIcon-colorError {
#   color: #f44336;
# }
# .MuiSvgIcon-colorDisabled {
#   color: rgba(0, 0, 0, 0.26);
# }
# .MuiSvgIcon-fontSizeInherit {
#   font-size: inherit;
# }
# .MuiSvgIcon-fontSizeSmall {
#   font-size: 1.25rem;
# }
# .MuiSvgIcon-fontSizeLarge {
#   font-size: 2.1875rem;
# }
# .MuiAvatar-root {
#   width: 40px;
#   height: 40px;
#   display: flex;
#   overflow: hidden;
#   position: relative;
#   font-size: 1.25rem;
#   align-items: center;
#   flex-shrink: 0;
#   font-family: "Roboto", "Helvetica", "Arial", sans-serif;
#   line-height: 1;
#   user-select: none;
#   border-radius: 50%;
#   justify-content: center;
# }
# .MuiAvatar-colorDefault {
#   color: #fafafa;
#   background-color: #bdbdbd;
# }
# .MuiAvatar-rounded {
#   border-radius: 4px;
# }
# .MuiAvatar-square {
#   border-radius: 0;
# }
# .MuiAvatar-img {
#   color: transparent;
#   width: 100%;
#   height: 100%;
#   object-fit: cover;
#   text-align: center;
#   text-indent: 10000px;
# }
# .MuiAvatar-fallback {
#   width: 75%;
#   height: 75%;
# }</style><style data-styled="" data-styled-version="5.3.5">html,body,div,span,applet,object,iframe,h1,h2,h3,h4,h5,h6,p,blockquote,pre,a,abbr,acronym,address,big,cite,code,del,dfn,em,img,ins,kbd,q,s,samp,small,strike,strong,sub,sup,tt,var,b,u,i,center,dl,dt,dd,menu,ol,ul,li,fieldset,form,label,legend,table,caption,tbody,tfoot,thead,tr,th,td,article,aside,canvas,details,embed,figure,figcaption,footer,header,hgroup,main,menu,nav,output,ruby,section,summary,time,mark,audio,video{margin:0;padding:0;border:0;font-size:100%;font:inherit;vertical-align:baseline;}/*!sc*/
# article,aside,details,figcaption,figure,footer,header,hgroup,main,menu,nav,section{display:block;}/*!sc*/
# *[hidden]{display:none;}/*!sc*/
# body{line-height:1;}/*!sc*/
# menu,ol,ul{list-style:none;}/*!sc*/
# blockquote,q{quotes:none;}/*!sc*/
# blockquote:before,blockquote:after,q:before,q:after{content:'';content:none;}/*!sc*/
# table{border-collapse:collapse;border-spacing:0;}/*!sc*/
# html,body{box-sizing:border-box;font-family:'Barlow',sans-serif;font-weight:400;font-size:20px;line-height:30px;color:#000;}/*!sc*/
# body{overflow-x:hidden;}/*!sc*/
# main{min-height:calc(100vh - 201px);}/*!sc*/
# *{margin:0;-webkit-transition:0.25s;-moz-transition:0.25s;-o-transition:0.25s;-ms-transition:0.25s;-webkit-transition:0.25s;transition:0.25s;}/*!sc*/
# *:hover{-webkit-transition:0.2s;-moz-transition:0.2s;-o-transition:0.2s;-ms-transition:0.2s;-webkit-transition:0.2s;transition:0.2s;}/*!sc*/
# button,a{cursor:pointer;outline:none;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# button.touch-increase,a.touch-increase{position:relative;margin-left:3px;}/*!sc*/
# button.touch-increase:after,a.touch-increase:after{z-index:1;padding:1.2em;margin:-1.2em;}/*!sc*/
# button.touch-increase:after,a.touch-increase:after,button.touch-area:after,a.touch-area:after{content:'';display:inline-block;position:absolute;top:0;left:0;right:0;bottom:0;}/*!sc*/
# article{-webkit-flex:74%;-ms-flex:74%;flex:74%;margin:40px 1% 40px 0;border-radius:6px;}/*!sc*/
# image{width:100%;}/*!sc*/
# .align-center{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .container{max-width:1024px;margin:0 auto;height:100%;position:relative;}/*!sc*/
# .container-fluid{max-width:1100px;margin:0 auto;height:100%;position:relative;}/*!sc*/
# .container-bg{background:#fff;padding:0 15px 15px 15px;border-radius:8px;}/*!sc*/
# .container.container-bg{max-width:1054px;}/*!sc*/
# .row{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}/*!sc*/
# .row-centered{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}/*!sc*/
# .row-default{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;}/*!sc*/
# main .container .row{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# .rowHeader{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}/*!sc*/
# .column-centered{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .navHeight{height:100%;}/*!sc*/
# .cursorPointer{cursor:pointer;}/*!sc*/
# .tradingview-widget-container{width:100%;margin-top:20px;}/*!sc*/
# .mobile-only{display:none;}/*!sc*/
# .ad-mobile-fixed-button{position:fixed;bottom:70px;left:0;z-index:10;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding:10px;border:0;background-color:#F5F5F7;display:none;}/*!sc*/
# .ad-mobile-fixed-button svg{font-size:14px;color:#000;}/*!sc*/
# .icon-blink{vertical-align:middle;-webkit-animation:blink 1.7s ease-in infinite;animation:blink 1.7s ease-in infinite;}/*!sc*/
# @-webkit-keyframes blink{from,to{opacity:1;}50%{opacity:0;}}/*!sc*/
# @keyframes blink{from,to{opacity:1;}50%{opacity:0;}}/*!sc*/
# @-webkit-keyframes fadeIn{from{opacity:0;}to{opacity:1;}}/*!sc*/
# @keyframes fadeIn{from{opacity:0;}to{opacity:1;}}/*!sc*/
# #home-native-ad-1,#home-native-ad-2,#home-native-ad-3{min-width:328px;}/*!sc*/
# #native-home-4,#native-home-5{background-color:#F5F5F7;border-radius:8px;width:100%;}/*!sc*/
# .anchor-ad{width:100%;height:90px;min-height:90px;background:#F5F5F7;}/*!sc*/
# .anchor-button{width:40px;height:40px;position:absolute;bottom:90px;left:0;z-index:8;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding:10px;border:0;background-color:#F5F5F7;}/*!sc*/
# .anchor-button svg{font-size:14px;color:#000;}/*!sc*/
# [id*="anchor_0"] svg{cursor:pointer;}/*!sc*/
# @media screen and (max-width:768px){.container{padding:0 16px;}.container-fluid{padding:0 0.5rem;}.desktop-only{display:none;}.mobile-only{display:block;}div.ad-keep-reading{width:100%;position:relative;}div.ad-keep-reading::before{content:'CONTINUA APÓS PUBLICIDADE';line-height:1;display:block;font-size:12px;position:absolute;left:50%;-webkit-transform:translateX(-50%);-ms-transform:translateX(-50%);transform:translateX(-50%);top:-20px;}.web-only{display:none;}.ad-mobile-fixed{position:fixed;z-index:10;bottom:0;margin:0;left:0;}.ad-mobile-fixed.small-container{margin:0;}.ad-mobile-fixed-button{display:block;}.anchor-button{display:none;}#adopt-controller-button{bottom:80px;right:10px;}}/*!sc*/
# @media screen and (max-width:1024px){.container{padding:0 16px;}}/*!sc*/
# @media screen and (max-width:850px){.mobile_reverse{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column-reverse;-ms-flex-direction:column-reverse;flex-direction:column-reverse;}}/*!sc*/
# data-styled.g2[id="sc-global-bGjHzo1"]{content:"sc-global-bGjHzo1,"}/*!sc*/
# .dgUMVE{font-family:'Poppins',sans-serif;color:#0f1923;font-weight:700;margin-bottom:25px;margin-top:px;font-size:32px;line-height:30px;}/*!sc*/
# @media screen and (max-width:768px){.dgUMVE{font-size:undefinedpx;line-height:undefinedpx;}}/*!sc*/
# data-styled.g21[id="sc-3bc294c4-0"]{content:"dgUMVE,"}/*!sc*/
# .hVpNtt{font-family:'Poppins',sans-serif;color:#0f1923;font-weight:800;font-size:24px;line-height:35px;margin-bottom:px;margin-top:px;}/*!sc*/
# @media screen and (max-width:768px){.hVpNtt{font-size:24px;line-height:28px;}}/*!sc*/
# @media screen and (max-width:576px){.hVpNtt{font-size:18px;}}/*!sc*/
# .iRPgSO{font-family:'Poppins',sans-serif;color:#0f1923;font-weight:800;font-size:16px;line-height:22px;margin-bottom:px;margin-top:px;}/*!sc*/
# @media screen and (max-width:768px){.iRPgSO{font-size:24px;line-height:28px;}}/*!sc*/
# @media screen and (max-width:576px){.iRPgSO{font-size:18px;}}/*!sc*/
# .dMQsGw{font-family:'Poppins',sans-serif;color:#0f1923;font-weight:800;font-size:18px;line-height:px;margin-bottom:px;margin-top:px;}/*!sc*/
# @media screen and (max-width:768px){.dMQsGw{font-size:24px;line-height:28px;}}/*!sc*/
# @media screen and (max-width:576px){.dMQsGw{font-size:18px;}}/*!sc*/
# data-styled.g22[id="sc-3bc294c4-1"]{content:"hVpNtt,iRPgSO,dMQsGw,"}/*!sc*/
# .gEIxfM{height:0;overflow:hidden;padding-top:56.2500000%;position:relative;border-radius:undefined;min-width:0;}/*!sc*/
# .evjciX{height:0;overflow:hidden;padding-top:100%;position:relative;border-radius:undefined;min-width:0;}/*!sc*/
# data-styled.g27[id="sc-60625158-0"]{content:"gEIxfM,evjciX,"}/*!sc*/
# .hoZzyj{background:#f5f5f7;background-color:undefined;width:100%;height:250px;margin:20px 0;padding:25px 10px;border-radius:8px;text-align:center;z-index:8;}/*!sc*/
# @media screen and (max-width:768px){.hoZzyj.only-web{display:none;}}/*!sc*/
# .hoZzyj.only-mobile{display:none;}/*!sc*/
# .hoZzyj.hide-mobile{display:block;}/*!sc*/
# @media screen and (max-width:768px){.hoZzyj{margin:40px 0;border-radius:0;height:auto;}.hoZzyj::after{display:none;}.hoZzyj.small-container{height:auto;}.hoZzyj.big-container{height:auto;}.hoZzyj.hide-mobile{display:none;}.hoZzyj.only-mobile{display:block;}}/*!sc*/
# .ftBHyl{background:#f5f5f7;background-color:undefined;width:100%;height:270px;margin:20px 0;padding:25px 10px;border-radius:8px;text-align:center;z-index:8;}/*!sc*/
# @media screen and (max-width:768px){.ftBHyl.only-web{display:none;}}/*!sc*/
# .ftBHyl.only-mobile{display:none;}/*!sc*/
# .ftBHyl.hide-mobile{display:block;}/*!sc*/
# @media screen and (max-width:768px){.ftBHyl{margin:40px 0;border-radius:0;height:auto;}.ftBHyl::after{display:none;}.ftBHyl.small-container{height:auto;}.ftBHyl.big-container{height:auto;}.ftBHyl.hide-mobile{display:none;}.ftBHyl.only-mobile{display:block;}}/*!sc*/
# .cAWHyg{background:#f5f5f7;background-color:undefined;width:calc(100% / 3 - 2em);height:calc(100%);margin:0 0 0 1em;padding:undefined;border-radius:8px;text-align:center;z-index:8;}/*!sc*/
# @media screen and (max-width:768px){.cAWHyg.only-web{display:none;}}/*!sc*/
# .cAWHyg.only-mobile{display:none;}/*!sc*/
# .cAWHyg.hide-mobile{display:block;}/*!sc*/
# @media screen and (max-width:768px){.cAWHyg{margin:40px 0;border-radius:0;height:auto;}.cAWHyg::after{display:none;}.cAWHyg.small-container{height:auto;}.cAWHyg.big-container{height:auto;}.cAWHyg.hide-mobile{display:none;}.cAWHyg.only-mobile{display:block;}}/*!sc*/
# data-styled.g32[id="sc-37813f0f-1"]{content:"hoZzyj,ftBHyl,cAWHyg,"}/*!sc*/
# .dYOAsd{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g42[id="sc-5076ec1d-0"]{content:"dYOAsd,"}/*!sc*/
# .klNVgk{color:#fff;outline:none;z-index:1;}/*!sc*/
# .emxhww{background-color:transparent;border:none;color:#fff;outline:none;z-index:1;}/*!sc*/
# .emJbaA{background-color:transparent;border:none;color:#222;outline:none;z-index:1;}/*!sc*/
# .glMxoD{background-color:transparent;border:none;color:#0C3CF8;outline:none;z-index:1;}/*!sc*/
# .caWWAI{background-color:transparent;border:none;color:#9AC85D;outline:none;z-index:1;}/*!sc*/
# .gwxZJV{background-color:transparent;border:none;color:#00AAEF;outline:none;z-index:1;}/*!sc*/
# .fdmtyA{background-color:transparent;border:none;color:#68B196;outline:none;z-index:1;}/*!sc*/
# data-styled.g43[id="sc-5076ec1d-1"]{content:"klNVgk,emxhww,emJbaA,glMxoD,caWWAI,gwxZJV,fdmtyA,"}/*!sc*/
# .jgTUPZ{padding:10px 20px;border-radius:30px;background-color:#ea2300;font-size:14px;font-family:Barlow,sans-serif;font-weight:600;-webkit-letter-spacing:0.06em;-moz-letter-spacing:0.06em;-ms-letter-spacing:0.06em;letter-spacing:0.06em;text-transform:uppercase;line-height:normal;}/*!sc*/
# .jgTUPZ:disabled{background-color:rgba(15,25,35,0.05);color:rgba(15,25,35,0.3);}/*!sc*/
# @media screen and (max-width:768px){.jgTUPZ{padding:10px 20px;}}/*!sc*/
# .dvApHz{padding:10px 20px;border-radius:30px;background-color:#ea2300;font-size:14px;font-family:Barlow,sans-serif;font-weight:600;-webkit-letter-spacing:0.06em;-moz-letter-spacing:0.06em;-ms-letter-spacing:0.06em;letter-spacing:0.06em;text-transform:uppercase;line-height:normal;margin:0 0 20px 0;}/*!sc*/
# .dvApHz:disabled{background-color:rgba(15,25,35,0.05);color:rgba(15,25,35,0.3);}/*!sc*/
# @media screen and (max-width:768px){.dvApHz{padding:10px 20px;}}/*!sc*/
# data-styled.g44[id="sc-5076ec1d-2"]{content:"jgTUPZ,dvApHz,"}/*!sc*/
# .jvjSEW{height:100%;font-size:15px;font-family:Arial;font-weight:600;color:#000;margin:30px;-webkit-letter-spacing:0.02em;-moz-letter-spacing:0.02em;-ms-letter-spacing:0.02em;letter-spacing:0.02em;text-transform:uppercase;}/*!sc*/
# .jvjSEW:hover{color:#ea2300;}/*!sc*/
# button.sc-5076ec1d-3{border:0;background:#00000000;}/*!sc*/
# @media screen and (max-width:768px){.jvjSEW{white-space:nowrap;padding:0;}}/*!sc*/
# data-styled.g45[id="sc-5076ec1d-3"]{content:"jvjSEW,"}/*!sc*/
# .fUSsig{width:100%;padding:10px 0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;font-size:16px;font-family:Poppins,sans-serif;font-weight:bold;}/*!sc*/
# .fUSsig:hover{color:#ea2300;}/*!sc*/
# @media screen and (max-width:768px){.fUSsig{white-space:nowrap;}}/*!sc*/
# .ekuaUy{width:100%;padding:10px 0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;font-size:16px;font-family:Poppins,sans-serif;font-weight:normal;}/*!sc*/
# .ekuaUy:hover{color:#ea2300;}/*!sc*/
# @media screen and (max-width:768px){.ekuaUy{white-space:nowrap;}}/*!sc*/
# data-styled.g47[id="sc-5076ec1d-5"]{content:"fUSsig,ekuaUy,"}/*!sc*/
# .jSxcbN{height:100%;-webkit-letter-spacing:0.02em;-moz-letter-spacing:0.02em;-ms-letter-spacing:0.02em;letter-spacing:0.02em;font-family:Poppins,sans-serif;font-size:18px;font-weight:bold;color:#222;margin:0px;}/*!sc*/
# .jSxcbN:hover{color:#ea2300;}/*!sc*/
# @media screen and (max-width:768px){.jSxcbN{white-space:nowrap;padding:0;}}/*!sc*/
# data-styled.g48[id="sc-5076ec1d-6"]{content:"jSxcbN,"}/*!sc*/
# .hHUOkY{background-color:transparent;border:none;padding:0;margin:0;line-height:0;}/*!sc*/
# data-styled.g49[id="sc-5076ec1d-7"]{content:"hHUOkY,"}/*!sc*/
# .dMkKfK{margin-top:24px;width:100%;height:100%;}/*!sc*/
# .dMkKfK.eleicoes-container{margin-top:0;}/*!sc*/
# .dMkKfK.gallery{position:relative;}/*!sc*/
# data-styled.g51[id="sc-4b483aaa-0"]{content:"dMkKfK,"}/*!sc*/
# .dOvApY{width:100%;padding-top:24px;border-top:2px solid #f1f1f2;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;margin-bottom:20px;}/*!sc*/
# @media screen and (max-width:768px){.dOvApY{margin-bottom:0;padding-top:16px;}.dOvApY h2{font-size:22px;line-height:33px;}}/*!sc*/
# .dOvApY .on_mobile_only_true{display:none;}/*!sc*/
# @media screen and (max-width:900px){.dOvApY .on_mobile_only_true{display:unset;}}/*!sc*/
# .dOvApY .title{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .dOvApY .title span{margin-right:8px !important;}/*!sc*/
# data-styled.g52[id="sc-4b483aaa-1"]{content:"dOvApY,"}/*!sc*/
# .eqaNXo{-webkit-flex:1;-ms-flex:1;flex:1;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;margin:0 0 20px 0;-webkit-column-count:3;column-count:3;-webkit-column-gap:1em;column-gap:1em;min-height:340px;min-height:340px;}/*!sc*/
# .eqaNXo > div{box-sizing:border-box;}/*!sc*/
# @media screen and (max-width:900px){.eqaNXo{min-height:auto;-webkit-column-count:1;column-count:1;margin:20px 0 0;-webkit-flex:auto;-ms-flex:auto;flex:auto;display:block;}.eqaNXo > div{height:auto;margin-bottom:1em;}}/*!sc*/
# .eqaNXo:empty{display:none;}/*!sc*/
# @media screen and (max-width:768px){.eqaNXo.scroll{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:stretch;-webkit-box-align:stretch;-ms-flex-align:stretch;align-items:stretch;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;gap:24px;overflow-x:auto;-webkit-scroll-snap-type:x mandatory;-moz-scroll-snap-type:x mandatory;-ms-scroll-snap-type:x mandatory;scroll-snap-type:x mandatory;width:100%;}}/*!sc*/
# .bpReYl{-webkit-flex:1;-ms-flex:1;flex:1;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;margin:0 0 20px 0;-webkit-column-count:2;column-count:2;-webkit-column-gap:1em;column-gap:1em;min-height:340px;min-height:340px;}/*!sc*/
# .bpReYl > div{box-sizing:border-box;}/*!sc*/
# @media screen and (max-width:900px){.bpReYl{min-height:auto;-webkit-column-count:1;column-count:1;margin:20px 0 0;-webkit-flex:auto;-ms-flex:auto;flex:auto;display:block;}.bpReYl > div{height:auto;margin-bottom:1em;}}/*!sc*/
# .bpReYl:empty{display:none;}/*!sc*/
# @media screen and (max-width:768px){.bpReYl.scroll{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:stretch;-webkit-box-align:stretch;-ms-flex-align:stretch;align-items:stretch;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;gap:24px;overflow-x:auto;-webkit-scroll-snap-type:x mandatory;-moz-scroll-snap-type:x mandatory;-ms-scroll-snap-type:x mandatory;scroll-snap-type:x mandatory;width:100%;}}/*!sc*/
# data-styled.g53[id="sc-4b483aaa-2"]{content:"eqaNXo,bpReYl,"}/*!sc*/
# .caSFzC{width:100%;margin:5px 0 20px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-column-gap:1em;column-gap:1em;}/*!sc*/
# .caSFzC > div{box-sizing:border-box;width:50%;min-height:100%;}/*!sc*/
# @media screen and (max-width:820px){.caSFzC > div{width:100%;min-height:auto;}}/*!sc*/
# @media screen and (max-width:820px){.caSFzC{margin:0 0 10px;display:block;}}/*!sc*/
# data-styled.g56[id="sc-4b483aaa-5"]{content:"caSFzC,"}/*!sc*/
# .hSMEbH{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;gap:1em;}/*!sc*/
# .hSMEbH > div{box-sizing:border-box;-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# @media screen and (max-width:820px){.hSMEbH{margin-top:1em;}}/*!sc*/
# @media screen and (min-width:1024px){.hSMEbH{gap:20px;max-height:572px;}}/*!sc*/
# data-styled.g57[id="sc-4b483aaa-6"]{content:"hSMEbH,"}/*!sc*/
# .jACWSN{margin:1em 0;width:100%;}/*!sc*/
# .jACWSN > .big-container{float:right;}/*!sc*/
# .jACWSN > div > div{margin-top:0;}/*!sc*/
# .jACWSN > div:last-child > div{margin-bottom:0;}/*!sc*/
# @media screen and (max-width:768px){.jACWSN{margin-bottom:0;}.jACWSN > .big-container{float:none;margin-bottom:42px;}}/*!sc*/
# data-styled.g61[id="sc-4b483aaa-10"]{content:"jACWSN,"}/*!sc*/
# .hglArh > .row > div{margin-top:0;}/*!sc*/
# data-styled.g63[id="sc-4b483aaa-12"]{content:"hglArh,"}/*!sc*/
# .hoRbDB{width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .hoRbDB svg{font-size:24px;}/*!sc*/
# .hoRbDB #clear{margin-right:16px;padding:2px 16px;border-right:1px solid #e1e1e1;-webkit-transition:all 0.9s ease 0s;transition:all 0.9s ease 0s;}/*!sc*/
# @media screen and (max-width:768px){.hoRbDB #clear{display:none;}}/*!sc*/
# data-styled.g149[id="sc-89b7573a-0"]{content:"hoRbDB,"}/*!sc*/
# .ZXSlP{font-family:'Barlow',sans-serif;font-size:20px;line-height:26px;-webkit-letter-spacing:0.01px;-moz-letter-spacing:0.01px;-ms-letter-spacing:0.01px;letter-spacing:0.01px;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;height:-webkit-fit-content;height:-moz-fit-content;height:fit-content;border:none;margin-left:16px;}/*!sc*/
# .ZXSlP:focus{outline:none;}/*!sc*/
# data-styled.g150[id="sc-89b7573a-1"]{content:"ZXSlP,"}/*!sc*/
# .hTQIUh span{display:block;text-indent:-99999px;white-space:nowrap;margin-top:-40px;overflow:hidden;}/*!sc*/
# .hTQIUh .img-wrapper{height:auto;}/*!sc*/
# .hTQIUh .logo-desktop{-webkit-transition:0.5s;transition:0.5s;}/*!sc*/
# .hTQIUh .logo-mobile{display:none;-webkit-transition:1s;transition:1s;}/*!sc*/
# .hTQIUh .fom .logo-desktop{-webkit-transition:1s;transition:1s;}/*!sc*/
# @media screen and (max-width:768px){.hTQIUh .logo-desktop{display:none;}.hTQIUh .logo-mobile{display:block;}}/*!sc*/
# data-styled.g151[id="sc-cce28851-0"]{content:"hTQIUh,"}/*!sc*/
# .cDaXMj{position:-webkit-sticky;position:-webkit-sticky;position:sticky;top:0;z-index:10;height:66px;-webkit-transform:translate3d(0px,-0%,0px);-ms-transform:translate3d(0px,-0%,0px);transform:translate3d(0px,-0%,0px);-webkit-transition:all 0.9s ease 0s;transition:all 0.9s ease 0s;background-color:#ffffff;-moz-box-shadow:unset;-webkit-box-shadow:unset;box-shadow:unset;overflow-y:hidden;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}/*!sc*/
# .cDaXMj:hover{-webkit-transform:unset;-ms-transform:unset;transform:unset;}/*!sc*/
# .cDaXMj img{margin-bottom:-4px !important;}/*!sc*/
# data-styled.g159[id="sc-5c6b99ad-0"]{content:"cDaXMj,"}/*!sc*/
# .ifzDlj{width:100%;padding:0 72px;max-width:1296px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;overflow:hidden;}/*!sc*/
# @media screen and (max-width:820px){.ifzDlj{padding:0 16px;}}/*!sc*/
# data-styled.g160[id="sc-5c6b99ad-1"]{content:"ifzDlj,"}/*!sc*/
# .cgHmZJ{width:100%;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;white-space:nowrap;overflow:hidden;}/*!sc*/
# .cgHmZJ button{height:auto;padding:10px 0;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# @media screen and (max-width:420px){.cgHmZJ button{padding:10px;font-size:15px;}}/*!sc*/
# data-styled.g161[id="sc-5c6b99ad-2"]{content:"cgHmZJ,"}/*!sc*/
# .gnhQNN{width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-transition:all 0.3s ease 0s;transition:all 0.3s ease 0s;-webkit-transform:translate3d(-0%,0px,0px);-ms-transform:translate3d(-0%,0px,0px);transform:translate3d(-0%,0px,0px);}/*!sc*/
# @media screen and (max-width:850px){.gnhQNN li.desktop_only{display:none;}}/*!sc*/
# data-styled.g162[id="sc-5c6b99ad-3"]{content:"gnhQNN,"}/*!sc*/
# .cKjumI{background-color:#FFFFFF;float:left;width:100%;padding:28px 0 8px;position:absolute;z-index:9;}/*!sc*/
# @media screen and (max-width:768px){.cKjumI{padding:8px 0;}}/*!sc*/
# data-styled.g163[id="sc-b5c61edd-0"]{content:"cKjumI,"}/*!sc*/
# .hKdErk{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# @media screen and (max-width:768px){.hKdErk{padding:10px 0;}}/*!sc*/
# data-styled.g164[id="sc-b5c61edd-1"]{content:"hKdErk,"}/*!sc*/
# .bnSqjB{margin:0 10px;}/*!sc*/
# @media screen and (max-width:768px){.bnSqjB{margin:0 7px;}}/*!sc*/
# .bnSqjB a{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-color:#f1f1f2;border-radius:50%;color:#0F1923;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;height:32px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;width:32px;}/*!sc*/
# .bnSqjB svg{font-size:20px;}/*!sc*/
# data-styled.g165[id="sc-b5c61edd-2"]{content:"bnSqjB,"}/*!sc*/
# .iSbXAo{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding:0 0 5px 0;}/*!sc*/
# .iSbXAo a{font-size:14px;font-weight:bold;color:#000000;-webkit-letter-spacing:0.02em;-moz-letter-spacing:0.02em;-ms-letter-spacing:0.02em;letter-spacing:0.02em;text-transform:uppercase;margin:0 8px;}/*!sc*/
# .iSbXAo a:hover{color:#ea2300;cursor:pointer;}/*!sc*/
# .iSbXAo a:first-child{margin:0 8px 0 0;}/*!sc*/
# .iSbXAo button{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;background:none;border:0;padding:0;margin:0 0 0 8px;}/*!sc*/
# .iSbXAo button p{font-size:14px;font-weight:bold;font-family:'Barlow',sans-serif;-webkit-letter-spacing:0.02em;-moz-letter-spacing:0.02em;-ms-letter-spacing:0.02em;letter-spacing:0.02em;text-transform:uppercase;}/*!sc*/
# .iSbXAo button svg{font-size:18px;}/*!sc*/
# @media screen and (max-width:768px){.iSbXAo{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;padding:10px 0;}.iSbXAo button{margin:0;}}/*!sc*/
# data-styled.g166[id="sc-b5c61edd-3"]{content:"iSbXAo,"}/*!sc*/
# .gqa-DaL{font-size:12px;font-weight:500;}/*!sc*/
# data-styled.g167[id="sc-b5c61edd-4"]{content:"gqa-DaL,"}/*!sc*/
# .cWzeax{border:1px solid #f1f1f2;margin:10px 0;}/*!sc*/
# data-styled.g168[id="sc-b5c61edd-5"]{content:"cWzeax,"}/*!sc*/
# .fbQUtB{font-size:18px;font-weight:500;}/*!sc*/
# data-styled.g169[id="sc-b5c61edd-6"]{content:"fbQUtB,"}/*!sc*/
# .chgGBN{width:100%;}/*!sc*/
# .chgGBN ul{display:grid;grid-template-columns:repeat(4,1fr);gap:0.5em;}/*!sc*/
# .chgGBN a{font-size:14px;font-weight:normal;-webkit-letter-spacing:0.02em;-moz-letter-spacing:0.02em;-ms-letter-spacing:0.02em;letter-spacing:0.02em;text-transform:none;margin:0;}/*!sc*/
# .chgGBN a:hover{color:#ea2300;}/*!sc*/
# .chgGBN summary{display:none;}/*!sc*/
# data-styled.g170[id="sc-b5c61edd-7"]{content:"chgGBN,"}/*!sc*/
# .jWcTMF{border:1px solid #f5f5f7;border-radius:8px;color:#0f1923;position:relative;-webkit-transition:border-color ease 0.2s;transition:border-color ease 0.2s;background-color:#fff;}/*!sc*/
# .jWcTMF:hover{border:1px solid #1119221a;}/*!sc*/
# .jWcTMF a,.jWcTMF h2,.jWcTMF h3,.jWcTMF h4{color:#0f1923;}/*!sc*/
# .jWcTMF a:hover{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .jWcTMF img{border-radius:8px 8px 0 0;}/*!sc*/
# .jWcTMF img.rounded{border-radius:8px;}/*!sc*/
# data-styled.g235[id="sc-ba826335-0"]{content:"jWcTMF,"}/*!sc*/
# .ckjnLv{background-color:transparent;border:1px solid transparent;border-color:#f5f5f7;height:100%;width:100%;}/*!sc*/
# @media screen and (max-width:820px){.ckjnLv{height:auto;}}/*!sc*/
# .ckjnLv.edicoes-card img{border-radius:8px;}/*!sc*/
# @media screen and (max-width:820px){.ckjnLv.edicoes-card{height:276px;}}/*!sc*/
# .ckjnLv.card-newsletter-home{padding-top:24px;}/*!sc*/
# @media screen and (max-width:900px){.ckjnLv .live_blog_content{position:relative;bottom:70px;margin:0 0 -70px 0;}}/*!sc*/
# @media screen and (max-width:900px){.ckjnLv .live_blog_img_true{-webkit-filter:brightness(0.6);filter:brightness(0.6);}}/*!sc*/
# .ckjnLv .election_true span{display:unset;}/*!sc*/
# .gpXvGI{background-color:transparent;border:1px solid transparent;border-color:#f5f5f7;height:auto;width:100%;}/*!sc*/
# @media screen and (max-width:820px){.gpXvGI{height:auto;}}/*!sc*/
# .gpXvGI.edicoes-card img{border-radius:8px;}/*!sc*/
# @media screen and (max-width:820px){.gpXvGI.edicoes-card{height:276px;}}/*!sc*/
# .gpXvGI.card-newsletter-home{padding-top:24px;}/*!sc*/
# @media screen and (max-width:900px){.gpXvGI .live_blog_content{position:relative;bottom:70px;margin:0 0 -70px 0;}}/*!sc*/
# @media screen and (max-width:900px){.gpXvGI .live_blog_img_true{-webkit-filter:brightness(0.6);filter:brightness(0.6);}}/*!sc*/
# .gpXvGI .election_true span{display:unset;}/*!sc*/
# data-styled.g236[id="sc-ba826335-1"]{content:"ckjnLv,gpXvGI,"}/*!sc*/
# .drXBrp{height:100%;width:502px;}/*!sc*/
# @media screen and (max-width:576px){.drXBrp{height:auto;}}/*!sc*/
# @media screen and (min-width:576px) and (max-width:1024px){.drXBrp{height:100%;}}/*!sc*/
# @media screen and (max-width:1024px){.drXBrp{width:auto;}}/*!sc*/
# @media screen and (min-width:821px){.drXBrp{min-height:139px;display:grid;grid-template-columns:154px auto;}.drXBrp img{border-radius:8px 0 0 8px;}}/*!sc*/
# data-styled.g241[id="sc-ba826335-6"]{content:"drXBrp,"}/*!sc*/
# .hYxKbN{padding-top:56.25%;background:#eee;}/*!sc*/
# @media screen and (min-width:820px){.hYxKbN{height:auto;}}/*!sc*/
# @media screen and (max-width:820px){.hide-img-on-mobile .sc-ba826335-7{display:none;}}/*!sc*/
# data-styled.g242[id="sc-ba826335-7"]{content:"hYxKbN,"}/*!sc*/
# .krrkKB{padding:16px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# .krrkKB .icon{border-radius:0;}/*!sc*/
# @media screen and (max-width:900px){.krrkKB .live_blog_content{bottom:60px;}}/*!sc*/
# .kKBPho{padding:16px;display:undefined;-webkit-flex-direction:undefined;-ms-flex-direction:undefined;flex-direction:undefined;}/*!sc*/
# .kKBPho .icon{border-radius:0;}/*!sc*/
# @media screen and (max-width:900px){.kKBPho .live_blog_content{bottom:60px;}}/*!sc*/
# data-styled.g250[id="sc-ba826335-15"]{content:"krrkKB,kKBPho,"}/*!sc*/
# .gpDcsB{font:normal normal 800 12px/14px 'Barlow', sans-serif;text-transform:uppercase;margin-bottom:0;-webkit-letter-spacing:0.2px;-moz-letter-spacing:0.2px;-ms-letter-spacing:0.2px;letter-spacing:0.2px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;color:#0f1923;}/*!sc*/
# .gpDcsB a{font-weight:800;color:#0f1923;}/*!sc*/
# data-styled.g252[id="sc-ba826335-17"]{content:"gpDcsB,"}/*!sc*/
# .hNdlTx{color:#0f1923;font:normal normal normal 12px/14px 'Barlow',sans-serif;opacity:0.7;-webkit-letter-spacing:0.02px;-moz-letter-spacing:0.02px;-ms-letter-spacing:0.02px;letter-spacing:0.02px;color:#111922;margin-bottom:8px;}/*!sc*/
# data-styled.g253[id="sc-ba826335-18"]{content:"hNdlTx,"}/*!sc*/
# .eIHFsl{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .eIHFsl > div{margin:0 5.22px 4px 0 !important;display:none !important;}/*!sc*/
# .eIHFsl > span{margin:0 5.22px 4px 0 !important;}/*!sc*/
# data-styled.g254[id="sc-ba826335-19"]{content:"eIHFsl,"}/*!sc*/
# .bRZbSZ{font-family:'Poppins',sans-serif;font-size:20px;line-height:30px;color:#0f1923;margin-top:8px;}/*!sc*/
# .bRZbSZ.highlight-dotted{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# @media screen and (min-width:820px){.bRZbSZ{display:-webkit-box;-webkit-line-clamp:3;-webkit-box-orient:vertical;overflow:hidden;text-overflow:ellipsis;}}/*!sc*/
# @media screen and (max-width:576px){.bRZbSZ{display:none;}}/*!sc*/
# data-styled.g255[id="sc-ba826335-20"]{content:"bRZbSZ,"}/*!sc*/
# .ccjlHJ{position:fixed;top:0;left:0;width:100%;height:100%;background-color:rgba(0,0,0,0.8);z-index:25;-webkit-transition:all 0.25s ease-in-out 0s;transition:all 0.25s ease-in-out 0s;opacity:0;pointer-events:none;}/*!sc*/
# data-styled.g295[id="sc-ebefef86-0"]{content:"ccjlHJ,"}/*!sc*/
# .gIFJIp{position:fixed;top:0;left:0;width:320px;height:100%;z-index:26;background-color:#fff;border-radius:0px 8px 8px 0px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;overflow-x:hidden;-webkit-transform:translateX(-100%);-ms-transform:translateX(-100%);transform:translateX(-100%);-webkit-transition:all 0.5s ease 0s;transition:all 0.5s ease 0s;}/*!sc*/
# .gIFJIp::-webkit-scrollbar{width:5px;}/*!sc*/
# .gIFJIp::-webkit-scrollbar-thumb{height:20px !important;border-radius:10px;background-color:rgba(0,0,0,0.3);}/*!sc*/
# .gIFJIp a{color:#222;}/*!sc*/
# .gIFJIp a:hover{color:#ea2300;}/*!sc*/
# @media screen and (max-width:768px){.gIFJIp{width:100%;border-radius:0;}}/*!sc*/
# @media screen and (min-width:768px){.gIFJIp #mobile-search{display:none;}}/*!sc*/
# data-styled.g296[id="sc-ebefef86-1"]{content:"gIFJIp,"}/*!sc*/
# .SpeSZ{display:grid;grid-template-columns:1fr 1fr 1fr;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-bottom:1px solid #f1f1f2;padding:21px 16px;}/*!sc*/
# .SpeSZ div{width:141px;height:24px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}/*!sc*/
# .SpeSZ button{border:none;outline:none;background:none;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;}/*!sc*/
# .SpeSZ svg{fill:#222;}/*!sc*/
# @media screen and (min-width:768px){.SpeSZ{display:none;}}/*!sc*/
# data-styled.g297[id="sc-ebefef86-2"]{content:"SpeSZ,"}/*!sc*/
# .geeaEm{width:100%;padding:25px 16px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;}/*!sc*/
# @media screen and (max-width:768px){.geeaEm{padding:0 0 16px 16px;}}/*!sc*/
# data-styled.g298[id="sc-ebefef86-3"]{content:"geeaEm,"}/*!sc*/
# .ePqbPQ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;text-align:left;margin-left:16px;line-height:21px;}/*!sc*/
# .ePqbPQ strong{font-size:16px;font-family:'Poppins',sans-serif;font-weight:bold;}/*!sc*/
# .ePqbPQ p{font-size:16px;font-family:'Barlow',sans-serif;}/*!sc*/
# .ePqbPQ a{color:#222;}/*!sc*/
# .ePqbPQ a:hover{color:#ea2300;}/*!sc*/
# data-styled.g299[id="sc-ebefef86-4"]{content:"ePqbPQ,"}/*!sc*/
# .hFSicf{width:90%;padding:0 5%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .hFSicf a,.hFSicf button{width:100%;color:#fff;text-align:center;}/*!sc*/
# .hFSicf a:hover,.hFSicf button:hover{color:#fff;}/*!sc*/
# data-styled.g301[id="sc-ebefef86-6"]{content:"hFSicf,"}/*!sc*/
# .llYvgd{display:contents;overflow:auto;}/*!sc*/
# .llYvgd::-webkit-scrollbar{width:5px;}/*!sc*/
# .llYvgd::-webkit-scrollbar-thumb{height:20px !important;border-radius:10px;background-color:rgba(0,0,0,0.3);}/*!sc*/
# data-styled.g302[id="sc-ebefef86-7"]{content:"llYvgd,"}/*!sc*/
# .wDCpi{border-top:1px solid #f1f1f2;padding:24px 16px;}/*!sc*/
# data-styled.g303[id="sc-ebefef86-8"]{content:"wDCpi,"}/*!sc*/
# .kieiAN{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;}/*!sc*/
# data-styled.g304[id="sc-ebefef86-9"]{content:"kieiAN,"}/*!sc*/
# .ezueNt{width:100%;font:normal normal normal 18px/25px Poppins;padding:0;}/*!sc*/
# .ezueNt + li{margin-top:24px;}/*!sc*/
# .ezueNt button{padding:0;}/*!sc*/
# data-styled.g305[id="sc-ebefef86-10"]{content:"ezueNt,"}/*!sc*/
# .search{position:absolute;width:100%;z-index:2;background:#fff;height:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-transition:all 0.3s ease-out;transition:all 0.3s ease-out;}/*!sc*/
# .search.closed{opacity:0;pointer-events:none;-webkit-transform:translateY(-24px);-ms-transform:translateY(-24px);transform:translateY(-24px);}/*!sc*/
# .search.closed button::after{display:none;}/*!sc*/
# .logo-link{display:block;padding:16px;}/*!sc*/
# .logo{height:24px;line-height:0;display:block;-webkit-transition:height .5s ease-out;transition:height .5s ease-out;}/*!sc*/
# @media screen and (min-width:768px){.logo-link{padding:24px;}.logo{height:30px;}.top-of-screen .logo{height:40px;}}/*!sc*/
# .logo-img{height:100%;width:auto;}/*!sc*/
# .right,.left{position:absolute;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;gap:16px;}/*!sc*/
# .left{justify-self:flex-start;}/*!sc*/
# .center{justify-self:center;}/*!sc*/
# .right{justify-self:flex-end;}/*!sc*/
# .sr-only{position:absolute;height:1px;width:1px;-webkit-clip:rect(1px 1px 1px 1px);clip:rect(1px 1px 1px 1px);-webkit-clip:rect(1px,1px,1px,1px);clip:rect(1px,1px,1px,1px);-webkit-clip-path:polygon(0px 0px,0px 0px,0px 0px);clip-path:polygon(0px 0px,0px 0px,0px 0px);-webkit-clip-path:polygon(0px 0px,0px 0px,0px 0px);overflow:hidden;}/*!sc*/
# .box-logged-controls{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .box-logged-controls .signIn-button{margin-left:16px;}/*!sc*/
# data-styled.g309[id="sc-global-bzUqeS1"]{content:"sc-global-bzUqeS1,"}/*!sc*/
# .jfZMhC{height:44px;padding:0 72px;}/*!sc*/
# @media screen and (max-width:820px){.jfZMhC{padding:0 16px;}}/*!sc*/
# data-styled.g310[id="sc-45375a02-0"]{content:"jfZMhC,"}/*!sc*/
# .ccPSFP{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;display:grid;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;max-width:1296px;}/*!sc*/
# .ccPSFP .login-button{background-color:#ffffff;border:2px solid #0f1923;color:#0f1923;font-family:'Barlow',sans-serif;}/*!sc*/
# .ccPSFP .signIn-button{border:2px solid #ea2300;}/*!sc*/
# @media screen and (max-width:820px){.ccPSFP .signIn-button{padding:10px 15px;}}/*!sc*/
# data-styled.g311[id="sc-45375a02-1"]{content:"ccPSFP,"}/*!sc*/
# @media screen and (min-width:768px){.jmNlav{padding:4px;}}/*!sc*/
# data-styled.g312[id="sc-45375a02-2"]{content:"jmNlav,"}/*!sc*/
# .hRdogA{top:-1px;display:grid;background:#fff;position:-webkit-sticky !important;position:sticky !important;position:-webkit-sticky;overflow:clip;-webkit-align-self:flex-start;-ms-flex-item-align:start;align-self:flex-start;z-index:20;-webkit-transition:all 0.5s ease-out;transition:all 0.5s ease-out;margin-bottom:10px;}/*!sc*/
# .hRdogA:not(.top-of-screen) > :last-child{box-shadow:0px 8px 14px rgba(0,0,0,0.07843);}/*!sc*/
# .hRdogA.is-fixed-header{margin-bottom:0;}/*!sc*/
# .hRdogA.is-fixed-header > div{box-shadow:unset !important;margin-bottom:0;}/*!sc*/
# .hRdogA.top-of-screen{box-shadow:unset;margin-bottom:0;}/*!sc*/
# .hRdogA.scroll-down{top:-141px;}/*!sc*/
# @media screen and (max-width:767px){.hRdogA{margin-bottom:0;}.hRdogA .sticky-menu{position:absolute;left:0;right:0;top:100%;z-index:-1;background:#fff;-webkit-transition:top 0.5s ease-out;transition:top 0.5s ease-out;}}/*!sc*/
# data-styled.g313[id="sc-ac8e98ac-0"]{content:"hRdogA,"}/*!sc*/
# .eNbDHk{height:42px;padding:15px 0;background-color:#FFFFFF;border-bottom:2px solid #fafafa;}/*!sc*/
# data-styled.g314[id="sc-ac8e98ac-1"]{content:"eNbDHk,"}/*!sc*/
# </style><style data-href="https://fonts.googleapis.com/css2?family=Barlow:wght@700&display=swap">@font-face{font-family:'Barlow';font-style:normal;font-weight:700;font-display:swap;src:url(https://fonts.gstatic.com/s/barlow/v12/7cHqv4kjgoGqM7E3t-4c4w.woff) format('woff')}@font-face{font-family:'Barlow';font-style:normal;font-weight:700;font-display:swap;src:url(https://fonts.gstatic.com/s/barlow/v12/7cHqv4kjgoGqM7E3t-4s6Fostz0rdom9.woff2) format('woff2');unicode-range:U+0102-0103,U+0110-0111,U+0128-0129,U+0168-0169,U+01A0-01A1,U+01AF-01B0,U+1EA0-1EF9,U+20AB}@font-face{font-family:'Barlow';font-style:normal;font-weight:700;font-display:swap;src:url(https://fonts.gstatic.com/s/barlow/v12/7cHqv4kjgoGqM7E3t-4s6Vostz0rdom9.woff2) format('woff2');unicode-range:U+0100-024F,U+0259,U+1E00-1EFF,U+2020,U+20A0-20AB,U+20AD-20CF,U+2113,U+2C60-2C7F,U+A720-A7FF}@font-face{font-family:'Barlow';font-style:normal;font-weight:700;font-display:swap;src:url(https://fonts.gstatic.com/s/barlow/v12/7cHqv4kjgoGqM7E3t-4s51ostz0rdg.woff2) format('woff2');unicode-range:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+2000-206F,U+2074,U+20AC,U+2122,U+2191,U+2193,U+2212,U+2215,U+FEFF,U+FFFD}</style><style data-href="https://fonts.googleapis.com/css2?family=Barlow:wght@700;800&display=swap">@font-face{font-family:'Barlow';font-style:normal;font-weight:700;font-display:swap;src:url(https://fonts.gstatic.com/s/barlow/v12/7cHqv4kjgoGqM7E3t-4c4w.woff) format('woff')}@font-face{font-family:'Barlow';font-style:normal;font-weight:800;font-display:swap;src:url(https://fonts.gstatic.com/s/barlow/v12/7cHqv4kjgoGqM7E3q-0c4w.woff) format('woff')}@font-face{font-family:'Barlow';font-style:normal;font-weight:700;font-display:swap;src:url(https://fonts.gstatic.com/s/barlow/v12/7cHqv4kjgoGqM7E3t-4s6Fostz0rdom9.woff2) format('woff2');unicode-range:U+0102-0103,U+0110-0111,U+0128-0129,U+0168-0169,U+01A0-01A1,U+01AF-01B0,U+1EA0-1EF9,U+20AB}@font-face{font-family:'Barlow';font-style:normal;font-weight:700;font-display:swap;src:url(https://fonts.gstatic.com/s/barlow/v12/7cHqv4kjgoGqM7E3t-4s6Vostz0rdom9.woff2) format('woff2');unicode-range:U+0100-024F,U+0259,U+1E00-1EFF,U+2020,U+20A0-20AB,U+20AD-20CF,U+2113,U+2C60-2C7F,U+A720-A7FF}@font-face{font-family:'Barlow';font-style:normal;font-weight:700;font-display:swap;src:url(https://fonts.gstatic.com/s/barlow/v12/7cHqv4kjgoGqM7E3t-4s51ostz0rdg.woff2) format('woff2');unicode-range:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+2000-206F,U+2074,U+20AC,U+2122,U+2191,U+2193,U+2212,U+2215,U+FEFF,U+FFFD}@font-face{font-family:'Barlow';font-style:normal;font-weight:800;font-display:swap;src:url(https://fonts.gstatic.com/s/barlow/v12/7cHqv4kjgoGqM7E3q-0s6Fostz0rdom9.woff2) format('woff2');unicode-range:U+0102-0103,U+0110-0111,U+0128-0129,U+0168-0169,U+01A0-01A1,U+01AF-01B0,U+1EA0-1EF9,U+20AB}@font-face{font-family:'Barlow';font-style:normal;font-weight:800;font-display:swap;src:url(https://fonts.gstatic.com/s/barlow/v12/7cHqv4kjgoGqM7E3q-0s6Vostz0rdom9.woff2) format('woff2');unicode-range:U+0100-024F,U+0259,U+1E00-1EFF,U+2020,U+20A0-20AB,U+20AD-20CF,U+2113,U+2C60-2C7F,U+A720-A7FF}@font-face{font-family:'Barlow';font-style:normal;font-weight:800;font-display:swap;src:url(https://fonts.gstatic.com/s/barlow/v12/7cHqv4kjgoGqM7E3q-0s51ostz0rdg.woff2) format('woff2');unicode-range:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+2000-206F,U+2074,U+20AC,U+2122,U+2191,U+2193,U+2212,U+2215,U+FEFF,U+FFFD}</style><style data-href="https://fonts.googleapis.com/css2?family=Barlow:wght@400;700;800&display=swap">@font-face{font-family:'Barlow';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/barlow/v12/7cHpv4kjgoGqM7EPCA.woff) format('woff')}@font-face{font-family:'Barlow';font-style:normal;font-weight:700;font-display:swap;src:url(https://fonts.gstatic.com/s/barlow/v12/7cHqv4kjgoGqM7E3t-4c4w.woff) format('woff')}@font-face{font-family:'Barlow';font-style:normal;font ...

# %% [markdown]
# ## Outras opções
# Algumas opções interessantes de **API** para uso em aplicações.
# - Twitter API https://developer.twitter.com/en/docs/twitter-api
# - Here Geocoding https://developer.here.com/sign-up e https://developer.here.com/c/geocoding
# - OpenAI https://openai.com/blog/introducing-chatgpt-and-whisper-apis
