# %% [markdown]
# # Análise de texto de fontes desestruturadas e Web
#
# ## Aula 06
#
# Nesta aula iremos continuar a extrair informações de páginas Web! Primeiro, iremos realizar a extração de informações de produtos de uma página sintética. Em seguida, realizaremos buscas nos sites do InstoÉDinheiro e Magazine Luiza e extrair informações dos resultados.
#
# A biblioteca utilizada será a **BeautifulSoup**, além da **requests**.
#
# Para conhecer mais sobre ela, acesse https://beautiful-soup-4.readthedocs.io/en/latest/

# %% [markdown]
# ## Instalando a biblioteca *BeautifulSoup*
#
# Primeiro, vamos instalar a principal biblioteca de nossa aula!

# %%
# !pip install BeautifulSoup4

# %% [markdown]
# Caso a biblioteca já esteja instalada, porém com uma versão antiga, podemos atualizá-la com:

# %%
# !pip install BeautifulSoup4 -U

# %% [markdown]
# ## Importando as bibliotecas necessárias
#
# Agora, vamos importar as bibliotecas necessárias:

# %%
# para trabalhar com diretórios / sistema operacional
import os

# para nos comunicarmos com a Web
import requests

# para extrair informações de páginas HTML
import bs4
from bs4 import BeautifulSoup

# utilizada para nos indicar o caminho do executável do Python
import sys

# Para criar um Data Frame
import pandas as pd

# Controlar espera entre requisições
import time

# Gerar valores aleatórios
import random

# Produto cartesiano
from sklearn.utils.extmath import cartesian

# Renderizar HTML
import IPython

# %% [markdown]
# Caso obtenha algum erro, utilize o **!pip install** para instalar a biblioteca ausente!
#
# Vamos conferir com qual versão da biblioteca **xxxx** estamos trabalhando?

# %%
print(bs4.__version__)
# Out:
# 4.11.2

# %% [markdown]
# Você também pode conferir de onde está executando o Python e qual a versão

# %%
print('Executável:')
print(sys.executable)

print('\nVersão do Python:')
print(sys.version)
# Out:
# Executável:
# /opt/conda/bin/python
#
# Versão do Python:
# 3.10.9 | packaged by conda-forge | (main, Feb  2 2023, 20:20:04) [GCC 11.3.0]

# %% [markdown]
# Vamos conferir em qual diretório iremos trabalhar (é o diretório do notebook)

# %%
print('O seu notebook está na pasta:')
print(os.getcwd())
# Out:
# O seu notebook está na pasta:
# /home/jovyan

# %% [markdown]
# ## Exemplo de aplicação
#
# Suponha que tenhamos uma página Web com diversos produtos listados.
#
# Acesse https://atd-insper.s3.us-east-2.amazonaws.com/aula05/produtos.html
#
# Vamos utilizar o BeautifulSoup para extrair as informações da página, construindo um **pandas DataFrame** contendo o **`produto`**, **`descrição`** e **`preço`**.
#
# Primeiro, vamos extrair a página com o *requests*:

# %%
url = 'https://atd-insper.s3.us-east-2.amazonaws.com/aula05/produtos.html'

pag_prod = requests.get(url)

pag_prod.encoding = 'utf-8'

print(pag_prod.text)
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
#         <meta charset="UTF-8">
#         <title>Exemplo Produtos</title>
#     </head>
# <body>
#
# <div class="menu" id="my_menu" align="right">
# 	<a href="#">HOME</a> | <a href="macielcv@insper.edu.br">CONTATO</a> | <a href="https://www.google.com">GOOGLE</a>
# </div>
#
#
# <div class="produto" id="produto_1" align="left" style="width:600px;height:160px; background-color:rgb(115, 185, 174);">
# 	<h4>Notebook Dell Core i5-8265U 8GB 1TB Tela 15.6” Windows 10 Inspiron I15-3583-A3XP</h4>
# 	<p>Com o notebook Dell Inspiron I15-3583-A3XP você conta com todos os recursos essenciais para o seu dia a dia. Sua estrutura leve e fina garante a portabilidade ideal para levar aonde quiser.</p>
#     <span class="preco_produto" id="preco_produto_1">R$&nbsp;4.299,00</span>
# </div>
#
#
# <div class="produto" id="produto_2" align="left" style="width:600px;height:160px; background-color:rgb(115, 185, 174);">
# 	<h4>Notebook Dell Core i7-8565U 8GB 2TB Placa de Vídeo 2GB Tela Full HD 15.6” Windows 10 Inspiron I15-3583-A40B</h4>
# 	<p>Intel® Core™ i7-8565U Quad Core 1.8 GHz com Turbo Max até 4.6 GHz. Windows 10 Home Single Language 64 bits.</p>
#     <span class="preco_produto" id="preco_produto_2">R$&nbsp;5.499,00</span>
# </div>
#
#
# <div class="produto" id="produto_3" align="left" style="width:600px;height:160px; background-color:rgb(115, 185, 174);">
# 	<h4>Notebook Gamer Dell G3 3500-U10P</h4>
# 	<p>Sua EXPERIÊNCIA Gamer Ainda Mais Intensa E Real: GRÁFICOS Poderosos, Desempenho Extremamente RÁPIDO E Sistema TÉRMICO Especial. Com o novo notebook Dell G3, você terá uma incrível experiência em um notebook com um design fino, leve e com uma performance incrível.</p>
#     <span class="preco_produto" id="preco_produto_3">R$&nbsp;6.049,00</span>
# </div>
#
#
# <div class="produto" id="produto_4" align="left" style="width:600px;height:160px; background-color:rgb(115, 185, 174);">
# 	<h4>Notebook Lenovo Core i3-8130U 4GB 1TB Tela 15.6” Windows 10 Ideapad S145</h4>
# 	<p>Design sofisticado leve e compacto, possui tela antirreflexo de 15.6" para mais conforto visual e definição de imagem. Um notebook perfeito para produtividade e entretenimento com WiFi AC ultrarrápido e teclado numérico.</p>
#     <span class="preco_produto" id="preco_produto_4">R$&nbsp;3.199,00</span>
# </div>
#
#
# <div class="produto" id="produto_5" align="left" style="width:600px;height:160px; background-color:rgb(115, 185, 174);">
# 	<h4>Notebook Lenovo BS145 Intel Core I5 4Gb 256Gb SSD W10 Pro</h4>
# 	<p>O teclado numérico BS145 integrado garante uma digitação mais rápida e ergonômica, especialmente para facilitar o trabalho com cálculos e planilhas. Tela anti-reflexo de 15,6 polegadas que pode ser aberta em 180 °, dando a você mais flexibilidade no ajuste do ângulo de visão e tornando a integridade da dobradiça mais segura.</p>
#     <span class="preco_produto" id="preco_produto_5">R$&nbsp;6.781,00</span>
# </div>
#
# </body>
# </html>

# %% [markdown]
# Podemos abrir diretamente a URL em um navegador para verificar seu conteúdo, ou então renderizar dentro do notebook com:

# %%
IPython.display.HTML(pag_prod.text)
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
#         <meta charset="UTF-8">
#         <title>Exemplo Produtos</title>
#     </head>
# <body>
#
# <div class="menu" id="my_menu" align="right">
# 	<a href="#">HOME</a> | <a href="macielcv@insper.edu.br">CONTATO</a> | <a href="https://www.google.com">GOOGLE</a>
# </div>
#
#
# <div class="produto" id="produto_1" align="left" style="width:600px;height:160px; background-color:rgb(115, 185, 174);">
# 	<h4>Notebook Dell Core i5-8265U 8GB 1TB Tela 15.6” Windows 10 Inspiron I15-3583-A3XP</h4>
# 	<p>Com o notebook Dell Inspiron I15-3583-A3XP você conta com todos os recursos essenciais para o seu dia a dia. Sua estrutura leve e fina garante a portabilidade ideal para levar aonde quiser.</p>
#     <span class="preco_produto" id="preco_produto_1">R$&nbsp;4.299,00</span>
# </div>
#
#
# <div class="produto" id="produto_2" align="left" style="width:600px;height:160px; background-color:rgb(115, 185, 174);">
# 	<h4>Notebook Dell Core i7-8565U 8GB 2TB Placa de Vídeo 2GB Tela Full HD 15.6” Windows 10 Inspiron I15-3583-A40B</h4>
# 	<p>Intel® Core™ i7-8565U Quad Core 1.8 GHz com Turbo Max até 4.6 GHz. Windows 10 Home Single Language 64 bits.</p>
#     <span class="preco_produto" id="preco_produto_2">R$&nbsp;5.499,00</span>
# </div>
#
#
# <div class="produto" id="produto_3" align="left" style="width:600px;height:160px; background-color:rgb(115, 185, 174);">
# 	<h4>Notebook Gamer Dell G3 3500-U10P</h4>
# 	<p>Sua EXPERIÊNCIA Gamer Ainda Mais Intensa E Real: GRÁFICOS Poderosos, Desempenho Extremamente RÁPIDO E Sistema TÉRMICO Especial. Com o novo notebook Dell G3, você terá uma incrível experiência em um notebook com um design fino, leve e com uma performance incrível.</p>
#     <span class="preco_produto" id="preco_produto_3">R$&nbsp;6.049,00</span>
# </div>
#
#
# <div class="produto" id="produto_4" align="left" style="width:600px;height:160px; background-color:rgb(115, 185, 174);">
# 	<h4>Notebook Lenovo Core i3-8130U 4GB 1TB Tela 15.6” Windows 10 Ideapad S145</h4>
# 	<p>Design sofisticado leve e compacto, possui tela antirreflexo de 15.6" para mais conforto visual e definição de imagem. Um notebook perfeito para produtividade e entretenimento com WiFi AC ultrarrápido e teclado numérico.</p>
#     <span class="preco_produto" id="preco_produto_4">R$&nbsp;3.199,00</span>
# </div>
#
#
# <div class="produto" id="produto_5" align="left" style="width:600px;height:160px; background-color:rgb(115, 185, 174);">
# 	<h4>Notebook Lenovo BS145 Intel Core I5 4Gb 256Gb SSD W10 Pro</h4>
# 	<p>O teclado numérico BS145 integrado garante uma digitação mais rápida e ergonômica, especialmente para facilitar o trabalho com cálculos e planilhas. Tela anti-reflexo de 15,6 polegadas que pode ser aberta em 180 °, dando a você mais flexibilidade no ajuste do ângulo de visão e tornando a integridade da dobradiça mais segura.</p>
#     <span class="preco_produto" id="preco_produto_5">R$&nbsp;6.781,00</span>
# </div>
#
# </body>
# </html>

# %% [markdown]
# Vamos utilizar o BeautifulSoup

# %%
soup = BeautifulSoup(pag_prod.text, 'html.parser')

# %% [markdown]
# E extrair a lista de produtos

# %%
lista_produto = soup.find_all('div', class_='produto')
lista_produto
# Out:
# [<div align="left" class="produto" id="produto_1" style="width:600px;height:160px; background-color:rgb(115, 185, 174);">
#  <h4>Notebook Dell Core i5-8265U 8GB 1TB Tela 15.6” Windows 10 Inspiron I15-3583-A3XP</h4>
#  <p>Com o notebook Dell Inspiron I15-3583-A3XP você conta com todos os recursos essenciais para o seu dia a dia. Sua estrutura leve e fina garante a portabilidade ideal para levar aonde quiser.</p>
#  <span class="preco_produto" id="preco_produto_1">R$ 4.299,00</span>
#  </div>,
#  <div align="left" class="produto" id="produto_2" style="width:600px;height:160px; background-color:rgb(115, 185, 174);">
#  <h4>Notebook Dell Core i7-8565U 8GB 2TB Placa de Vídeo 2GB Tela Full HD 15.6” Windows 10 Inspiron I15-3583-A40B</h4>
#  <p>Intel® Core™ i7-8565U Quad Core 1.8 GHz com Turbo Max até 4.6 GHz. Windows 10 Home Single Language 64 bits.</p>
#  <span class="preco_produto" id="preco_produto_2">R$ 5.499,00</span>
#  </div>,
#  <div align="left" class="produto" id="produto_3" style="width:600px;height:160px; background-color:rgb(115, 185, 174);">
#  <h4>Notebook Gamer Dell G3 3500-U10P</h4>
#  <p>Sua EXPERIÊNCIA Gamer Ainda Mais Intensa E Real: GRÁFICOS Poderosos, Desempenho Extremamente RÁPIDO E Sistema TÉRMICO Especial. Com o novo notebook Dell G3, você terá uma incrível experiência em um notebook com um design fino, leve e com uma performance incrível.</p>
#  <span class="preco_produto" id="preco_produto_3">R$ 6.049,00</span>
#  </div>,
#  <div align="left" class="produto" id="produto_4" style="width:600px;height:160px; background-color:rgb(115, 185, 174);">
#  <h4>Notebook Lenovo Core i3-8130U 4GB 1TB Tela 15.6” Windows 10 Ideapad S145</h4>
#  <p>Design sofisticado leve e compacto, possui tela antirreflexo de 15.6" para mais conforto visual e definição de imagem. Um notebook perfeito para produtividade e entretenimento com WiFi AC ultrarrápido e teclado numérico.</p>
#  <span class="preco_produto" id="preco_produto_4">R$ 3.199,00</span>
#  </div>,
#  <div align="left" class="produto" id="produto_5" style="width:600px;height:160px; background-color:rgb(115, 185, 174);">
#  <h4>Notebook Lenovo BS145 Intel Core I5 4Gb 256Gb SSD W10 Pro</h4>
#  <p>O teclado numérico BS145 integrado garante uma digitação mais rápida e ergonômica, especialmente para facilitar o trabalho com cálculos e planilhas. Tela anti-reflexo de 15,6 polegadas que pode ser aberta em 180 °, dando a você mais flexibilidade no ajuste do ângulo de visão e tornando a integridade da dobradiça mais segura.</p>
#  <span class="preco_produto" id="preco_produto_5">R$ 6.781,00</span>
#  </div>]

# %% [markdown]
# Podemos obter um produto qualquer da lista, bastando informar o índice da lista

# %%
produto = lista_produto[0]
produto
# Out:
# <div align="left" class="produto" id="produto_1" style="width:600px;height:160px; background-color:rgb(115, 185, 174);">
# <h4>Notebook Dell Core i5-8265U 8GB 1TB Tela 15.6” Windows 10 Inspiron I15-3583-A3XP</h4>
# <p>Com o notebook Dell Inspiron I15-3583-A3XP você conta com todos os recursos essenciais para o seu dia a dia. Sua estrutura leve e fina garante a portabilidade ideal para levar aonde quiser.</p>
# <span class="preco_produto" id="preco_produto_1">R$ 4.299,00</span>
# </div>

# %% [markdown]
# Então, podemos obter as informações de **PRODUTO**, **DESCRIÇÃO** e **PREÇO**!

# %%
produto_titulo = produto.find('h4').text
descricao = produto.find('p').text
preco = produto.find('span').text

print('Produto....: ', produto_titulo)
print('\nDescrição..: ', descricao)
print('\nPreço......: ', preco)
# Out:
# Produto....:  Notebook Dell Core i5-8265U 8GB 1TB Tela 15.6” Windows 10 Inspiron I15-3583-A3XP
#
# Descrição..:  Com o notebook Dell Inspiron I15-3583-A3XP você conta com todos os recursos essenciais para o seu dia a dia. Sua estrutura leve e fina garante a portabilidade ideal para levar aonde quiser.
#
# Preço......:  R$ 4.299,00

# %% [markdown]
# ### Obter todos os produtos e construir o DataFrame!
#
# Para obter as informações de todos os produtos de forma fácil, podemos iterar (laço, estrutura de repetição **for**) sobre as *div*'s de todos os produtos e extrair as informações para cada uma delas.
#
# Podemos guardar cada produto, descrição e preço em uma lista, o que facilitará a construção do DataFrame.

# %%
lista_prod_titulo = []
lista_descricao = []
lista_preco = []

for produto in soup.find_all('div', class_='produto'):
    produto_titulo = produto.find('h4').text
    descricao = produto.find('p').text
    preco = produto.find('span').text
    
    preco = preco.replace('R$\xa0', '')
    preco = float(preco.replace(".", "").replace(",", "."))

    
    lista_prod_titulo.append(produto_titulo)
    lista_descricao.append(descricao)
    lista_preco.append(preco)

# %% [markdown]
# Agora, com as listas de produto, descrição e preço, podemos construir o DataFrame!

# %%
df = pd.DataFrame({'Produto': lista_prod_titulo,
                   'Descrição': lista_descricao,
                   'Preço': lista_preco
                  })
df
# Out:
#                                              Produto  \
# 0  Notebook Dell Core i5-8265U 8GB 1TB Tela 15.6”...
# 1  Notebook Dell Core i7-8565U 8GB 2TB Placa de V...
# 2                   Notebook Gamer Dell G3 3500-U10P
# 3  Notebook Lenovo Core i3-8130U 4GB 1TB Tela 15....
# 4  Notebook Lenovo BS145 Intel Core I5 4Gb 256Gb ...
#
#                                            Descrição   Preço
# 0  Com o notebook Dell Inspiron I15-3583-A3XP voc...  4299.0
# 1  Intel® Core™ i7-8565U Quad Core 1.8 GHz com Tu...  5499.0
# 2  Sua EXPERIÊNCIA Gamer Ainda Mais Intensa E Rea...  6049.0
# 3  Design sofisticado leve e compacto, possui tel...  3199.0
# 4  O teclado numérico BS145 integrado garante uma...  6781.0

# %% [markdown]
# Você conseguiria pensar em alguma aplicação prática feita a partir deste exemplo?

# %% [markdown]
# <div class="alert alert-success">
#
# Sua resposta aqui! Dê dois cliques e edite.
#
# </div>

# %% [markdown]
# ## IstoÉDinheiro
#
# Vamos utilizar `requests` para baixar (`get`) notícias do site da **IstoÉDinheiro** e `BeautifulSoup` para extrair informações e construir um Pandas `DataFrame` de títulos e descrições.
#
# ### Definindo qual página buscar
#
# Faremos algumas configurações (cabeçalho, seção e URL):

# %%
headers = ({'User-Agent':
            'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36'})

secao = 'economia'

url = f"https://www.istoedinheiro.com.br/categoria/{secao}/"

# %% [markdown]
# ### Utilizando *requests* para baixar a página de notícias
#
# E utilizar `requests` para baixar a página de notícias:

# %%
resposta = requests.get(url=url, headers=headers)

resposta.encoding = 'utf-8'

resposta.text
# Out:
# '<!DOCTYPE html>\n<html class="no-js" lang="pt-BR">\n<head>\n\t<meta charset="UTF-8" />\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\t<meta name="viewport" content="width=device-width, initial-scale=1.0" />\n\t<meta name="theme-color" content="#D00018">\n\t<link rel="profile" href="http://gmpg.org/xfn/11" />\n\t<link href="https://www.istoedinheiro.com.br/wp-content/themes/tema_dinheiro/assets/images/favicon_dinheiro_32X32-v21.ico" rel="shortcut icon" />\n  <meta name=\'dailymotion-domain-verification\' content=\'dm8ibc0sv94vdc6bk\' />\n\t<meta name=\'robots\' content=\'max-image-preview:large\' />\n\n\t<!-- This site is optimized with the Yoast SEO plugin v14.2 - https://yoast.com/wordpress/plugins/seo/ -->\n\t<meta name="robots" content="index, follow" />\n\t<meta name="googlebot" content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" />\n\t<meta name="bingbot" content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" />\n\t<link rel="canonical" href="https://www.istoedinheiro.com.br/categoria/economia/" />\n\t<link rel="next" href="https://www.istoedinheiro.com.br/categoria/economia/page/2/" />\n\t<meta property="og:locale" content="pt_BR" />\n\t<meta property="og:type" content="article" />\n\t<meta property="og:title" content="Economia - ISTOÉ DINHEIRO" />\n\t<meta property="og:url" content="https://www.istoedinheiro.com.br/categoria/economia/" />\n\t<meta property="og:site_name" content="ISTOÉ DINHEIRO" />\n\t<meta property="og:image" content="https://www.istoedinheiro.com.br/wp-content/uploads/sites/17/2021/04/dinheiro-facebook.png" />\n\t<meta property="og:image:width" content="1200" />\n\t<meta property="og:image:height" content="630" />\n\t<meta property="fb:app_id" content="897801760242827" />\n\t<meta name="twitter:card" content="summary_large_image" />\n\t<meta name="twitter:site" content="@RevistaDinheiro" />\n\t<script type="application/ld+json" class="yoast-schema-graph">{"@context":"https://schema.org","@graph":[{"@type":"WebSite","@id":"https://www.istoedinheiro.com.br/#website","url":"https://www.istoedinheiro.com.br/","name":"ISTO\\u00c9 DINHEIRO","description":"Portal de not\\u00edcias e an\\u00e1lises de economia, neg\\u00f3cios, finan\\u00e7as, tecnologia e investimentos","potentialAction":[{"@type":"SearchAction","target":"https://www.istoedinheiro.com.br/?s={search_term_string}","query-input":"required name=search_term_string"}],"inLanguage":"pt-BR"},{"@type":"CollectionPage","@id":"https://www.istoedinheiro.com.br/categoria/economia/#webpage","url":"https://www.istoedinheiro.com.br/categoria/economia/","name":"Economia - ISTO\\u00c9 DINHEIRO","isPartOf":{"@id":"https://www.istoedinheiro.com.br/#website"},"inLanguage":"pt-BR"}]}</script>\n\t<!-- / Yoast SEO plugin. -->\n\n\n<link rel=\'dns-prefetch\' href=\'//www.istoedinheiro.com.br\' />\n<link rel=\'dns-prefetch\' href=\'//fonts.googleapis.com\' />\n<link rel=\'dns-prefetch\' href=\'//s.w.org\' />\n<link rel="alternate" type="application/rss+xml" title="Feed para ISTOÉ DINHEIRO &raquo;" href="https://www.istoedinheiro.com.br/feed/" />\n<link rel="alternate" type="application/rss+xml" title="Feed de comentários para ISTOÉ DINHEIRO &raquo;" href="https://www.istoedinheiro.com.br/comments/feed/" />\n<link rel="alternate" type="application/rss+xml" title="Feed de categoria para ISTOÉ DINHEIRO &raquo; Economia" href="https://www.istoedinheiro.com.br/categoria/economia/feed/" />\n\t\t<script type="text/javascript">\n\t\t\twindow._wpemojiSettings = {"baseUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/13.0.1\\/72x72\\/","ext":".png","svgUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/13.0.1\\/svg\\/","svgExt":".svg","source":{"concatemoji":"https:\\/\\/www.istoedinheiro.com.br\\/wp-includes\\/js\\/wp-emoji-release.min.js?ver=5.7.2"}};\n\t\t\t!function(e,a,t){var n,r,o,i=a.createElement("canvas"),p=i.getContext&&i.getContext("2d");function s(e,t){var a=String.fromCharCode;p.cle ...

# %% [markdown]
# ### Extraindo informações relevantes com *BeautifulSoup*
# Perceba que o HTML inclui uma grande quantidade de tags, o que dificulta identificar informações relevantes de forma direta. Com o auxílio da biblioteca **BeautifulSoup** podemos extrair facilmente as informações que desejamos.

# %%
soup = BeautifulSoup(resposta.text, 'html.parser')

# %% [markdown]
# Então, vamos obter uma lista com todos os trechos HTML que contém uma **notícia**.
#
# Para identificar as tags corretas, é preciso ir até a página Web que desejamos extrair informações, dar botão direito e ir em **inspecionar elemento**, navegando pelo HTML até identificar as tags necessárias
#
# Ex: https://www.istoedinheiro.com.br/categoria/economia/

# %%
lista_tag_noticia = soup.select(".c-conteudo > article > div.row")
lista_tag_noticia
# Out:
# [<div class="row">
#  <div class="wrapper-image">
#  <!--<a href="" title="" class="link-category link-cat-mob">Mundo</a>-->
#  <a class="c-container-img" href="https://www.istoedinheiro.com.br/governo-frances-usa-procedimento/" title="Governo francês usa procedimento especial para aprovar reforma previdenciária sem votação">
#  <img alt="" src="https://www.istoedinheiro.com.br/wp-content/uploads/sites/17/Reuters_Direct_Media/BrazilOnlineReportTopNews/tagreuters.com2023binary_LYNXMPEJ2F0Q1-BASEIMAGE-418x235.jpg" title="Governo francês usa procedimento especial para aprovar reforma previdenciária sem votação"/>
#  </a>
#  </div>
#  <div class="wrapper-title">
#  <h3>
#  <a href="https://www.istoedinheiro.com.br/governo-frances-usa-procedimento/" title="Governo francês usa procedimento especial para aprovar reforma previdenciária sem votação">Governo francês usa procedimento especial para aprovar reforma previdenciária sem votação</a>
#  </h3>
#  <a class="description" href="https://www.istoedinheiro.com.br/governo-frances-usa-procedimento/" title="Governo francês usa procedimento especial para aprovar reforma previdenciária sem votação">
#  <p>Por Elizabeth Pineau PARIS (Reuters) – A primeira-ministra francesa, Elisabeth Borne, acionou um procedimento especial para aprovar um impopular projeto de reforma da previdência na Assembleia Nacional nesta quinta-feira sem uma votação, em meio a gritos de parlamentares da esquerda contra a reforma. A medida, usando o chamado artigo 49.3 da Constituição, garantirá que o […]</p>
#  <time class="c-data" datetime="2023-03-16 18:14">16/03/2023 18:14</time>
#  </a>
#  <div class="share-post-mb"></div>
#  </div>
#  </div>,
#  <div class="row">
#  <div class="wrapper-image">
#  <!--<a href="" title="" class="link-category link-cat-mob">Mundo</a>-->
#  <a class="c-container-img" href="https://www.istoedinheiro.com.br/lucro-da-caramuru-sobe/" title="Lucro da Caramuru sobe 52% no 4º tri, mas cai em 2022 com diferenciadas e biocombustíveis">
#  <img alt="" src="https://www.istoedinheiro.com.br/wp-content/uploads/sites/17/Reuters_Direct_Media/BrazilOnlineReportAgribusinessNews/tagreuters.com2023binary_LYNXMPEJ2F10H-BASEIMAGE-418x235.jpg" title="Lucro da Caramuru sobe 52% no 4º tri, mas cai em 2022 com diferenciadas e biocombustíveis"/>
#  </a>
#  </div>
#  <div class="wrapper-title">
#  <h3>
#  <a href="https://www.istoedinheiro.com.br/lucro-da-caramuru-sobe/" title="Lucro da Caramuru sobe 52% no 4º tri, mas cai em 2022 com diferenciadas e biocombustíveis">Lucro da Caramuru sobe 52% no 4º tri, mas cai em 2022 com diferenciadas e biocombustíveis</a>
#  </h3>
#  <a class="description" href="https://www.istoedinheiro.com.br/lucro-da-caramuru-sobe/" title="Lucro da Caramuru sobe 52% no 4º tri, mas cai em 2022 com diferenciadas e biocombustíveis">
#  <p>Por Nayara Figueiredo SÃO PAULO (Reuters) – A Caramuru Alimentos registrou lucro líquido de 102,2 milhões de reais no quarto trimestre de 2022, alta de 51,8% ante igual período do ano anterior, mas teve impactos nas áreas de commodities diferenciadas e biocombustíveis que afetaram o resultado anual consolidado, conforme balanço financeiro. A companhia, uma das […]</p>
#  <time class="c-data" datetime="2023-03-16 18:13">16/03/2023 18:13</time>
#  </a>
#  <div class="share-post-mb"></div>
#  </div>
#  </div>,
#  <div class="row">
#  <div class="wrapper-image">
#  <!--<a href="" title="" class="link-category link-cat-mob">Mundo</a>-->
#  <a class="c-container-img" href="https://www.istoedinheiro.com.br/polonia-enviara-4-jatos/" title="Polônia enviará 4 jatos MiG-29 à Ucrânia nos próximos dias">
#  <img alt="" src="https://www.istoedinheiro.com.br/wp-content/uploads/sites/17/Reuters_Direct_Media/BrazilOnlineReportWorldNews/tagreuters.com2023binary_LYNXMPEJ2F10E-BASEIMAGE-418x235.jpg" title="Polônia enviará 4 jatos MiG-29 à Ucrânia nos próximos dias"/>
#  </a>
#  </div>
#  <div class="wrapper-title">
#  <h3>
#  <a href="https://www.istoedinheiro.com.br/polonia-enviara-4-jatos/" title="Polônia enviará 4 jatos MiG-29 à Ucrânia nos próximos dias">Polônia enviará 4 jatos MiG-29 à Ucrânia nos próximos dias</a>
#  </h3>
#  <a class="description" href="https://www.istoedinheiro.com.br
a>
#  </h3>
#  <a class="description" href="https://www.istoedinheiro.com.br/chuvas-na-proxima-semana/" title="Chuvas na próxima semana na Argentina marcam início da normalização do clima">
#  <p>Por Maximilian Heath BUENOS AIRES (Reuters) – A soja e o milho da Argentina receberão as chuvas necessárias na próxima semana, marcando o início de uma lenta normalização do padrão de chuvas e temperaturas em um país onde uma seca histórica causou estragos na produção agrícola, disseram um especialista e um relatório na quinta-feira. agroclimática. […]</p>
#  <time class="c-data" datetime="2023-03-16 16:21">16/03/2023 16:21</time>
#  </a>
#  <div class="share-post-mb"></div>
#  </div>
#  </div>,
#  <div class="row">
#  <div class="wrapper-image">
#  <!--<a href="" title="" class="link-category link-cat-mob">Mundo</a>-->
#  <a class="c-container-img" href="https://www.istoedinheiro.com.br/explosao-em-predio-da/" title="Explosão em prédio da FSB no sul da Rússia deixa uma pessoa morta, dizem agências">
#  <img alt="" src="https://www.istoedinheiro.com.br/wp-content/uploads/sites/17/Reuters_Direct_Media/BrazilOnlineReportWorldNews/tagreuters.com2023binary_LYNXMPEJ2F0XW-BASEIMAGE-418x235.jpg" title="Explosão em prédio da FSB no sul da Rússia deixa uma pessoa morta, dizem agências"/>
#  </a>
#  </div>
#  <div class="wrapper-title">
#  <h3>
#  <a href="https://www.istoedinheiro.com.br/explosao-em-predio-da/" title="Explosão em prédio da FSB no sul da Rússia deixa uma pessoa morta, dizem agências">Explosão em prédio da FSB no sul da Rússia deixa uma pessoa morta, dizem agências</a>
#  </h3>
#  <a class="description" href="https://www.istoedinheiro.com.br/explosao-em-predio-da/" title="Explosão em prédio da FSB no sul da Rússia deixa uma pessoa morta, dizem agências">
#  <p>ROSTOV-ON-DON, Rússia (Reuters) – Pelo menos uma pessoa morreu e duas ficaram feridas nesta quinta-feira em  explosão e incêndio em um prédio do serviço de segurança FSB da Rússia na cidade de Rostov-on-Don, no sul do país, de acordo com funcionários citados por agências de notícias russas. Imagens capturadas pela Reuters mostraram uma espessa coluna […]</p>
#  <time class="c-data" datetime="2023-03-16 16:13">16/03/2023 16:13</time>
#  </a>
#  <div class="share-post-mb"></div>
#  </div>
#  </div>]

# %% [markdown]
# Agora, podemos passar por cada uma das chamadas de notícias, extraindo informações de interesse, como o título, descrição e data.

# %%
lista_titulo = [noticia.find("h3").text.replace("\n", "") for noticia in lista_tag_noticia]
lista_desc = [noticia.find("p").text for noticia in lista_tag_noticia]
lista_data = [noticia.find("time").text for noticia in lista_tag_noticia]

# %% [markdown]
# ## Criando um DataFrame
#
# As informações que consideramos foram extraídas na repetição **for** e armazenadas em listas. Podemos utilizar estas listas para construir um Pandas DataFrame:

# %%
df = pd.DataFrame({'Secao': secao,
                   'Titulo': lista_titulo,
                   'Descrição': lista_desc,
                   'Data': lista_data
                  })
df
# Out:
#        Secao                                             Titulo  \
# 0   economia  Governo francês usa procedimento especial para...
# 1   economia  Lucro da Caramuru sobe 52% no 4º tri, mas cai ...
# 2   economia  Polônia enviará 4 jatos MiG-29 à Ucrânia nos p...
# 3   economia  Número de mortos por ciclone Freddy passa de 4...
# 4   economia  Cyrela: lucro do 4º trimestre de 2022 soma R$ ...
# 5   economia  EcoRodovias: lucro líquido recorrente no 4º tr...
# 6   economia  França: cias aéreas me procuraram; querem desm...
# 7   economia  Reino Unido e sindicatos de profissionais de s...
# 8   economia  Argentina: BC eleva taxa básica de juros em 30...
# 9   economia  Bancos depositarão US$ 30 bilhões no First Rep...
# 10  economia  Seara aposta em tecnologia 4.0 para segmento d...
# 11  economia  Bancos suspendem consignado do INSS após gover...
# 12  economia  IGC vê avanço na produção global de grãos em 2...
# 13  economia  Dano moral previdenciário: quando se aplica e ...
# 14  economia  ‘Não vejo espaço para crise chegar a bancos do...
# 15  economia    Europa: medo de contágio testa força dos bancos
# 16  economia  Exportações de soja e milho dos EUA se animam ...
# 17  economia  Argentina reduz novamente previsão de produção...
# 18  economia  Chuvas na próxima semana na Argentina marcam i...
# 19  economia  Explosão em prédio da FSB no sul da Rússia dei...
#
#                                             Descrição              Data
# 0   Por Elizabeth Pineau PARIS (Reuters) – A prime...  16/03/2023 18:14
# 1   Por Nayara Figueiredo SÃO PAULO (Reuters) – A ...  16/03/2023 18:13
# 2   VARSÓVIA (Reuters) – A Polônia enviará à Ucrân...  16/03/2023 18:10
# 3   Por Tom Gibb e Frank Phiri BLANTYRE (Reuters) ...  16/03/2023 18:05
# 4   A Cyrela Brazil Realty teve lucro líquido de R...  16/03/2023 18:05
# 5   A EcoRodovias reportou lucro líquido recorrent...  16/03/2023 18:01
# 6   O “Voa, Brasil”, como está sendo chamado um pr...  16/03/2023 17:59
# 7   Por Muvija M e Sachin Ravikumar LONDRES (Reute...  16/03/2023 17:54
# 8   O Banco Central da República Argentina (BCRA) ...  16/03/2023 17:35
# 9   Um grupo de 11 bancos americanos e que inclui ...  16/03/2023 17:33
# 10  Por Nayara Figueiredo SÃO PAULO (Reuters) – A ...  16/03/2023 17:30
# 11  Os bancos começaram nesta quinta-feira, 16, a ...  16/03/2023 17:17
# 12  LONDRES (Reuters) – A produção global de grãos...  16/03/2023 17:15
# 13  O Instituto Nacional do Seguro Social (INSS) t...  16/03/2023 17:02
# 14  Ex-diretor do Banco Central, José Júlio Senna ...  16/03/2023 17:02
# 15  A queda acentuada recente nas ações do Credit ...  16/03/2023 16:51
# 16  Por Karen Braun NAPERVILLE, ILLINOIS (Reuters)...  16/03/2023 16:42
# 17  BUENOS AIRES (Reuters) – A produção de soja da...  16/03/2023 16:21
# 18  Por Maximilian Heath BUENOS AIRES (Reuters) – ...  16/03/2023 16:21
# 19  ROSTOV-ON-DON, Rússia (Reuters) – Pelo menos u...  16/03/2023 16:13

# %% [markdown]
# ### Salvando o DataFrame em CSV
#
# É interessante armazenar o Dataframe em **CSV** (ou **xlsx**) para que ele possa ser análisado em algum momento posterior. Você poderia, por exemplo, extrair as notícias todos os dias de uma semana e analisar somente após ter todos estes dados.

# %%
df.to_csv(f'notebooks/lessons/06/noticias_{secao}_160323.csv', index=False)

# %% [markdown]
# # Exercícios
#
#
# **Exercício 1)** Altere o código de extração das informações das notícias para trazer também o **link da notícia**. Rode todo o código novamente.

# %%
lista_link = [noticia.find("a").attrs["href"] for noticia in lista_tag_noticia]

df = pd.DataFrame({'Secao': secao,
                   'Titulo': lista_titulo,
                   'Descrição': lista_desc,
                   'Data': lista_data,
                   "Link": lista_link
                  })
df
# Out:
#        Secao                                             Titulo  \
# 0   economia  Governo francês usa procedimento especial para...
# 1   economia  Lucro da Caramuru sobe 52% no 4º tri, mas cai ...
# 2   economia  Polônia enviará 4 jatos MiG-29 à Ucrânia nos p...
# 3   economia  Número de mortos por ciclone Freddy passa de 4...
# 4   economia  Cyrela: lucro do 4º trimestre de 2022 soma R$ ...
# 5   economia  EcoRodovias: lucro líquido recorrente no 4º tr...
# 6   economia  França: cias aéreas me procuraram; querem desm...
# 7   economia  Reino Unido e sindicatos de profissionais de s...
# 14  https://www.istoedinheiro.com.br/nao-vejo-espa...
# 15  https://www.istoedinheiro.com.br/europa-medo-d...
# 16  https://www.istoedinheiro.com.br/exportacoes-d...
# 17  https://www.istoedinheiro.com.br/argentina-red...
# 18  https://www.istoedinheiro.com.br/chuvas-na-pro...
# 19  https://www.istoedinheiro.com.br/explosao-em-p...

# %% [markdown]
# **Exercício 2)** Crie um CSV (pesquise e salve) com as notícias das seções de **economia**, **política** e **finanças**.
#
# Faça a pesquisa e gere o `DataFrame` e **CSV** com cada uma das seções. Observe como a IstoÉ as nomeia em seu site.
#
# Em seguida, abra os três arquivos e os concatene, gerando apenas um DataFrame contendo todas as notícias das três seções (dica: pd.concat).

# %%
def fetch_istoe_noticias(url):
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36"}
    resposta = requests.get(url=url, headers=headers)
    resposta.encoding = "utf-8"

    return BeautifulSoup(resposta.text, "html.parser")

def get_istoe_noticias(soup):
    secao = soup.find("h1").text
    lista_tag_noticia = soup.select(".c-conteudo > article > div.row")
    lista_titulo = [noticia.find("h3").text.replace("\n", "") for noticia in lista_tag_noticia]
    lista_desc = [noticia.find("p").text for noticia in lista_tag_noticia]
    lista_data = [noticia.find("time").text for noticia in lista_tag_noticia]
    lista_link = [noticia.find("a").attrs["href"] for noticia in lista_tag_noticia]

    return pd.DataFrame({
        "Secao": secao,
        "Titulo": lista_titulo,
        "Descrição": lista_desc,
        "Data": lista_data,
        "Link": lista_link
    })

# %%
paginas_url = [
    "https://www.istoedinheiro.com.br/categoria/economia/",
    "https://www.istoedinheiro.com.br/categoria/politica/",
    "https://www.istoedinheiro.com.br/categoria/financas/",
]

lista_df_noticias = [
    get_istoe_noticias(fetch_istoe_noticias(pagina_url))
    for pagina_url in paginas_url
]

df = pd.concat(lista_df_noticias).reset_index()
df
# Out:
#     index     Secao                                             Titulo  \
# 0       0  Economia  Fleury tem lucro líquido de R$ 31 milhões no 4...
# 1       1  Economia  Tribunal russo mantém direito de soldado de pr...
# 2       2  Economia  Café arábica fecha na máxima de uma semana na ...
# 3       3  Economia  Governo francês usa procedimento especial para...
# 4       4  Economia  Lucro da Caramuru sobe 52% no 4º tri, mas cai ...
# 5       5  Economia  Polônia enviará 4 jatos MiG-29 à Ucrânia nos p...
# 6       6  Economia  Número de mortos por ciclone Freddy passa de 4...
# 7       7  Economia  Cyrela: lucro do 4º trimestre de 2022 soma R$ ...
# 8       8  Economia  EcoRodovias: lucro líquido recorrente no 4º tr...
# 9       9  Economia  França: cias aéreas me procuraram; querem desm...
# 10     10  Economia  Reino Unido e sindicatos de profissionais de s...
# 11     11  Economia  Argentina: BC eleva taxa básica de juros em 30...
# 12     12  Economia  Bancos depositarão US$ 30 bilhões no First Rep...
# 13     13  Economia  Seara aposta em tecnologia 4.0 para segmento d...
# 14     14  Economia  IGC vê avanço na produção global de grãos em 2...
# 15     15  Economia  Dano moral previdenciário: quando se aplica e ...
# 16     16  Economia  ‘Não vejo espaço para crise chegar a bancos do...
# 17     17  Economia    Europa: medo de contágio testa força dos bancos
# 18     18  Economia  Exportações de soja e milho dos EUA se animam ...
# 32  https://www.istoedinheiro.com.br/reforma-tribu...
# 33  https://www.istoedinheiro.com.br/perfil-mais-c...
# 34  https://www.istoedinheiro.com.br/bolsonaro-fic...
# 35  https://www.istoedinheiro.com.br/governo-exclu...
# 36  https://www.istoedinheiro.com.br/gestao-bolson...
# 37  https://www.istoedinheiro.com.br/ministerio-da...
# 38  https://www.istoedinheiro.com.br/tarcisio-sp-v...
# 39  https://www.istoedinheiro.com.br/michelle-bols...
# 40  https://www.istoedinheiro.com.br/dolar-cai-103...
# 41  https://www.istoedinheiro.com.br/juros-taxas-s...
# 42  https://www.istoedinheiro.com.br/ibovespa-sobe...
# 43  https://www.istoedinheiro.com.br/bolsas-de-ny-...
# 44  https://www.istoedinheiro.com.br/bancos-suspen...
# 45  https://www.istoedinheiro.com.br/bancos-suspen...
# 46  https://www.istoedinheiro.com.br/dolar-recua-a...
# 47  https://www.istoedinheiro.com.br/petroleo-se-r...
# 48  https://www.istoedinheiro.com.br/ouro-fecha-em...
# 49  https://www.istoedinheiro.com.br/ibovespa-acel...
# 50  https://www.istoedinheiro.com.br/acoes-europei...
# 51  https://www.istoedinheiro.com.br/bolsas-da-eur...
# 52  https://www.istoedinheiro.com.br/duvidas-com-n...
# 53  https://www.istoedinheiro.com.br/estrangeiro-e...
# 54  https://www.istoedinheiro.com.br/dolar-recua-c...
# 55  https://www.istoedinheiro.com.br/taxas-de-juro...
# 56  https://www.istoedinheiro.com.br/bolsas-da-eur...
# 57  https://www.istoedinheiro.com.br/bolsas-da-asi...
# 58  https://www.istoedinheiro.com.br/dolar-fecha-n...
# 59  https://www.istoedinheiro.com.br/juros-taxas-c...

# %% [markdown]
# **Exercício 3)** Crie uma solução em Python que faça o download de várias páginas (1, 2, 3, ...) de notícias do IstoÉDinheiro. Defina no inicio do código variáveis de **página inicial** e **página** final.
#
# Como resultado, produza um `DataFrame` contendo todas as notícias. Adicione uma coluna com o número da página onde a notícia aparece.

# %%
def navega_istoe_paginas(url_start, url_end):
    current = url_start
    paginas = []

    while current != url_end:
        noticias = fetch_istoe_noticias(current)
        current = noticias.select_one(".box_paginacao > ul.page-numbers > li > a.next").attrs["href"]

        paginas.append(noticias)
    
    return paginas

# %%
pagina_inicial = "https://www.istoedinheiro.com.br/categoria/economia/"
pagina_final = "https://www.istoedinheiro.com.br/categoria/economia/page/5/"

paginas = navega_istoe_paginas(pagina_inicial, pagina_final)
paginas
# Out:
# [<!DOCTYPE html>
#
#  <html class="no-js" lang="pt-BR">
#  <head>
#  <meta charset="utf-8"/>
#  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#  <meta content="width=device-width, initial-scale=1.0" name="viewport">
#  <meta content="#D00018" name="theme-color"/>
#  <link href="http://gmpg.org/xfn/11" rel="profile"/>
#  <link href="https://www.istoedinheiro.com.br/wp-content/themes/tema_dinheiro/assets/images/favicon_dinheiro_32X32-v21.ico" rel="shortcut icon"/>
#  <meta content="dm8ibc0sv94vdc6bk" name="dailymotion-domain-verification">
#  <meta content="max-image-preview:large" name="robots"/>
#  <!-- This site is optimized with the Yoast SEO plugin v14.2 - https://yoast.com/wordpress/plugins/seo/ -->
#  <meta content="index, follow" name="robots"/>
#  <meta content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="googlebot"/>
#  <meta content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="bingbot"/>
#  <link href="https://www.istoedinheiro.com.br/categoria/economia/" rel="canonical"/>
#  <link href="https://www.istoedinheiro.com.br/categoria/economia/page/2/" rel="next"/>
#  <meta content="pt_BR" property="og:locale"/>
#  <meta content="article" property="og:type"/>
#  <meta content="Economia - ISTOÉ DINHEIRO" property="og:title"/>
#  <meta content="https://www.istoedinheiro.com.br/categoria/economia/" property="og:url"/>
#  <meta content="ISTOÉ DINHEIRO" property="og:site_name"/>
#  <meta content="https://www.istoedinheiro.com.br/wp-content/uploads/sites/17/2021/04/dinheiro-facebook.png" property="og:image"/>
#  <meta content="1200" property="og:image:width"/>
#  <meta content="630" property="og:image:height"/>
#  <meta content="897801760242827" property="fb:app_id"/>
#  <meta content="summary_large_image" name="twitter:card"/>
#  <meta content="@RevistaDinheiro" name="twitter:site"/>
#  <script class="yoast-schema-graph" type="application/ld+json">{"@context":"https://schema.org","@graph":[{"@type":"WebSite","@id":"https://www.istoedinheiro.com.br/#website","url":"https://www.istoedinheiro.com.br/","name":"ISTO\u00c9 DINHEIRO","description":"Portal de not\u00edcias e an\u00e1lises de economia, neg\u00f3cios, finan\u00e7as, tecnologia e investimentos","potentialAction":[{"@type":"SearchAction","target":"https://www.istoedinheiro.com.br/?s={search_term_string}","query-input":"required name=search_term_string"}],"inLanguage":"pt-BR"},{"@type":"CollectionPage","@id":"https://www.istoedinheiro.com.br/categoria/economia/#webpage","url":"https://www.istoedinheiro.com.br/categoria/economia/","name":"Economia - ISTO\u00c9 DINHEIRO","isPartOf":{"@id":"https://www.istoedinheiro.com.br/#website"},"inLanguage":"pt-BR"}]}</script>
#  <!-- / Yoast SEO plugin. -->
#  <link href="//www.istoedinheiro.com.br" rel="dns-prefetch"/>
#  <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
#  <link href="//s.w.org" rel="dns-prefetch"/>
#  <link href="https://www.istoedinheiro.com.br/feed/" rel="alternate" title="Feed para ISTOÉ DINHEIRO »" type="application/rss+xml"/>
#  <link href="https://www.istoedinheiro.com.br/comments/feed/" rel="alternate" title="Feed de comentários para ISTOÉ DINHEIRO »" type="application/rss+xml"/>
#  <link href="https://www.istoedinheiro.com.br/categoria/economia/feed/" rel="alternate" title="Feed de categoria para ISTOÉ DINHEIRO » Economia" type="application/rss+xml"/>
#  <script type="text/javascript">
#  			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.0.1\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.0.1\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/www.istoedinheiro.com.br\/wp-includes\/js\/wp-emoji-release.min.js?ver=5.7.2"}};
#  			!function(e,a,t){var n,r,o,i=a.createElement("canvas"),p=i.getContext&&i.getContext("2d");function s(e,t){var a=String.fromCharCode;p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,e),0,0);e=i.toDataURL();return p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,t),0,0),e===i.toDataURL()}function c(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(o=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},r=0;r<o.length;r++)t.supports[o[r]]=function(e){if(!p||!p.fillText)return!1;switch(p.textBaseline="top",p.font="600 32px Arial",e){case"flag":return s([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])?!1:!s([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!s([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]);case"emoji":return!s([55357,56424,8205,55356,57212],[55357,56424,8203,55356,57212])}return!1}(o[r]),t.supports.everything=t.supports.everything&&t.supports[o[r]],"flag"!==o[r]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[o[r]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(n=t.source||{}).concatemoji?c(n.concatemoji):n.wpemoji&&n.twemoji&&(c(n.twemoji),c(n.wpemoji)))}(window,document,window._wpemojiSettings);
#  		</script>
#  <style type="text/css">
#  img.wp-smiley,
#  img.emoji {
#  	display: inline !important;
#  	border: none !important;
#  	box-shadow: none !important;
#  	height: 1em !important;
#  	width: 1em !important;
#  	margin: 0 .07em !important;
#  	vertical-align: -0.1em !important;
#  	background: none !important;
#  	padding: 0 !important;
#  }
#  </style>
#  <link href="https://www.istoedinheiro.com.br/wp-content/themes/revistas_3/assets/css/main.css?ver=9.0.3" id="istoe-principal-css" media="all" rel="stylesheet" type="text/css"/>
#  <link href="//fonts.googleapis.com/css?family=Lato:400,300italic,300,400italic,700,700italic,900,900italic" id="istoe-font-lato-css" media="all" rel="stylesheet" type="text/css"/>
#  <link href="//fonts.googleapis.com/css?family=Open+Sans:400,300,300italic,400italic,600,600italic,700,700italic,800,800italic" id="istoe-font-opensans-css" media="all" rel="stylesheet" type="text/css"/>
#  <link href="https://www.istoedinheiro.com.br/wp-includes/css/dist/block-library/style.min.css?ver=5.7.2" id="wp-block-library-css" media="all" rel="stylesheet" type="text/css"/>
#  <link href="https://www.istoedinheiro.com.br/wp-content/plugins/embedpress/Gutenberg/dist/blocks.style.build.css?ver=1626202506" id="embedpress_blocks-cgb-style-css-css" media="all" rel="stylesheet" type="text/css"/>
#  <link href="https://www.istoedinheiro.com.br/wp-content/plugins/embedpress/assets/css/embedpress.css?ver=5.7.2" id="embedpress-css" media="all" rel="stylesheet" type="text/css"/>
#  <link href="https://www.istoedinheiro.com.br/wp-content/themes/revistas_3/assets/css/main.css?ver=5.7.2" id="parent-style-css" media="all" rel="stylesheet" type="text/css"/>
#  <link href="https://www.istoedinheiro.com.br/wp-content/themes/tema_dinheiro/stylev2.css?v=2.4&amp;ver=x1.2.5" id="child-style-css" media="all" rel="stylesheet" type="text/css"/>
#  <script id="jquery-core-js" src="https://www.istoedinheiro.com.br/wp-includes/js/jquery/jquery.min.js?ver=3.5.1" type="text/javascript"></script>
#  <script id="jquery-migrate-js" src="https://www.istoedinheiro.com.br/wp-includes/js/jquery/jquery-migrate.min.js?ver=3.3.2" type="text/javascript"></script>
#  <script id="jquery-stick-js" src="https://www.istoedinheiro.com.br/wp-content/themes/revistas_3/assets/js/client/theia-sticky-sidebar.js?ver=1.0.0" type="text/javascript"></script>
#  <script id="embedpress-pdfobject-js" src="https://www.istoedinheiro.com.br/wp-content/plugins/embedpress/assets/js/pdfobject.min.js?ver=2.7.6" type="text/javascript"></script>
#  <link href="https://www.istoedinheiro.com.br/wp-json/" rel="https://api.w.org/"/><link href="https://www.istoedinheiro.com.br/wp-json/wp/v2/categories/5" rel="alternate" type="application/json"/><link href="https://www.istoedinheiro.com.br/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
#  <link href="https://www.istoedinheiro.com.br/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
#  <meta content="WordPress 5.7.2" name="generator"/>
#  <title>Economia - ISTOÉ DINHEIRO</title>
#  <!--[if lt IE 9]>
#  		<script src="https://www.istoedinheiro.com.br/wp-content/themes/revistas_3/assets/js/html5.js"></script>
#  	<![endif]-->
#  <script src="https://www.googletagservices.com/tag/js/gpt.js"></script>
#  <style>
#  @media screen and (max-width: 782px) {
#  	html #wpadminbar { display:none !important; }
#  }
#  .banner_arroba{margin:20px auto;text-align:center;}
#  .banner_arroba_250{margin:0px auto;text-align:center;}
#
#  .banner_mobile{margin:30px auto;text-align:center}
#  .banner_mobile_topo{margin:0 auto;text-align:center;width: 320px !important;height: auto !important;}
#
#  .banner_super_topo, .banner_super{margin:0 auto;text-align:center}
#  .banner_desktop{margin:40px auto;text-align:center}
#  .banner_desktop_topo{margin:0 auto;text-align:center}
#  .banner_desktop_arroba{margin:20px auto;text-align:center;}
#  .banner_desktop_arroba_250{{margin:0px auto;text-align:center;}
#  </style>
#  <script>
#  var width = window.innerWidth || document.documentElement.clientWidth;
#  jQuery( document ).ready(function() {
#  if( width < 768 ) {
#  	jQuery( '.banner_super' ).addClass( 'banner_mobile' );
#  	jQuery( '.banner_super_topo' ).addClass( 'banner_mobile_topo' );
#  	} else {
#  	jQuery( '.banner_super' ).addClass( 'banner_desktop_topo' );
#  	//jQuery( '.banner_super_topo' ).addClass( 'banner_desktop_topo' );
#  	jQuery( '.banner_arroba' ).addClass( 'banner_desktop_arroba' );
#  	jQuery( '.banner_arroba_250' ).addClass( 'banner_desktop_arroba_250' );
#  	}
#  })
#  </script>
#  <meta content="239837762723938" property="fb:pages"/>
#  <!-- Global site tag (gtag.js) - Google Analytics -->
#  <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-6VP0875DQD"></script>
#  <script>
#    window.dataLayer = window.dataLayer || [];
#    function gtag(){dataLayer.push(arguments);}
#    gtag('js', new Date());
#
#    //rede
#    gtag('config', 'G-6VP0875DQD');
#    //dinheiro
#    gtag('config', 'G-DW2CDKPMMX');
#  </script>
#  <script type="text/javascript">
#  	  var googletag = googletag || {};
#        googletag.cmd = googletag.cmd || [];
#
#        googletag.cmd.push(function() {
#
#  	if (width < 768) {
#  		googletag.defineSlot('/22452847/IEDinheiro_Internas/economia', [320, 100], 'topinterna').setTargeting('pos', ['topMB_int']).addService(googletag.pubads());
#  		googletag.defineSlot('/22452847/IEDinheiro_Internas/economia', [300, 250], 'top2').setTargeting('pos', ['topMB']).addService(googletag.pubads());
#  		googletag.defineSlot('/22452847/IEDinheiro_Internas/economia', [300, 250], 'top3').setTargeting('pos', ['2MB']).addService(googletag.pubads());
#  		googletag.defineSlot('/22452847/IEDinheiro_Internas/economia', [300, 250], 'top4').setTargeting('pos', ['3MB']).addService(googletag.pubads());
#  		googletag.defineSlot('/22452847/IEDinheiro_Internas/economia', [[300, 50],[320,50]], 'stickybanner').addService(googletag.pubads()).setCollapseEmptyDiv(true);
#  	}else{
#  		googletag.defineSlot('/22452847/IEDinheiro_Internas/economia', [[728, 90],[970, 90]], 'stickybanner').setTargeting('pos', ['under_banner']).addService(googletag.pubads());
#  		googletag.defineSlot('/22452847/IEDinheiro_Internas/economia', [[728, 90],[970, 90],[970, 250]], 'topinterna').setTargeting('pos', ['top_int']).addService(googletag.pubads());
#  		if (window.innerWidth>=1280){
#  			googletag.defineSlot('/22452847/IEDinheiro_Internas/economia', [[160,600],[300, 600]], 'half').setTargeting('pos', ['top']).addService(googletag.pubads());
#  			googletag.defineSlot('/22452847/IEDinheiro_Internas/economia', [300, 250], 'arroba').setTargeting('pos', ['top']).addService(googletag.pubads());
#  						googletag.defineSlot('/22452847/IEDinheiro_Internas/economia', [300, 250], 'arroba2').setTargeting('pos', ['2']).addService(googletag.pubads());
#  					}
#  		else{
#  			googletag.defineSlot('/22452847/IEDinheiro_Internas/economia', [250, 250], 'x250_1').setTargeting('pos', ['250x250_top']).addService(googletag.pubads());
#  			googletag.defineSlot('/22452847/IEDinheiro_Internas/economia', [250, 250], 'x250_2').setTargeting('pos', ['250x250_2']).addService(googletag.pubads());
#  						googletag.defineSlot('/22452847/IEDinheiro_Internas/economia', [250, 250], 'x250_3').setTargeting('pos', ['250x250_3']).addService(googletag.pubads());
#  					}
#  	}
#  			googletag.defineSlot('/22452847/IEDinheiro_Internas', [1, 1], 'div-gpt-ad-1567006255544-0').addService(googletag.pubads());
#
#  	googletag.enableServices();
#    });
#  </script>
#  <!-- Begin comScore Tag -->
#  <script>
#    var _comscore = _comscore || [];
#    _comscore.push({ c1: "2", c2: "36204834" });
#    (function() {
#      var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#      s.src = "https://sb.scorecardresearch.com/cs/36204834/beacon.js";
#      el.parentNode.insertBefore(s, el);
#    })();
#  </script>
#  <noscript>
#  <img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=36204834&amp;cv=3.6.0&amp;cj=1"/>
#  </noscript>
#  <!-- End comScore Tag -->
#  <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#    (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#    m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#    })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#    ga('create', 'UA-13292077-1', 'auto');
#  ga('set', 'contentGroup1', 'Economia');
#  ga('send', 'pageview');
#    ga('create', 'UA-12962565-11', 'auto', 'rede');
#    ga('rede.send', 'pageview');
#  </script>
#  <link href="https://www.istoedinheiro.com.br/wp-content/themes/tema_dinheiro/assets/images/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
#  <link href="https://www.istoedinheiro.com.br/wp-content/themes/tema_dinheiro/assets/images/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#  <link href="https://www.istoedinheiro.com.br/wp-content/themes/tema_dinheiro/assets/images/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#  <link href="https://www.istoedinheiro.com.br/wp-content/themes/tema_dinheiro/assets/images/apple-icon-192x192.png" rel="apple-touch-icon" sizes="192x192"/>
#  <!-- Facebook Pixel Code -->
#  <script>
#    !function(f,b,e,v,n,t,s)
#    {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#    n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#    if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#    n.queue=[];t=b.createElement(e);t.async=!0;
#    t.src=v;s=b.getElementsByTagName(e)[0];
#    s.parentNode.insertBefore(t,s)}(window, document,'script',
#    'https://connect.facebook.net/en_US/fbevents.js');
#    fbq('init', '2641197072803735');
#    fbq('track', 'PageView');
#  </script>
#  <noscript><img height="1" src="https://www.facebook.com/tr?id=2641197072803735&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
#  <!-- End Facebook Pixel Code -->
#  <script src="//api.grumft.com/inter/24336/24336_INTER_1.js"></script>
#  <!-- Hotjar Tracking Code for https://www.istoedinheiro.com.br/ -->
#  <script>
#      (function(h,o,t,j,a,r){
#          h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#          h._hjSettings={hjid:2306807,hjsv:6};
#          a=o.getElementsByTagName('head')[0];
#          r=o.createElement('script');r.async=1;
#          r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
#          a.appendChild(r);
#      })(window,document,'https://static.hotjar.com/c/hotjar-','.js?sv=');
#  </script>
#  <script>
#    window.teads_analytics = window.teads_analytics || {};
#    window.teads_analytics.analytics_tag_id = "PUB_15064";
#    window.teads_analytics.share = window.teads_analytics.share || function() {
#      ;(window.teads_analytics.shared_data = window.teads_analytics.shared_data || []).push(arguments)
#    };
#  </script>
#  <script async="" src="https://a.teads.tv/analytics/tag.js"></script>
#  <script async="" src="https://www.dataunion.com.br/6793ab22-b32b-4d8e-a8b2-35835c9d4c1b" type="text/javascript"></script>
#  <!--<script async type="text/javascript" src="https://nave.foone.com.br/client/eef0ff46-01e5-11ec-acda-53613212d6c6"></script>-->
#  <style>
#  	.section-week-phrases .col-3 article a img { width: 100% !important;}
#  	.section-materia .main-content article h1 {
#  		letter-spacing: -0.6px;
#  	}
#
#  	@media screen and (min-width: 768px) {
#  		.banner_super_topo {
#  			margin:0 auto;
#  		}
#  	}
#  </style>
#  <link href="https://www.istoedinheiro.com.br/wp-content/themes/revistas_3/assets/css/print.css?v=1.6" media="print" rel="stylesheet" type="text/css"/>
#  <script>
#  function track(category,action,label){
#  	ga('send', 'event', category, action,  label);
#  }
#  var local = 'interna';
#  </script>
#  <script>
#  		jQuery( document ).ready(function() {
#  			var width = window.innerWidth || document.documentElement.clientWidth;
#  			var testeira = '';
#  //			console.log('largura' + width);
#  			var logo_1280 = 'https://www.istoedinheiro.com.br/wp-content/themes/tema_dinheiro/assets/svg/logo-dinheiro-1280-v20.svg';
#  			var logo_1024 = 'https://www.istoedinheiro.com.br/wp-content/themes/tema_dinheiro/assets/svg/logo-dinheiro-1024-v20.svg';
#  			var logo_mob = 'https://www.istoedinheiro.com.br/wp-content/themes/tema_dinheiro/assets/svg/logo-dinheiro-mob-v20.svg';
#  			if( width > 1279 ) {
#  				jQuery( '.logo-3-imagens' ).attr( 'src', logo_1280 );
#  			} else if ( width <= 1279 && width > 1023 ) {
#  				jQuery( '.logo-3-imagens' ).attr( 'src', logo_1024 );
#  			} else if ( width <= 1023 ) {
#  				jQuery( '.logo-3-imagens' ).attr( 'src', logo_mob );
#  			} else {
#  				jQuery( '.logo-3-imagens' ).attr( 'src', logo_1280 );
#  			}
#  		});
#  	</script>
#  <style>
#  	@media only screen and (min-width: 3000px){
#  		.box-content {
#  			width: calc(100% - 340px);
#  		}
#  	}
#  	</style>
#  </meta></meta></head>
#  <body class="archive category category-economia category-5">
#  <div id="x_out_of_page">
#  <script>
#          googletag.cmd.push(function() {
#            googletag.display('x_out_of_page');
#          });
#      </script>
#  </div>
#  <div id="div-gpt-ad-1567006255544-0">
#  <script>
#      googletag.cmd.push(function() { googletag.display('div-gpt-ad-1567006255544-0'); });
#    </script>
#  </div>
#  <!-- advertising dhtml -->
#  <!-- end dhtml -->
#  <div class="shadow-new"></div>
#  <svg style="display: none;" xmlns="http://www.w3.org/2000/svg">
#  <symbol id="icon-facebook" viewbox="0 0 11 24">
#  <path class="path-facebook" d="M7.36886448,23.75 L7.36886448,11.8736095 L10.6472677,11.8736095 L11.0817269,7.78093958 L7.36886448,7.78093958 L7.37443447,5.73251888 C7.37443447,4.66508753 7.47585471,4.09313343 9.00899441,4.09313343 L11.0585186,4.09313343 L11.0585186,0 L7.77965123,0 C3.84120425,0 2.45497302,1.98538524 2.45497302,5.32417888 L2.45497302,7.78140308 L0,7.78140308 L0,11.874073 L2.45497302,11.874073 L2.45497302,23.75 L7.36886448,23.75 Z" sketch:type="MSShapeGroup"></path>
#  </symbol>
#  <symbol id="icon-twitter" viewbox="0 0 28 24">
#  <path class="path-twitter" d="M13.8383763,6.26524651 L13.9001547,7.28394437 L12.8705136,7.15920586 C9.12262006,6.68104156 5.8483614,5.05944089 3.06833045,2.33598336 L1.70920421,0.984649465 L1.35912624,1.98255757 C0.617784654,4.20706105 1.09141956,6.55630304 2.63588119,8.13632421 C3.45959406,9.0094938 3.27425867,9.13423231 1.85335396,8.61448851 C1.35912624,8.44817049 0.926676982,8.32343198 0.885491338,8.38580123 C0.741341585,8.5313295
sketch:type="MSShapeGroup"></path>
#  </symbol>
#  <!-- <symbol id="icon-menu-open" viewBox="0 0 26 20">
#  		<rect id="Rectangle-1-Copy-17" sketch:type="MSShapeGroup" x="0" y="0" width="26" height="3" class="burger-top"></rect>
#          <rect id="Rectangle-1-Copy-19" sketch:type="MSShapeGroup" x="0" y="14" width="26" height="3"  class="burger-middle"></rect>
#          <rect id="Rectangle-1-Copy-20" sketch:type="MSShapeGroup" x="0" y="7" width="26" height="3" class="burger-bottom"></rect>
#  	</symbol> -->
#  <symbol id="icon-menu-open" viewbox="0 0 24 15">
#  <rect height="3" id="Rectangle-1-Copy-17" sketch:type="MSShapeGroup" width="24" x="0" y="0"></rect>
#  <rect height="3" id="Rectangle-1-Copy-19" sketch:type="MSShapeGroup" width="24" x="0" y="12"></rect>
#  <rect height="3" id="Rectangle-1-Copy-20" sketch:type="MSShapeGroup" width="24" x="0" y="6"></rect>
#  </symbol>
#  <symbol id="icon-menu-close" viewbox="0 0 18 20">
#  <path d="M21,12 L12,12 L12,21 L9,21 L9,12 L0,12 L0,9 L9,9 L9,0 L12,0 L12,9 L21,9 L21,12 L21,12 Z" id="Shape" sketch:type="MSShapeGroup"></path>
#  </symbol>
#  <symbol id="logo-istoe" viewbox="0 0 219 71">
#  <path d="M141.764382,55.7148543 C132.720901,55.7148543 125.389757,48.2808855 125.389757,39.1099907 C125.389757,29.9386325 132.720901,22.5042001 141.764382,22.5042001 C150.80832,22.5042001 158.139006,29.9386325 158.139006,39.1099907 C158.139006,48.2808855 150.80832,55.7148543 141.764382,55.7148543 M59.8350329,49.4026791 C61.6223363,50.5661923 62.5187307,52.0829315 62.4707341,54.2365899 C62.4145094,56.7388386 60.788109,59.4774985 55.4609392,59.3546574 C50.5259705,59.2406239 45.98366,54.4183019 44.0546522,49.9149031 L31.179211,49.9149031 L31.179211,57.8759294 L22.0950471,57.8759294 L22.0950471,20.5711921 L29.1912359,20.566093 C29.3183127,20.566093 28.3277535,23.6352648 28.4315177,26.7127804 C28.5997345,31.7168144 30.3952659,36.6527064 34.6002286,39.5647344 C46.0956522,47.5262243 53.105447,45.0239755 59.8350329,49.4026791 M141.764382,7.37760099 C135.600242,7.37760099 129.785335,9.14743905 124.940874,12.268065 L124.940874,7.83280816 L63.031152,7.83280816 L63.031152,11.4721478 C63.031152,11.4721478 61.5172008,9.936403 55.4047146,8.05994819 C46.552763,5.34214816 35.2730957,7.60520458 29.6090352,19.7177945 L29.6090352,7.83280816 L0.00013713325,7.83280816 L0.00013713325,20.5711921 L6.8417152,20.5711921 L6.8417152,57.8759294 L0.00013713325,57.8759294 L0.00013713325,70.6147769 L43.0677499,70.6147769 L43.0677499,67.6007677 C47.8902694,70.8989337 53.4181108,72.0986039 60.3396833,71.8088845 C72.5646558,71.2971241 78.8165609,62.3422442 78.6209174,52.4166883 C78.396476,41.0434623 66.1495622,36.
="https://www.istoedinheiro.com.br/edicao/1315/" onclick="track('ultima-edicao-menu', local, 'imagem-da-capa');" title="Edição nº1315 - Mulheres &amp; poder">
#  <img alt="" src="https://www.istoedinheiro.com.br/wp-content/uploads/sites/17/2023/03/assinante-1-147x196.jpg" title=""/>
#  </a>
#  <div class="wrapper-content menu">
#  <a class="titulo-edicao menu" href="https://www.istoedinheiro.com.br/edicao/1315/" onclick="track('ultima-edicao-menu', local, 'titulo-da-edicao');" title="Edição nº1315 - Mulheres &amp; poder">Edição nº1315 10.03 <span class="menu"></span></a>
#  <a class="link-edicoes-anteriores menu" href="https://www.istoedinheiro.com.br/edicoes" onclick="track('ultima-edicao-menu', local, 'link-edicoes-anteriores')" title="Edições anteriores">Ver edições anteriores</a>
#  </div>
#  </div>
#  <hr class="divisao-linha linha-edicao-mobile"/>
#  <div class="menu-sidebar-100">
#  <ul class="itens-menu menu-principal">
#  <li>
#  <a href="https://www.istoedinheiro.com.br" onclick="track('menu', local, 'home')" title="Home">Home</a>
#  </li>
#  <li>
#  <a href="https://www.istoedinheiro.com.br/ultimas" onclick="track('menu', local, 'ultimas')" title="Últimas notícias">Últimas notícias</a>
#  </li>
#  <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-2606363" id="menu-item-2606363"><a href="https://www.istoedinheiro.com.br/categoria/black-friday/" onclick="track('menu', local, 'Black Friday')">Black Friday</a></li>
#  <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-2524894" id="menu-item-2524894"><a href="https://www.istoedinheiro.com.br/categoria/estilo/" onclick="track('menu', local, 'Estilo')">Estilo</a></li>
#  <li class="menu-item menu-item-type-taxonomy menu-item-object-category current-menu-item menu-item-372798" id="menu-item-372798"><a href="https://www.istoedinheiro.com.br/categoria/economia/" onclick="track('menu', local, 'Economia')">Economia</a></li>
#  <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-382328" id="menu-item-382328"><a href="https://www.istoedinheiro.com.br/categoria/negocios/" onclick="track('menu', local, 'Negócios')">Negócios</a></li>
#  <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-372804" id="menu-item-372804"><a href="https://www.istoedinheiro.com.br/categoria/mercado-digital/" onclick="track('menu', local, 'Tecnologia')">Tecnologia</a></li>
#  <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-372802" id="menu-item-372802"><a href="https://www.istoedinheiro.com.br/categoria/financas/" onclick="track('menu', local, 'Finanças')">Finanças</a></li>
#  <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1169830" id="menu-item-1169830"><a href="https://www.istoedinheiro.com.br/categoria/giro/" onclick="track('menu', local, 'Giro')">Giro</a></li>
#  <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-382331" id="menu-item-382331"><a href="https://www.istoedinheiro.com.br/colunas/" onclick="track('menu', local, 'Colunistas')">Colunistas</a></li>
#  <hr>
#  <li>
#  <a href="https://www.istoedinheiro.com.br/busca" onclick="track('menu', local, 'buscar')" title="BUSCAR">BUSCAR</a>
#  </li>
#  <hr/>
#  </hr></ul>
#  <ul class="itens-menu menu-revista">
#  <li>
#  <a href="https://www.istoedinheiro.com.br/edicao/1315/" onclick="track('menu', local, 'revista')" title="Revista ISTOÉ">Revista ISTOÉ DINHEIRO</a>
#  </li>
#  <li>
#  <a href="https://www.istoedinheiro.com.br/edicoes" onclick="track('menu', local, 'edicoes-anteriores')" title="Edições anteriores">Edições anteriores</a>
#  </li>
#  <hr/>
#  </ul>
#  <ul class="itens-menu menu-social-media">
#  <div>
#  <li class="facebook">
#  <a href="https://www.facebook.com/revistaISTOE" onclick="track('menu', local, 'facebook')" target="_blank" title="Facebook da ISTOÉ">Facebook</a>
#  </li>
#  <li class="twitter">
#  <a href="https://twitter.com/RevistaISTOE" onclick="track('menu', local, 'twitter')" target="_blank" title="Twitter da ISTOÉ">Twitter</a>
#  </li>
#  </div>
#  <hr/>
#  </ul>
#  <ul class="itens-menu menu-revistas">
#  <li><a href="http://www.editora3.com.br/" onclick="track('menu', local, 'editora3')" target="_blank" title="">Editora 3</a></li>
#  <li><a href="https://istoe.com.br/" onclick="track('menu', local, 'istoe')" title="ISTOÉ">ISTOÉ</a></li>
#  <li><a href="https://www.istoedinheiro.com.br/" onclick="track('menu', local, 'dinheiro')" target="_blank" title="ISTOÉ Dinheiro">ISTOÉ Dinheiro</a></li>
#  <li><a href="https://www.dinheirorural.com.br/" onclick="track('menu', local, 'rural')" target="_blank" title="Dinheiro Rural">Dinheiro Rural</a></li>
#  <li><a href="https://www.revistamenu.com.br/" onclick="track('menu', local, 'menu')" target="_blank" title="Menu">Menu</a></li>
#  <li><a href="https://motorshow.com.br/" onclick="track('menu', local, 'motorshow')" target="_blank" title="Motorshow">Motorshow</a></li>
#  <li><a href="https://www.revistaplaneta.com.br/" onclick="track('menu', local, 'planeta')" target="_blank" title="Planeta">Planeta</a></li>
#  <li><a href="https://www.select.art.br/" onclick="track('menu', local, 'select')" target="_blank" title="Select">Select</a></li>
#  <li><a href="http://gooutside.com.br/" onclick="track('menu', local, 'gooutside')" target="_blank" title="Gooutside">Gooutside</a></li>
#  <li><a href="http://hardcore.uol.com.br" onclick="track('menu', local, 'hardcore')" target="_blank" title="Hardcore">Hardcore</a></li>
#  <li><a href="http://runnersworld.com.br/" onclick="track('menu', local, 'runners')" target="_blank" title="Runner's World">Runner's World</a></li>
#  <li><a href="http://revistawh.com.br/" onclick="track('menu', local, 'womens-healt')" target="_blank" title="Women's Health">Women's Health</a></li>
#  <hr/>
#  </ul>
#  </div>
#  </div>
#  <!-- .navbar-publishing-company -->
#  <nav class="menu-revistas">
#  <ul>
#  <li><a href="https://istoe.com.br/" onclick="track('header', local, 'istoe')" title="ISTOÉ">ISTOÉ</a></li>
#  <li class="active"><a href="https://www.istoedinheiro.com.br/" onclick="track('header', local, 'dinheiro')" style="background: #333333; padding: 4px; border-radius: 4px; color:white;" target="_blank" title="ISTOÉ Dinheiro">ISTOÉ Dinheiro</a></li>
#  <li><a href="https://www.dinheirorural.com.br/" onclick="track('header', local, 'rural')" target="_blank" title="Dinheiro Rural">Dinheiro Rural</a></li>
#  <li><a href="https://www.revistamenu.com.br/" onclick="track('header', local, 'menu')" target="_blank" title="Menu">Menu</a></li>
#  <li><a href="https://motorshow.com.br/" onclick="track('header', local, 'motorshow')" target="_blank" title="Motorshow">Motorshow</a></li>
#  <li><a href="https://www.revistaplaneta.com.br/" onclick="track('header', local, 'planeta')" target="_blank" title="Planeta">Planeta</a></li>
#  <li><a href="https://www.select.art.br/" onclick="track('header', local, 'select')" target="_blank" title="Select">Select</a></li>
#  <li><a href="http://gooutside.com.br/" onclick="track('header', local, 'gooutside')" target="_blank" title="Gooutside">Gooutside</a></li>
#  <li><a href="http://hardcore.com.br" onclick="track('header', local, 'hardcore')" target="_blank" title="Hardcore">Hardcore</a></li>
#  <li class="active link-assine"><a href="https://www.assine3.com.br/promocao/sitedinheiro?utm_source=sitedinheiro&amp;utm_medium=siteconteudo&amp;utm_campaign=campanhasites" onclick="track('header', local, 'assine')" style="background: #333333; padding: 4px; border-radius: 4px; color:white !important;" title="Assine">Assine</a></li>
#  <li class="active link-assine"><a href="https://istoe.com.br/anuncie/" onclick="track('header', local, 'anuncie')" style="background: #333333; padding: 4px; border-radius: 4px; color:white !important;" title="Anucie">Anuncie</a></li>
#  </ul>
#  </nav>
#  <div class="cabecalho" style="margin:0px auto 10px auto;">
#  <div class="cabecalho-col-1">
#  <div class="cabecalho-col-1-linha-1">
#  <div class="cabecalho-redes-sociais">
#  <a class="link-icon icon-menu c" href="javascript:;" onclick="track('header', local, 'menu-open')" title="">
#  <svg height="15px" version="1.1" viewbox="-1003 1573 24 15" width="24px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs></defs>
#  <rect fill="#D0011B" fill-rule="evenodd" height="3" id="Rectangle-1-Copy-29" stroke="none" width="24" x="-1003" y="1573"></rect>
#  <rect fill="#D0011B" fill-rule="evenodd" height="3" id="Rectangle-1-Copy-41" stroke="none" width="24" x="-1003" y="1585"></rect>
#  <rect fill="#D0011B" fill-rule="evenodd" height="3" id="Rectangle-1-Copy-42" stroke="none" width="24" x="-1003" y="1579"></rect>
#  </svg>
#  </a>
#  <a class="link-icon icon-facebook" href="https://www.facebook.com/istoedinheiro" onclick="track('header', local, 'facebook')" target="_blank" title="Facebook">
#  <svg height="20px" version="1.1" viewbox="-956 1571 10 20" width="10px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs></defs>
#  <path d="M-949.79464,1591 L-949.79464,1580.99883 L-947.03388,1580.99883 L-946.668019,1577.55237 L-949.79464,1577.55237 L-949.78995,1575.82738 C-949.78995,1574.92849 -949.704543,1574.44685 -948.413478,1574.44685 L-946.687563,1574.44685 L-946.687563,1571 L-949.448715,1571 C-952.765302,1571 -953.932654,1572.6719 -953.932654,1575.48352 L-953.932654,1577.55276 L-956,1577.55276 L-956,1580.99922 L-953.932654,1580.99922 L-953.932654,1591 L-949.79464,1591 Z" fill="#D00018" fill-rule="evenodd" id="Path-Copy-29" stroke="none"></path>
#  </svg>
#  </a>
#  <a class="link-icon icon-twitter" href="https://twitter.com/RevistaDinheiro" onclick="track('header', local, 'twitter')" target="_blank" title="Twitter">
#  <svg height="20px" version="1.1" viewbox="-927 1571 24 20" width="24px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs></defs>
#  <path d="M-915.346631,1576.276 L-915.294607,1577.13385 L-916.161673,1577.0288 C-919.317794,1576.62614 -922.075064,1575.26058 -924.416143,1572.96714 L-925.56067,1571.82918 L-925.855473,1572.66952 C-926.47976,1574.54279 -926.08091,1576.5211 -924.780311,1577.85164 C-924.086658,1578.58694 -924.24273,1578.69199 -925.439281,1578.25431 C-925.855473,1578.11425 -926.21964,1578.00921 -926.254323,1578.06173 C-926.375712,1578.18428 -925.959521,1579.77743 -925.630035,1580.40769 C-925.179161,1581.28304 -924.260071,1582.1409 -923.254274,1582.6486 L-922.404549,1583.05127 L-923.410346,1583.06878 C-924.38146,1583.06878 -924.416143,1583.08628 -924.312095,1583.45393 C-923.965268,1584.5919 -922.595304,1585.79989 -921.069267,1586.32511 L-919.994105,1586.69276 L-920.930
https://www.istoedinheiro.com.br/wp-content/themes/tema_dinheiro/assets/svg/logo-dinheiro-1280-v20.svg"/>
#  </a>
#  </div>
#  <div class="edicao-atual">
#  <a class="link-edicao-atual" href="https://www.istoedinheiro.com.br/edicao/1315/" onclick="track('header', local, 'edicao')" title="Edição nº 1315 - Mulheres &amp; poder">Edição nº 1315  10.03</a>
#  </div>
#  <a class="assine-menu-pequeno" href="https://www.assine3.com.br/promocao/sitedinheiro?utm_source=sitedinheiro&amp;utm_medium=siteconteudo&amp;utm_campaign=campanhasites" onclick="track('header', local, 'assine')" title="Assine">Assine</a>
#  </div>
#  <div class="cabecalho-col-1-linha-2">
#  <ul class="menu-do-site">
#  <li><a href="https://www.istoedinheiro.com.br/ultimas" onclick="track('header', local, 'ultimas')">Últimas</a></li>
#  <li><a href="https://www.istoedinheiro.com.br/categoria/live-da-dinheiro/" onclick="track('header', local, 'lives')">Lives</a></li>
#  <li><a href="https://www.istoedinheiro.com.br/edicao/1315/" onclick="track('header', local, 'revista')">Revista</a></li>
#  <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-2606363"><a href="https://www.istoedinheiro.com.br/categoria/black-friday/" onclick="track('header', local, 'Black Friday')">Black Friday</a></li>
#  <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-2524894"><a href="https://www.istoedinheiro.com.br/categoria/estilo/" onclick="track('header', local, 'Estilo')">Estilo</a></li>
#  <li class="menu-item menu-item-type-taxonomy menu-item-object-category current-menu-item menu-item-372798"><a href="https://www.istoedinheiro.com.br/categoria/economia/" onclick="track('header', local, 'Economia')">Economia</a></li>
#  <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-382328"><a href="https://www.istoedinheiro.com.br/categoria/negocios/" onclick="track('header', local, 'Negócios')">Negócios</a></li>
#  <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-372804"><a href="https://www.istoedinheiro.com.br/categoria/mercado-digital/" onclick="track('header', local, 'Tecnologia')">Tecnologia</a></li>
#  <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-372802"><a href="https://www.istoedinheiro.com.br/categoria/financas/" onclick="track('header', local, 'Finanças')">Finanças</a></li>
#  <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1169830"><a href="https://www.istoedinheiro.com.br/categoria/giro/" onclick="track('header', local, 'Giro')">Giro</a></li>
#  <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-382331"><a href="https://www.istoedinheiro.com.br/colunas/" onclick="track('header', local, 'Colunistas')">Colunistas</a></li>
#  </ul>
#  <a class="icone-de-busca2" href="/busca">
#  <img class="buscar2" src="https://www.istoedinheiro.com.br/wp-content/themes/tema_dinheiro/assets/svg/busca.svg"/>
#  </a>
#  </div>
#  </div>
#  <div class="cabecalho-col-2">
#  <a href="https://www.istoedinheiro.com.br/edicao/1315/" onclick="track('ultima-edicao-mobile', local, 'imagem-da-capa');" title="Edição nº 1315 - Mulheres &amp; poder">
#  <img src="https://www.istoedinheiro.com.br/wp-content/uploads/sites/17/2023/03/assinante-1-147x196.jpg"/>
#  </a>
#  </div>
#  <hr/>
#  </div>
#  <!-- .ad-bar-header -->
#  <div class="ad-bar-header" style="padding-top:0;">
#  <div class="banner_super_topo" id="topinterna">
#  <script type="text/javascript">
#  		googletag.cmd.push(function() { googletag.display('topinterna'); });
#  		</script>
#  </div>
#  </div>
#  <!-- ./ad-bar-header -->
#  <!-- CABECALHO FIXO PEQUENO -->
#  <div class="cabecalho-min">
#  <div class="cabecalho-col-1">
#  <div class="cabecalho-col-1-linha-1">
#  <div class="cabecalho-redes-sociais">
#  <a class="link-icon icon-menu c" href="javascript:;" onclick="track('header', local, 'menu-open')" title="">
#  <svg height="15px" version="1.1" viewbox="-1003 1573 24 15" width="24px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs></defs>
#  <rect fill="#D0011B" fill-rule="evenodd" height="3" id="Rectangle-1-Copy-29" stroke="none" width="24" x="-1003" y="1573"></rect>
#  <rect fill="#D0011B" fill-rule="evenodd" height="3" id="Rectangle-1-Copy-41" stroke="none" width="24" x="-1003" y="1585"></rect>
#  <rect fill="#D0011B" fill-rule="evenodd" height="3" id="Rectangle-1-Copy-42" stroke="none" width="24" x="-1003" y="1579"></rect>
#  </svg>
#  </a>
#  </div>
#  <div class="logo-do-site">
#  <a class="magazine" href="https://www.istoedinheiro.com.br/" onclick="track('header', local, 'logo')" title="">
#  <img src="https://www.istoedinheiro.com.br/wp-content/themes/tema_dinheiro/assets/svg/logo-dinheiro-mob-v20.svg"/>
#  </a>
#  </div>
#  <a class="assine-menu-pequeno" href="https://www.assine3.com.br/promocao/sitedinheiro?utm_source=sitedinheiro&amp;utm_medium=siteconteudo&amp;utm_campaign=campanhasites" onclick="track('header', local, 'assine')" style="background: #333333; padding: 4px; border-radius: 4px; color:white !important;" title="Assine">Assine</a>
#  </div>
#  </div>
#  <hr/>
#  </div>
#  <!-- FIM DO CABECALHO FIXO PEQUENO -->
#  <!-- From header render in 0.02647 seconds --> <div class="general">
#  <div class="c_container">
#  <header>
#  <div class="c-header">
#  <h1>Economia</h1>
#  </div>
#  </header>
#  <section class="c-destaques">
#  <div class="c-destaque-principal">
#  <div class="share-content-top"></div>
# ...
#  <p>O presidente da Câmara dos Deputados, Arthur Lira (Progressistas-AL), afirmou na noite da quarta-feira, 15, em entrevista à GloboNews, que é contra uma parte da Lei das Estatais. A legislação impede a indicação de membros de partidos políticos ou participantes de campanhas eleitorais para cargos de direção em empresas públicas. Segundo Lira, o ponto que […]</p>
#  <time class="c-data" datetime="2023-03-16 08:55">16/03/2023 08:55</time>
#  </a>
#  <div class="share-post-mb"></div>
#  </div>
#  </div>
#  </article>
#  <article class="thumb">
#  <div class="bloco-noticias-share-post share-noticias-no-image">
#  </div>
#  <div class="row">
#  <div class="wrapper-image">
#  <!--<a href="" title="" class="link-category link-cat-mob">Mundo</a>-->
#  <a class="c-container-img" href="https://www.istoedinheiro.com.br/igp-10-avanca-em-marco-e-taxa-em-12-meses-tem-menor-nivel-em-5-anos/" title="IGP-10 avança em março e taxa em 12 meses tem menor nível em 5 anos, diz FGV">
#  <img alt="" src="https://www.istoedinheiro.com.br/wp-content/uploads/sites/17/2023/03/20052020supermercado-rio-de-janeiro-0520203149-418x235.jpg" title="IGP-10 avança em março e taxa em 12 meses tem menor nível em 5 anos, diz FGV"/>
#  </a>
#  </div>
#  <div class="wrapper-title">
#  <h3>
#  <a href="https://www.istoedinheiro.com.br/igp-10-avanca-em-marco-e-taxa-em-12-meses-tem-menor-nivel-em-5-anos/" title="IGP-10 avança em março e taxa em 12 meses tem menor nível em 5 anos, diz FGV">IGP-10 avança em março e taxa em 12 meses tem menor nível em 5 anos, diz FGV</a>
#  </h3>
#  <a class="description" href="https://www.istoedinheiro.com.br/igp-10-avanca-em-marco-e-taxa-em-12-meses-tem-menor-nivel-em-5-anos/" title="IGP-10 avança em março e taxa em 12 meses tem menor nível em 5 anos, diz FGV">
#  <p>SÃO PAULO (Reuters) – O Índice Geral de Preços-10 (IGP-10) registrou avanço de 0,05% em março, em meio à queda nos preços ao produtor e desaceleração da alta ao consumidor, com o acumulado em 12 meses indo ao menor patamar em cinco anos. A leitura mensal do indicador divulgada nesta quinta-feira pela Fundação Getulio Vargas […]</p>
#  <time class="c-data" datetime="2023-03-16 08:33">16/03/2023 08:33</time>
#  </a>
#  <div class="share-post-mb"></div>
#  </div>
#  </div>
#  </article>
#  <article class="thumb no-image">
#  <div class="bloco-noticias-share-post share-noticias-no-image">
#  </div>
#  <div class="row">
#  <div class="wrapper-title no-image">
#  <h3>
#  <a href="https://www.istoedinheiro.com.br/igp-10-de-marco-sobe-005-ante-alta-de-002-em-fevereiro-mostra-fgv/" title="IGP-10 de março sobe 0,05% ante alta de 0,02% em fevereiro, mostra FGV">IGP-10 de março sobe 0,05% ante alta de 0,02% em fevereiro, mostra FGV</a>
#  </h3>
#  <a class="description" href="https://www.istoedinheiro.com.br/igp-10-de-marco-sobe-005-ante-alta-de-002-em-fevereiro-mostra-fgv/" title="IGP-10 de março sobe 0,05% ante alta de 0,02% em fevereiro, mostra FGV">
#  <p>O Índice Geral de Preços – 10 (IGP-10) subiu 0,05% em março, após a alta de 0,02% em fevereiro, informou a Fundação Getulio Vargas (FGV) nesta quinta-feira, 16. O resultado ficou dentro das estimativas dos analistas do mercado financeiro ouvidos pelo Projeções Broadcast, que esperavam desde uma queda de 0,15% a aumento de 0,18%, com […]</p>
#  <time class="c-data" datetime="2023-03-16 08:23">16/03/2023 08:23</time>
#  </a>
#  <div class="share-post-mb"></div>
#  </div>
#  </div>
#  </article>
#  <article class="thumb">
#  <div class="bloco-noticias-share-post share-noticias-no-image">
#  </div>
#  <div class="row">
#  <div class="wrapper-image">
#  <!--<a href="" title="" class="link-category link-cat-mob">Mundo</a>-->
#  <a class="c-container-img" href="https://www.istoedinheiro.com.br/processamento-de-soja-na-2/" title="Processamento de soja na Argentina entra em crise com ameaça da seca, diz indústria">
#  <img alt="" src="https://www.istoedinheiro.com.br/wp-content/uploads/sites/17/Reuters_Direct_Media/BrazilOnlineReportAgribusinessNews/tagreuters.com2023binary_LYNXMPEJ2F0GL-BASEIMAGE-418x235.jpg" title="Processamento de soja na Argentina entra em crise com ameaça da seca, diz indústria"/>
#  </a>
#  </div>
#  <div class="wrapper-title">
#  <h3>
#  <a href="https://www.istoedinheiro.com.br/processamento-de-soja-na-2/" title="Processamento de soja na Argentina entra em crise com ameaça da seca, diz indústria">Processamento de soja na Argentina entra em crise com ameaça da seca, diz indústria</a>
#  </h3>
#  <a class="description" href="https://www.istoedinheiro.com.br/processamento-de-soja-na-2/" title="Processamento de soja na Argentina entra em crise com ameaça da seca, diz indústria">
#  <p>Por Maximilian Heath BUENOS AIRES (Reuters) – As plantas de esmagamento de soja da Argentina estão operando com a capacidade mais baixa da história devido ao impacto de uma seca brutal, disse o líder da principal câmara de processamento de grãos do país na quarta-feira. A Argentina, maior exportador mundial de farelo de soja e […]</p>
#  <time class="c-data" datetime="2023-03-16 08:20">16/03/2023 08:20</time>
#  </a>
#  <div class="share-post-mb"></div>
#  </div>
#  </div>
#  </article>
#  <article class="thumb">
#  <div class="bloco-noticias-share-post share-noticias-no-image">
#  </div>
#  <div class="row">
#  <div class="wrapper-image">
#  <!--<a href="" title="" class="link-category link-cat-mob">Mundo</a>-->
#  <a class="c-container-img" href="https://www.istoedinheiro.com.br/eua-vao-lancar-o-fednow-para-pagamentos-instantaneos/" title="EUA vão lançar o FedNow para pagamentos instantâneos">
#  <img alt="" src="https://www.istoedinheiro.com.br/wp-content/uploads/sites/17/2023/03/fednow-e1678967759601.jpg" title="EUA vão lançar o FedNow para pagamentos instantâneos"/>
#  </a>
#  </div>
#  <div class="wrapper-title">
#  <h3>
#  <a href="https://www.istoedinheiro.com.br/eua-vao-lancar-o-fednow-para-pagamentos-instantaneos/" title="EUA vão lançar o FedNow para pagamentos instantâneos">EUA vão lançar o FedNow para pagamentos instantâneos</a>
#  </h3>
#  <a class="description" href="https://www.istoedinheiro.com.br/eua-vao-lancar-o-fednow-para-pagamentos-instantaneos/" title="EUA vão lançar o FedNow para pagamentos instantâneos">
#  <p>O Federal Reserve (Fed, o banco central dos Estados Unidos) informou nesta quarta, 15, que vai lançar o seu sistema de pagamentos instantâneos, o FedNow, em julho. Anunciada em 2019, a ferramenta – uma espécie de Pix americano – estava em testes desde setembro do ano passado, e agora entra na reta final de ajustes. […]</p>
#  <time class="c-data" datetime="2023-03-16 08:18">16/03/2023 08:18</time>
#  </a>
#  <div class="share-post-mb"></div>
#  </div>
#  </div>
#  </article>
#  <article class="thumb no-image">
#  <div class="bloco-noticias-share-post share-noticias-no-image">
#  </div>
#  <div class="row">
#  <div class="wrapper-title no-image">
#  <h3>
#  <a href="https://www.istoedinheiro.com.br/modelo-do-banco-central-independente-e-adequado-e-correto-diz-lira/" title="Modelo do Banco Central independente é adequado e correto, diz Lira">Modelo do Banco Central independente é adequado e correto, diz Lira</a>
#  </h3>
#  <a class="description" href="https://www.istoedinheiro.com.br/modelo-do-banco-central-independente-e-adequado-e-correto-diz-lira/" title="Modelo do Banco Central independente é adequado e correto, diz Lira">
#  <p>O presidente da Câmara dos Deputados, Arthur Lira (Progressistas-AL), elogiou na noite da quarta-feira, 15, o modelo do Banco Central independente. Lira também disse que o momento atual exige um “armistício”, em referência às tensões entre o governo e a autoridade monetária. “Já coloquei publicamente que o modelo do BC independente é adequado e correto. […]</p>
#  <time class="c-data" datetime="2023-03-16 08:10">16/03/2023 08:10</time>
#  </a>
#  <div class="share-post-mb"></div>
#  </div>
#  </div>
#  </article>
#  <div class="box_paginacao"><ul class="page-numbers">
#  <li><a class="prev page-numbers" href="https://www.istoedinheiro.com.br/categoria/economia/page/3/"></a></li>
#  <li><a class="page-numbers" href="https://www.istoedinheiro.com.br/categoria/economia/page/1/">1</a></li>
#  <li><a class="page-numbers" href="https://www.istoedinheiro.com.br/categoria/economia/page/2/">2</a></li>
#  <li><a class="page-numbers" href="https://www.istoedinheiro.com.br/categoria/economia/page/3/">3</a></li>
#  <li><span aria-current="page" class="page-numbers current">4</span></li>
#  <li><a class="page-numbers" href="https://www.istoedinheiro.com.br/categoria/economia/page/5/">5</a></li>
#  <li><a class="page-numbers" href="https://www.istoedinheiro.com.br/categoria/economia/page/6/">6</a></li>
#  <li><span class="page-numbers dots">…</span></li>
#  <li><a class="page-numbers" href="https://www.istoedinheiro.com.br/categoria/economia/page/20446/">20.446</a></li>
#  <li><a class="next page-numbers" href="https://www.istoedinheiro.com.br/categoria/economia/page/5/"></a></li>
#  </ul>
#  </div> </div>
#  <aside>
#  <div id="arroba" style="margin:25px auto;width:300px">
#  <script type="text/javascript">
#  					googletag.cmd.push(function() { googletag.display('arroba'); });
#  					</script>
#  </div>
#  <!--<section class="section-home block-section-popular c-section-popular">
#  						<div class="content-section">
#  							<header>
#  								<div class="c-header">
#  									<hr>
#  									<h1>Mais lidas</span></h1>
#  								</div>
#  							</header>
#  							<div class="tabs">
#  								<div class="tab tab-1 active">
#  																	</div>
#  							</div>
#  						</div>
#  					</section>-->
#  <!--
#  								<script>
#  					jQuery(document).ready(function() {
#  						jQuery('aside, .c-conteudo')
#  							.theiaStickySidebar({
#  								additionalMarginTop: 60
#  							});
#  					});
#  				</script>
#  								-->
#  </aside>
#  </div>
#  </div>
#  <footer>
#  <div class="separador-bloco"></div>
#  <!-- .container-subscribe -->
#  <!-- /sticky -->
#  <!-- .container-credits -->
#  <div class="container-credits">
#  <div class="content-credits">
#  <div class="credits">
#  <img alt="" src="https://www.istoedinheiro.com.br/wp-content/themes/revistas_3/assets/svg/editora-3.svg" title=""/>
#  <p>
#  					Copyright ©2023 - Três Editorial Ltda.<br/>
#  					Todos os direitos reservados.
#  				</p>
#  </div>
#  <div class="credits" style="margin-top:25px;">
#  <p style="font-size:10px"><strong>Nota de esclarecimento:</strong>
#  		A Três Comércio de Publicações Ltda., empresa responsável pela comercialização das revistas da Três Editorial, informa aos seus consumidores que não realiza cobranças e que também não oferece o cancelamento do contrato de assinatura mediante o pagamento de qualquer valor, tampouco autoriza terceiros a fazê-lo.  A empresa não se responsabiliza por tais mensagens e cobranças.
#                  	</p></div>
#  </div>
#  </div>
#  <!-- ./container-credits -->
#  <script async="" data-pn-plugin-url="https://www.istoedinheiro.com.br/wp-content/plugins/pushnews/" data-pn-wp-plugin-version="3.6.2" src="https://cdn.pn.vg/sites/7f519def-bd8e-4a5f-8960-5c9d648a175d.js" type="text/javascript"></script><script id="istoe-main-js-extra" type="text/javascript">
#  /* <![CDATA[ */
#  var ajax_object = {"ajax_url":"https:\/\/www.istoedinheiro.com.br\/wp-admin\/admin-ajax.php"};
#  /* ]]> */
#  </script>
#  <script id="istoe-main-js" src="https://www.istoedinheiro.com.br/wp-content/themes/revistas_3/assets/js/build/all.js?ver=9.0.3" type="text/javascript"></script>
#  <script id="embedpress-front-js" src="https://www.istoedinheiro.com.br/wp-content/plugins/embedpress/assets/js/front.js?ver=2.7.6" type="text/javascript"></script>
#  <script id="child-js-js" src="https://www.istoedinheiro.com.br/wp-content/themes/tema_dinheiro/assets/js/main.js" type="text/javascript"></script>
#  </footer>
#  <script async="true" class="teads" src="//a.teads.tv/page/78111/tag" type="text/javascript"></script>
#  <script>
#  //append target blank to all external links
#  jQuery( document ).ready(function( $ ) {
#  	$('a').each(function() {
#  	   var a = new RegExp('/' + window.location.host + '/');
#  	   if (!a.test(this.href) && (this.href != 'javascript:;')) {
#  		  $(this).attr("target","_blank");
#  	   }
#  	});
#  });
#  </script>
#  <style>
#  @media screen and (max-width: 782px) {
#  #stickybanner {
#  position: fixed;
#  text-align:center;
#  bottom: 0px;
#  width:100%;
#  z-index:999;
#  background: rgba(0,0,0,.7);
#  }
#  }
#  </style>
#  <div id="stickybanner">
#  <script type="text/javascript">
#  if (width < 768) {
#  googletag.cmd.push(function() { googletag.display('stickybanner'); });
#  }
#  </script>
#  </div>
#  <!--BEGIN FIRSTIMPRESSION TAG - istoedinheiro -->
#  <script data-cfasync="false" type="text/javascript">
#      ;(function(o) {
#          var w=window.top,a='apdAdmin',ft=w.document.getElementsByTagName('head')[0],
#          l=w.location.href,d=w.document;w.apd_options=o;
#          if(l.indexOf('disable_fi')!=-1) { console.error('disable_fi has been detected in URL. FI functionality is disabled for this page view.'); return; }
#          var fiab=d.createElement('script'); fiab.type = 'text/javascript';
#          fiab.src=o.scheme+'ecdn.analysis.fi/static/js/fab.js';fiab.id='fi-'+o.websiteId;
#          ft.appendChild(fiab, ft);if(l.indexOf(a)!=-1) w.localStorage[a]=1; var aM = w.localStorage[a]==1, fi=d.createElement('script');
#          fi.type='text/javascript'; fi.async=true; if(aM) fi['data-cfasync']='false';
#          fi.src=o.scheme+(aM?'cdn':'ecdn') + '.firstimpression.io/' + (aM ? 'fi.js?id='+o.websiteId : 'fi_client.js');
#          ft.appendChild(fi);
#      })({
#          'websiteId': 8041,
#          'scheme':    '//'
#      });
#  </script>
#  <!-- END FIRSTIMPRESSION TAG -->
#  <!-- Adops / Adsensor -->
#  <script src="//wfpscripts.webspectator.com/bootstrap/ws-LARMX9YH.js" type="text/javascript"></script>
#  <!-- taller/speedcurve -->
#  <script>LUX=(function(){var a=("undefined"!==typeof(LUX)&&"undefined"!==typeof(LUX.gaMarks)?LUX.gaMarks:[]);var d=("undefined"!==typeof(LUX)&&"undefined"!==typeof(LUX.gaMeasures)?LUX.gaMeasures:[]);var j="LUX_start";var k=window.performance;var l=("undefined"!==typeof(LUX)&&LUX.ns?LUX.ns:(Date.now?Date.now():+(new Date())));if(k&&k.timing&&k.timing.navigationStart){l=k.timing.navigationStart}function f(){if(k&&k.now){return k.now()}var o=Date.now?Date.now():+(new Date());return o-l}function b(n){if(k){if(k.mark){return k.mark(n)}else{if(k.webkitMark){return k.webkitMark(n)}}}a.push({name:n,entryType:"mark",startTime:f(),duration:0});return}function m(p,t,n){if("undefined"===typeof(t)&&h(j)){t=j}if(k){if(k.measure){if(t){if(n){return k.measure(p,t,n)}else{return k.measure(p,t)}}else{return k.measure(p)}}else{if(k.webkitMeasure){return k.webkitMeasure(p,t,n)}}}var r=0,o=f();if(t){var s=h(t);if(s){r=s.startTime}else{if(k&&k.timing&&k.timing[t]){r=k.timing[t]-k.timing.navigationStart}else{return}}}if(n){var q=h(n);if(q){o=q.startTime}else{if(k&&k.timing&&k.timing[n]){o=k.timing[n]-k.timing.navigationStart}else{return}}}d.push({name:p,entryType:"measure",startTime:r,duration:(o-r)});return}function h(n){return c(n,g())}function c(p,o){for(i=o.length-1;i>=0;i--){var n=o[i];if(p===n.name){return n}}return undefined}function g(){if(k){if(k.getEntriesByType){return k.getEntriesByType("mark")}else{if(k.webkitGetEntriesByType){return k.webkitGetEntriesByType("mark")}}}return a}return{mark:b,measure:m,gaMarks:a,gaMeasures:d}})();LUX.ns=(Date.now?Date.now():+(new Date()));LUX.ac=[];LUX.cmd=function(a){LUX.ac.push(a)};LUX.init=function(){LUX.cmd(["init"])};LUX.send=function(){LUX.cmd(["send"])};LUX.addData=function(a,b){LUX.cmd(["addData",a,b])};LUX_ae=[];window.addEventListener("error",function(a){LUX_ae.push(a)});LUX_al=[];if("function"===typeof(PerformanceObserver)&&"function"===typeof(PerformanceLongTaskTiming)){var LongTaskObserver=new PerformanceObserver(function(c){var b=c.getEntries();for(var a=0;a<b.length;a++){var d=b[a];LUX_al.push(d)}});try{LongTaskObserver.observe({type:["longtask"]})}catch(e){}};</script><script async="" crossorigin="anonymous" defer="" src="https://cdn.speedcurve.com/js/lux.js?id=4156354880"></script>
#  </div>
#  <script>
#  googletag.pubads().defineOutOfPagePassback('/22452847/IEDinheiro_Internas/economia')
#  .setTargeting('pos', ['dhtml'])
#  .display();
#  </script>
#  </body>
#  </html>]

# %% [markdown]
# ## Magazine Luiza
#
# Iremos utilizar o BeautifulSoup para extrair informações sobre produtos de um site do varejo brasileiro!
#
# Vamos descobrir como funciona o site da Magazine Luiza? Iremos acessar https://www.magazineluiza.com.br. Após acessar o site, clique com o botão direito do mouse e selecione **Inspecionar Elemento**.
#
# Faça uma busca no site utilizando algum termo como **'smartphone 128gb'**.
#
# Tente inspecionar vários elementos até encontrar padrões:
# - Onde está a **lista de produtos** retornada pela busca?
# - Como obter do produto:
#     - A **descrição**
#     - O **preço**
#     - A URL da **imagem**
#     - Etc.

# %% [markdown]
# ### Arquivos `robots.txt`
#
# Os sites costumam deixar no arquivo robots.txt as informações de boas práticas de web **crawling** e **scraping**.
#
# Vamos conferir o robots.txt da Magazine Luiza?
#
# Acesse https://www.magazineluiza.com.br/robots.txt ou faça um requests.
#
# Acesse https://developers.google.com/search/docs/advanced/robots/create-robots-txt?hl=pt-br para saber mais.

# %% [markdown]
# ### User-agent
#
# Alguns sites bloqueiam requisições identificadas como não realizadas por usuários em navegadores. Para prevenir bloqueios e extrair informações destes sites, uma prática é criar um cabeçalho com **User-Agent**.

# %%
# headers = ({'User-Agent':
#             'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.103 Safari/537.36'})

headers = {
     'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.35 (KHTML, like Gecko) Chrome/75.0.3770.142 Safari/537.35'
}

# %% [markdown]
# Você também pode alterar o **User-Agent** a cada nova requisição. O cabeçalho também pode ter informações de login por exemplo, mas isso foge do escopo da disciplina!

# %% [markdown]
# ### Buscando um produto
#
# Vamos acessar o site https://www.magazineluiza.com.br e realizar a busca manual por algum produto.
#
# Digite algo no campo de busca e realize a busca. Observe que a URL irá ser alterada e conter os seus termos de busca.
#
# Edite a URL diretamente para realizar a busca por outros produtos (direto na barra de endereços do navegador ao invés de utilizar o campo de buscas do site).

# %% [markdown]
# Alguns exemplos de busca:
#
# - https://www.magazineluiza.com.br/busca/smartphone+128gb/
# - https://www.magazineluiza.com.br/busca/smartphone+256gb/

# %%
url = 'https://www.magazineluiza.com.br/busca/smartphone+128gb/'

resposta = requests.get(url=url, headers=headers)

resposta.encoding = 'utf-8'

resposta.text

# %%
resposta.request.headers

# %% [markdown]
# Conferindo o código de resposta

# %%
print('Código de status da resposta: {}'.format(resposta.status_code))

# %% [markdown]
# e o texto de resposta

# %%
print('Texto de resposta:')
print(resposta.text)

# %% [markdown]
# Podemos verificar se a o texto de resposta possui algum termo com

# %%
'128GB' in resposta.text

# %% [markdown]
# Vamos criar um soup para conseguir extrair informações a partir do HTML

# %%
soup = BeautifulSoup(resposta.text, 'html.parser')

# %% [markdown]
# Qual a tag que identifica um produto? Vamos procurar o primeiro produto da lista

# %%
lista_prod = soup.find('div', attrs={'data-testid': 'mod-productlist'})
lista_prod

# %%
tag_produto = lista_prod.find('li')
tag_produto

# %% [markdown]
# Como podemos extrair a Descrição?

# %%
desc_produto = tag_produto.find(#SEU CODIGO AQUI!)
desc_produto.text

# %% [markdown]
# E para extrair o Preço?

# %%
preco_produto = tag_produto.find(#SEU CODIGO AQUI!)
print(preco_produto.text)

# %% [markdown]
# ### Procurando por todos os produtos
#
# Vamos extrair a lista de produtos (suas tags) e iterar sobre elas para extrair informações de vários produtos. Por enquanto, considere a extração das duas primeiras linhas de informação no site (oito produtos).

# %%
lista_prod = soup.find('div', attrs={'data-testid': 'mod-productlist'})
lista_tag_produto = lista_prod.find_all('li')

# %%
qt_prod = len(lista_tag_produto)
qt_prod

# %%
lista_desc = []
lista_preco = []
for i in range(8):
    tag_produto = lista_tag_produto[i]

    desc_produto = tag_produto.#SEU CODIGO AQUI!
    lista_desc.append(desc_produto.text)

    preco_produto = tag_produto.#SEU CODIGO AQUI!

    if preco_produto == None:
        preco_produto = None
    else:    
        preco_clean = preco_produto.text.replace('\n', '')
        preco_clean = preco_clean.strip()
        preco_clean = preco_clean.replace('R$', '')
        preco_clean = preco_clean.replace(".", "").replace(",", ".")
        preco_clean = float(preco_clean)
    
    lista_preco.append(preco_clean)

    
lista_preco

# %%
tag_produto

# %%
lista_desc

# %% [markdown]
# #### Criar DataFrame
#
# Então, podemos facilmente transformar as listas extraídas em um DataFrame do pandas

# %%
busca = 'smarpthone 64GB'
df = pd.DataFrame({'Busca': busca,
                   'Descrição': lista_desc,
                   'Preço': lista_preco
                  })
df

# %% [markdown]
# ## Criando funções
#
# Vamos criar funções para fazer uma busca, tratar os dados obter um DataFrame.
#
# Função que pesquisa por um termo no site e retorna o HTML como um texto

# %%
def pesquisa(termo):
    
    s1 = random.randint(1,40)
    s2 = random.randint(1,140)
    
    headers = {
         'user-agent': f'Mozilla/5.0  (Windows NT 10.0; Win64; x64) AppleWebKit/537.{s1} (KHTML, like Gecko) Chrome/75.0.3770.{s2} Safari/537.{s1}'
    }
    
    url = f'https://www.magazineluiza.com.br/busca/smartphone+{termo}/'
    
    time.sleep(abs(random.gauss(2,1)))

    resposta = requests.get(url = url, headers=headers)

    resposta.encoding = 'utf-8'

    return resposta.text

# %% [markdown]
# Função que processa o HTML e extrai a descrição, preço e demais informações necessárias

# %%
def processa(resposta, qtde_produto):
    
    soup = BeautifulSoup(resposta, 'html.parser')
    
    lista_prod = #SEU CODIGO AQUI!
    lista_tag_produto = lista_prod.find_all('li')
    
    lista_desc = []
    lista_preco = []
    lista_ranking = []
    
    for i in range(qtde_produto):
        tag_produto = lista_tag_produto[i]
        desc_produto = #SEU CODIGO AQUI!
        lista_desc.append(desc_produto.text)

        preco_produto = #SEU CODIGO AQUI!

        if preco_produto == None:
            preco_produto = None
        else:    
            preco_clean = preco_produto.text.replace('\n', '')
            preco_clean = preco_clean.strip()
            preco_clean = preco_clean.replace('R$', '')
            preco_clean = preco_clean.replace(".", "").replace(",", ".")
            preco_clean = float(preco_clean)

        lista_preco.append(preco_clean)
        
        lista_ranking.append(i+1)
        
    return lista_desc, lista_preco, lista_ranking

# %% [markdown]
# Função que gera um DataFrame a partir de listas de informações dos produtos

# %%
def gera_df(termo, lista_desc, lista_preco, lista_ranking):
    df = pd.DataFrame({'Pesquisa': termo,
                       'Ranking': lista_ranking,
                       'Descrição': lista_desc,
                       'Preço': lista_preco
                      })
    return df

# %% [markdown]
# Função para chamar as demais funções e retornar um DataFrame

# %%
def pesquisa_estruturada(termo, qtde_produto):
    texto = pesquisa(termo)
    lista_desc, lista_preco, lista_ranking = processa(texto, qtde_produto)
    return gera_df(termo, lista_desc, lista_preco, lista_ranking)

# %%
df = pesquisa_estruturada('64gb', 8)
df

# %% [markdown]
# Como concatenar DataFrames para juntar o resultado de diversas buscas?

# %%
pd.concat([pesquisa_estruturada('64gb', 4), pesquisa_estruturada('128gb', 4)])

# %% [markdown]
# Então, podemos criar uma função que recebe uma lista de termos de busca, efetua a pesquisa de cada termo e junta os DataFrames ao final!

# %%
def multi_pesquisa(lista_busca, qtde_produto):
    time.sleep(random.randint(3,6))
    lista_df = []
    for termo in lista_busca:
        df = pesquisa_estruturada(termo, qtde_produto)
        lista_df.append(df)
        time.sleep(0.5)
    df_full = pd.concat(lista_df)
    return df_full.reset_index(drop=True)

# %%
# Termos a serem pesquisados
lista_busca = ['32Gb', '64Gb', '128Gb', '256Gb']

df = multi_pesquisa(lista_busca, 50)
df.head()

# %%
df.tail()

# %%
df

# %% [markdown]
# # Exercícios
#
# Utilizando os dados obtidos no Magalu:
#
# **Exercício 4)** Calcule o preço médio produtos:
#
# a) Geral

# %%
#SEU CODIGO AQUI!

# %% [markdown]
# b) Por termo de busca
#
# Dica: groupby

# %%
#SEU CODIGO AQUI!

# %% [markdown]
# a) Os preços médios obtidos fazem sentido?

# %% [markdown]
# R:

# %% [markdown]
# b) Produza um gráfico de barras com os preços médios

# %%
#SEU CODIGO AQUI!

# %% [markdown]
# **Exercício 5)** Crie uma coluna que informe se o produto é de cor discreta ou não.
#
# Dica: pesquise pelos termos *black*, *preto*, *gray*, *branco*, etc.

# %%
#SEU CODIGO AQUI!

# %% [markdown]
# a) Compare o preço médio dos produtos que são e não são de cor discreta.

# %%
#SEU CODIGO AQUI!

# %% [markdown]
# **Exercício 6)** Conte quantos produtos são das marcas **Samsung**, **Motorola** e **LG**.

# %%
#SEU CODIGO AQUI!

# %% [markdown]
# **Exercício 7)** Crie uma coluna de Marca no DataFrame, informando se é **Samsung**, **Motorola**, **LG** ou **Outra**.

# %%
#SEU CODIGO AQUI!

# %% [markdown]
# **Exercício 8)** Altere o código que processa os dados de resposta para retornar também (até o DataFrame) uma coluna de **ranking**, informando se o produto aparece na primeira, segunda, n-ésima posição da busca.
#
# a) Calcule o preço médio dos produtos das primeiras quatro posições de busca.

# %%
#SEU CODIGO AQUI!

# %% [markdown]
# b) Calcule a probabilidade de cada Marca aparecer em cada uma das quatro primeiras posições de busca.
#
# Dica: você precisa de uma tabela cruzada normalizada

# %%
#SEU CODIGO AQUI!

# %% [markdown]
# c) Exiba a informação anterior em um mapa de calor.
#
# Dica: utilize a função **heatmap** da biblioteca **seaborn**, ou a função **imshow** da biblioteca **plotly.express**.

# %%
#SEU CODIGO AQUI!

# %% [markdown]
# d) Calcule o preço médio cruzando ranking e marca.
#
# Dica: você precisa de uma pivot_table

# %%
#SEU CODIGO AQUI!

# %% [markdown]
# **Exercício 9)** Escolha um site de seu interesse e tente fazer o Web scraping dos seus dados. Gere e exporte para CSV um `DataFrame` contendo informações de interesse do site.

# %%
#SEU CODIGO AQUI!

# %% [markdown]
# ## Combinando termos de busca
#
# Uma outra abordagem de busca poderia ser pesquisar utilizando diversas características.
#
# Tendo os termos separados em listas, existe uma forma de combinar todos eles de forma fácil (produto cartesiano)

# %%
# !pip install sklearn

# %%
lista_marca = ['Samsung', 'Motorola', 'LG', 'Xiaomi', 'Apple']
lista_mem = ['64Gb', '128Gb', '256Gb']
lista_cor = ['Gold', 'Preto', 'Azul']

df_busca = pd.DataFrame(cartesian((lista_marca, lista_mem, lista_cor)), columns=['Marca', 'Memória', 'Cor'])
df_busca

# %% [markdown]
# Seria necessário alterar o código de pesquisa para concatenar os termos de busca e retorná-los também no DataFrame. Não precisa fazer! Esta é apenas uma sugestão.
